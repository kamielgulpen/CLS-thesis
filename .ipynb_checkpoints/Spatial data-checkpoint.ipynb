# %%
from pyclbr import Class
from networkx.algorithms.centrality import group

from descriptive import Person_links

from itertools import product
import math
import random
import pandas as pd
import networkx as nx
import numpy as np
import multiprocessing as mp
import matplotlib.pyplot as plt
from pathlib import Path
import time

# %%
df = pd.read_csv('Data/Spatial_data/bbga_latest_and_greatest_948e83a9fa.csv', sep=';')

# %%
df.columns
# Out:
# Index(['jaar', 'gebiedcode15', 'variabele', 'waarde'], dtype='object')

# %%
df = df[df['jaar'] == 2021]

# %%
df_t
# Out:
#         jaar gebiedcode15 variabele   waarde  amount_of_persons
# 100423  2021          A00  BEVDICHT  12986.0             9982.0
# 100424  2021          A01  BEVDICHT   7182.0             5521.0
# 100425  2021          A02  BEVDICHT  14217.0            10928.0
# 100426  2021          A03  BEVDICHT  10353.0             7958.0
# 100427  2021          A04  BEVDICHT  13856.0            10651.0
# ...      ...          ...       ...      ...                ...
# 100517  2021          T94  BEVDICHT   8064.0             6199.0
# 100518  2021          T95  BEVDICHT   1436.0             1104.0
# 100519  2021          T96  BEVDICHT   7014.0             5392.0
# 100520  2021          T97  BEVDICHT   6177.0             4748.0
# 100521  2021          T98  BEVDICHT    942.0              724.0
#
# [99 rows x 5 columns]

# %%
possibilities = list(df['variabele'].unique())

for possible in possibilities:

    if possible[-2:] == '_P' and possible[0:3] == 'BEV':
        print(possible)
# Out:
# BEVMAN_P
# BEVVROUW_P
# BEVINST_P
# BEVINST65PLUS_P
# BEVPOTBBV15_74_P
# BEVSUR_P
# BEVANTIL_P
# BEVTURK_P
# BEVMAROK_P
# BEVOVNW_P
# BEVWEST_P
# BEVAUTOCH_P
# BEVNW_P
# BEVNSTEDELING_P
# BEVEENOUDERHH_P
# BEVALLEENHH_P
# BEVPAARZKINDHH_P
# BEVPAARMKINDHH_P
# BEVOVERIGHH_P
# BEVHHMKIND_P
# BEV1P75PLUS_P
# BEV0_3_P
# BEV65PLUS_P
# BEV4_12_P
# BEV13_17_P
# BEV0_17_P
# BEV0_18_P
# BEV18_26_P
# BEV18_64_P
# BEV27_65_P
# BEV66PLUS_P
# BEV65_74_P
# BEV75PLUS_P
# BEV80PLUS_P
# BEV17AUTO_P
# BEV18_22NL_P
# BEV23_39NL_P
# BEV40_64NL_P
# BEV65PLUSNL_P
# BEV65_79NL_P
# BEV80PLUSNL_P
# BEV17W_P
# BEV18_22W_P
# BEV23_39W_P
# BEV40_64W_P
# BEV65PLUSW_P
# BEV65_79W_P
# BEV80PLUSW_P
# BEV17NW_P
# BEV18_22NW_P
# BEV23_39NW_P
# BEV40_64NW_P
# BEV65PLUSNW_P
# BEV65_79NW_P
# BEV80PLUSNW_P

# %%
groepen = ['BEVSUR_P',
'BEVANTIL_P',
'BEVTURK_P',
'BEVMAROK_P',
'BEVOVNW_P',
'BEVWEST_P',
'BEVAUTOCH_P',
]

# %%
x = 0

wijken = []
for i in df['gebiedcode15'].unique():
    
    if i == 'A00':
        x = 1
    
    if i == 'Z99':
        break
        
    if x == 1:
        wijken.append(i)

# %%
df_sp = df[df['jaar'] == 2021]

# %%
df_sp = df_sp.loc[df['variabele'].isin(groepen)]

# %%
df_sp = df_sp.loc[df['gebiedcode15'].isin(wijken)]

# %%
df_sp
# Out:
#         jaar gebiedcode15    variabele  waarde
# 339366  2021          A00     BEVSUR_P     2.3
# 339367  2021          A01     BEVSUR_P     1.9
# 339368  2021          A02     BEVSUR_P     0.9
# 339369  2021          A03     BEVSUR_P     1.0
# 339370  2021          A04     BEVSUR_P     2.8
# ...      ...          ...          ...     ...
# 436786  2021          T94  BEVAUTOCH_P    20.8
# 436787  2021          T95  BEVAUTOCH_P    43.3
# 436788  2021          T96  BEVAUTOCH_P    26.9
# 436789  2021          T97  BEVAUTOCH_P    35.7
# 436790  2021          T98  BEVAUTOCH_P    78.1
#
# [693 rows x 4 columns]

# %%
sum(df_sp[df_sp['gebiedcode15'] == 'A00']['waarde'])
# Out:
# 100.0

# %%
df_t = df[df['variabele'] == 'BEVDICHT']

df_t = df_t.loc[df['gebiedcode15'].isin(wijken)]

df_t['amount_of_persons'] = round(df_t['waarde']/sum(df_t['waarde']) * 861000)

# %%
df_sp['waarde']
# Out:
# 339366     2.3
# 339367     1.9
# 339368     0.9
# 339369     1.0
# 339370     2.8
#           ...
# 436786    20.8
# 436787    43.3
# 436788    26.9
# 436789    35.7
# 436790    78.1
# Name: waarde, Length: 693, dtype: float64

# %%
amount = []

for i in df_sp.iterrows():
    row = i[1]
    area = row['gebiedcode15']
    waarde = row['waarde']
    
    total = df_t[df_t['gebiedcode15'] == area]['amount_of_persons']
    
#     print(total)
#     print(total, waarde)
    amount.append(math.ceil(float(total)*float(waarde)/100))

df_sp['amount_per_area'] = amount

print(sum(amount))
# Out:
# 861224

# %%
df_sp = df_sp.replace(['BEVANTIL_P',
'BEVOVNW_P',
'BEVWEST_P'], 'OVERIG')

# %%
df_sp = df_sp.groupby(['variabele', 'gebiedcode15'], as_index=False).sum()

# %%
sum(df_sp['amount_per_area'])
# Out:
# 861224

# %%
df_sp['area_code'] = [i%99 for i in range(495)]

# %%
df_sp
# Out:
#        variabele gebiedcode15  jaar  waarde  amount_per_area  area_code
# 0    BEVAUTOCH_P          A00  2021    48.3             4822          0
# 1    BEVAUTOCH_P          A01  2021    44.7             2468          1
# 2    BEVAUTOCH_P          A02  2021    53.8             5880          2
# 3    BEVAUTOCH_P          A03  2021    52.6             4186          3
# 4    BEVAUTOCH_P          A04  2021    55.6             5922          4
# ..           ...          ...   ...     ...              ...        ...
# 490       OVERIG          T94  6063    45.6             2829         94
# 491       OVERIG          T95  6063    42.3              468         95
# 492       OVERIG          T96  6063    38.4             2072         96
# 493       OVERIG          T97  6063    37.4             1778         97
# 494       OVERIG          T98  6063    14.5              106         98
#
# [495 rows x 6 columns]

# %%
'BEVSUR_P',
'BEVANTIL_P',
'BEVTURK_P',
'BEVMAROK_P',
'BEVOVNW_P',
'BEVWEST_P',

# %%
df_sp = df_sp.replace(['BEVAUTOCH_P','BEVSUR_P','BEVMAROK_P','BEVTURK_P', 'OVERIG' ],['Autochtoon','Surinaams','Marokkaans','Turks', 'Overig'])

# %%
df_n = pd.read_csv('Data/tab_n(with oplniv).csv')

# %%
df_sp.to_csv('Data/spatial_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a1f7e7de2073> in <module>
# ----> 1 df_sp.to_csv('Data/spatial_data.csv')
#
# NameError: name 'df_sp' is not defined

# %%
def spatial(etn_dict, group_nodes):
    df_sp = pd.read_csv('Data\Spatial_data\spatial_data.csv')
    area_list = df_sp['area_code'].unique()
    etn_list = df_sp['variabele'].unique()
    groups = list(group_nodes.keys())

    areas_groups = {}
    node_area = {}
    areas_df = {} 
    areas = {}

    for area in area_list:
        areas[area] = {}
        areas_df[area] = {}
        areas_groups[area] = {}

        for etn in etn_list:
            areas_df[area][etn] = int(df_sp[(df_sp['variabele'] == etn) & (df_sp['area_code'] == area)]['amount_per_area'])
            areas[area][etn] = []
        for group in groups:
            areas_groups[area][group] = []

    total = 0
    for etn in etn_dict:
        random.shuffle(etn_dict[etn])
        random.shuffle(area_list)
        total+=len(etn_dict[etn])

        area = 0
        for count, node in enumerate(etn_dict[etn]):

            
            if len(areas[area][etn]) < areas_df[area][etn] and area < 99:
                areas[area][etn].append(node)
                areas_groups[area][node[1]].append(node[0])
                node_area[node[0]] = area

            else:
                area+=1
                
                if area > 98:
                    print(count, etn)
                    

#         print(etn_dict[etn][0:100])
#         for chosen_area in area_list:
#             # print(chosen_area)
            
#             l = []
#             for node in etn_dict[etn]:

#                 if len(areas[chosen_area][etn]) < areas_df[chosen_area][etn]:

#                     areas[chosen_area][etn].append(node[0])
#                     # etn_dict[etn].remove(node)
                    
#                     areas_groups[chosen_area][node[1]].append(node[0])
#                     node_area[node[0]] = chosen_area

#                 else:
#                     print(node)
#                     break
    return areas_groups, node_area

# %%
# total = 0
# for x in ['Autochtoon', 'Marokkaans', 'Turks', 'Overig', 'Surinaams']:

#     total+=len(etn_dict[x])

# total

spatial(etn_dict, group_nodes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-aa9fa29d62e8> in <module>
#       6 # total
#       7
# ----> 8 spatial(etn_dict, group_nodes)
#
# <ipython-input-28-0e1191397c86> in spatial(etn_dict, group_nodes)
#      31
#      32
# ---> 33             if len(areas[area][etn]) < areas_df[area][etn] and area < 99:
#      34                 areas[area][etn].append(node)
#      35                 areas_groups[area][node[1]].append(node[0])
#
# KeyError: 99

# %%
# def initialize_nodes(df, hash_dict):
#     '''
#     Initilizes all the nodes for the network
#     '''

#     # Initialize list with nodes and nodes per group (example: Man,"[0,20)",1,Autochtoon)
#     all_nodes = []
#     group_nodes = {}
    
#     etn_list = df_sp['variabele'].unique()
#     etn_dict = {etn : [] for etn in etn_list}
    
    
#     areas = {}
#     areas_df = {}
    

#     id = 0

#     # Loops through all lines in the tab_n file and get group properties of each line
#     for i in range(df.shape[0]):
#         group = df.iloc[i]

        
#         age = group['lft']
#         etnc = group['etngrp']
#         gender = group['geslacht']
#         education = group['oplniv']
#         amount = group['n']
#         nodes = []
        
#         hd = hash_dict[f'{age}, {etnc}, {gender}, {education}']
        
         
#         # Makes n (the size of the group) nodes of the group
#         for _ in range(math.ceil((group['n']))):
             
#             node = (id, hd)
#             nodes.append(node[0])
#             all_nodes.append(id)
#             etn_dict[etnc].append(node)
#             # all_nodes.append(node)
#             id += 1
            
   
                
                
#         # make a dictionary with as key the group properties and value a list of nodes of the group
#         group_nodes[hd] = nodes




#     return all_nodes, group_nodes, etn_dict

# %%
# Out:
# '\nInitialize nodes \n'

# %%
# areas = spatial(etn_dict,)

# %%
# TODO
# Spatial
# Interlayer correlation
import main



'''
Hash function
'''

hash_dict, rehash_dict =main.hash_groups()

'''
Initialize nodes 
'''

df_nodes = pd.read_csv('Data/tab_n(with oplniv).csv')
all_nodes, group_nodes, etn_dict = main.initialize_nodes(df_nodes, hash_dict)

print(all_nodes[0])
area_dict, node_area = spatial(etn_dict, group_nodes)

len(node_area)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6c0d482406bb> in <module>
#      20
#      21 print(all_nodes[0])
# ---> 22 area_dict, node_area = spatial(etn_dict, group_nodes)
#      23
#      24 len(node_area)
#
# <ipython-input-24-6c68debc6f36> in spatial(etn_dict, group_nodes)
#      34                 areas[area][etn].append(node)
#      35                 areas_groups[area][node[1]].append(node[0])
# ---> 36                 node_area[node[0]] = chosen_area
#      37
#      38             else:
#
# NameError: name 'chosen_area' is not defined

# %%
'''
Initialize edges for multiple layers
'''

layers ='buren', 'c'

barabasi = 0

percentage = 1

reciprocity = 0

# %%
def initialize_edges_links(df_edges,all_nodes, layer ,group_nodes, hash_dict, area_dict,node_area, id_source = None, id_destination = None, source = None, destination = None, barabasi = False, percentage=1, reciprocity=0):     
    '''
    Initializes the links based on the links per group instead of the probability
    '''   
    
    # Initialize all nodes with own link dictionary
    link_dictionary = {}

    for node in all_nodes:
        link_dictionary[node] = set()
      
    

    # Make from all strings integers so we do not have toe loop over pandas dataframe but over numpy array
    initial_list = []

    symetry_dict = {}


    for row in df_edges.iterrows():


        row = row[1]

        dst = hash_dict[f"{row['lft_dst']}, {row['etngrp_dst']}, {row['geslacht_dst']}, {row['oplniv_dst']}"]
        src = hash_dict[f"{row['lft_src']}, {row['etngrp_src']}, {row['geslacht_src']}, {row['oplniv_src']}"]

        initial_list.append(
            (
            dst,
            src,
            int(row['n'])
            )
            )
        
        symetry_dict[(src,dst)] = 0
    initial_list = np.array(initial_list)


    # If layer is huishouden or familie set symetric to True
    if layer == 'huishouden' or layer == 'familie':
        reciprocity = 1

    
    # Initializes the source and destinations lists if not multiprocessed
    if source == None and destination == None:
        source = []
        destination = []
        id_source = []
        id_destination = []

    total_edges = sum(df_edges['n'])

    edges_layd = 0
  
    # Loops through all connections (generated by the initialize node function) and makes links
    for row in initial_list:

        # Identifies source and destination group
        src_group = row[0]
        dst_group = row[1]
        connections = row[2]

        # If te data is symetric (familie, household), initiate a dictionary for the destination group
        if reciprocity:
            connections = connections - symetry_dict[(dst_group, src_group)]
     
        # If there are no connections between the source group and the destination group we continue
        if connections == 0:
            continue

        # Initialize dictionary with the node id as key and initial edges, 1, as value
        dst_nodes = group_nodes[dst_group]
        src_nodes = group_nodes[src_group]
        
        # If Barabasi parameter is on take a sample to put in the initial bin (1 percent is standard)
        if barabasi: 
            dst_nodes_bin = random.sample(dst_nodes, k=(math.ceil(len(dst_nodes)*(percentage/100))))
        
        i = 0
        while i < connections:

            if edges_layd % 10000 == 0:
                print(edges_layd/total_edges)
                print(edges_layd)
            
            while True:
                
                # Take random source node and destination node based on the groups
                if len(src_nodes) > 0 and len(dst_nodes) > 0:
                    
                    src_node = random.choices(src_nodes)[0]
                    dst_node = random.choices(dst_nodes)[0]
                    
                    # CHECK IN WHICH AREA HE IS FROM ==> MAKE DICTIONARY WHERE NODE IS KEY AND AREA IS VALUE
                    # CHOOSE A RANDOM OTHE NODE FROM THAT AREA WITH GROUP SPECIFICS ==> MAKE DICTIONARY WHERE AREA AND GROUP IS KEY AND LIST OF NODES IS VALUE

             
                    if layer == 'buren':
                        area = node_area[src_node]
                        
                        print(area, rehash_dict[src_group], rehash_dict[dst_group], area)
                        while True:
                           

                            dst_area_nodes = area_dict[area][src_group]
                            if len(dst_area_nodes) > 1:

                                dst_node = random.choices(dst_area_nodes)[0]
                               
                                break
                                
                            else:
                                
                                try: 
                                    area+=1
                                    area_dict[area][src_group]
                                    
                                except: 
                                   
                                    area = random.randint(0,98)
                                      
                    
                    # Take random node from the bin
                    if barabasi: dst_node = random.choices(dst_nodes_bin)[0]
                   

                else:
                    break


                # Checks if the source and destination node are not the same and checks if they aren't already linked
                if dst_node != src_node and dst_node not in link_dictionary[src_node]:
                    
                    # If Barabasi append a random node to the bin
                    if barabasi:
                        dst_nodes_bin.append(random.choices(dst_nodes)[0])
               
                        # Add the chosen node to the bin so the chosen node gets a higher weight 
                        if np.random.uniform() < barabasi : dst_nodes_bin.append(dst_node)

                        

                    # Appends both nodes to lists
                    if reciprocity > np.random.uniform() and src_node not in link_dictionary[dst_node]:


                        source.append(dst_group)
                        destination.append(src_group)
                        link_dictionary[dst_node].add(src_node)
                    
                        id_source.append(dst_node)
                        id_destination.append(src_node)
                        
                        symetry_dict[(src_group, dst_group)] += 1

                        if dst_nodes == src_nodes:
                            i += 1
                    source.append(src_group)
                    destination.append(dst_group)
                
                    id_source.append(src_node)
                    id_destination.append(dst_node)

                    link_dictionary[src_node].add(dst_node)

                    break
                
            edges_layd += 1
            i += 1

    print(edges_layd)   
    return source, destination, id_source, id_destination



if __name__ == '__main__':


    for layer_number, layer in enumerate(layers):
        
    
        df_edges = pd.read_csv(f'Data/tab_{layer}.csv')
        source, destination, source_id, destination_id = initialize_edges_links(df_edges, all_nodes, layer ,group_nodes, hash_dict,area_dict,node_area, id_source = None, id_destination = None, source = None, destination = None, barabasi = barabasi, percentage = percentage, reciprocity = reciprocity)


        d = {'source_id': list(source_id), 'destination_id':list(destination_id), 'source_group': list(source), 'destination_group': list(destination)}

        df_ = pd.DataFrame(d)
        
        df_.to_csv(f'Data/NW_data/{layer}_nw_b={barabasi}_{percentage}_percentage.csv')


#     areas
# Out:
# 0.0
# 0
# 64 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 64
# 86 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 86
# 30 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 30
# 24 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 24
# 66 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 66
# 18 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 18
# 77 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 77
# 7 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 7
# 27 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 27
# 79 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 79
# 57 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 57
# 56 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 56
# 24 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 24
# 82 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 82
# 52 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 52
# 49 [0,20), Autochtoon, Man, 2 [0,20), Autochtoon, Man, 1 49
# ...

# %%
len(etn_dict['Autochtoon']) + len(etn_dict['Turks']) + len(etn_dict['Overig']) + len(etn_dict['Marokkaans']) + len(etn_dict['Surinaams'])


# len(all_nodes)
# sum(df_nodes['n'])
# Out:
# 861000

# %%
df_sp = pd.read_csv('Data\Spatial_data\spatial_data.csv')
etn_list = df_sp['variabele'].unique()

# %%
# x = 0
# for etn in etn_list:
#     print(len(etn_dict[etn]))
#     x += len(etn_dict[etn])
# # len(node_area)
x = 0
for i in group_nodes:
    print(len(group_nodes[i]))
    
    x+= len(group_nodes[i])

x
# Out:
# 3872
# 15733
# 13303
# 4915
# 9776
# 12917
# 30829
# 1863
# 15
# 1391
# 14269
# 24847
# 29312
# 2389
# 11
# 2080
# 14068
# 17661
# 2680
# 3829
# 25004
# 2294
# 6150
# 14165
# 1506
# 3707
# 695
# 2451
# 7360
# 15798
# 939
# 2245
# 726
# 3497
# 3414
# 3399
# 2281
# 9271
# 19559
# 12208
# 596
# 2
# 3037
# 4252
# 7220
# 3492
# 5062
# 11056
# 5346
# 362
# 2
# 24605
# 1792
# 9
# 2072
# 4679
# 23061
# 26105
# 994
# 10
# 2907
# 603
# 105
# 1536
# 1586
# 1783
# 1923
# 9480
# 17205
# 6140
# 4654
# 6117
# 1138
# 3280
# 592
# 11511
# 790
# 2
# 1194
# 2486
# 1329
# 2167
# 2983
# 863
# 1935
# 3198
# 1174
# 2703
# 2098
# 705
# 1400
# 1631
# 1079
# 1965
# 388
# 53
# 2346
# 2297
# 1169
# 2970
# 3019
# 4120
# 698
# 3284
# 1026
# 2737
# 5524
# 7946
# 1441
# 297
# 767
# 1671
# 1050
# 887
# 2492
# 6706
# 22711
# 4339
# 4218
# 6248
# 1872
# 909
# 232
# 6423
# 5743
# 9643
# 4077
# 8302
# 12731
# 1264
# 1873
# 570
# 4267
# 6176
# 9363
# 594
# 4236
# 1180
# 2713
# 1170
# 427
# 1159
# 41
# 9
# 1330
# 1084
# ...

# %%
len(node_area)

node_area[92303]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4fd918d2ea2e> in <module>
#       1 len(node_area)
#       2
# ----> 3 node_area[92303]
#
# KeyError: 92303

# %%
92303 in all_nodes
# Out:
# True
