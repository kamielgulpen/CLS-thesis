# %%
from IPython.display import display
import pandas as pd

# %%
names = ['werkschool', 'buren', 'familie', 'huishouden']
categories = ['geslacht', 'oplniv', 'lft', 'etngrp']
for name in names:
    print('\n')
    print(name)
    for category in categories:
        df = pd.read_csv(f'Data/Descriptives/Theils_t/{name}_{category}2.csv')
        display(df)
# Out:
# werkschool
#   Unnamed: 0 Source        Man      Vrouw      gini    Atkins     Theil
# 0        Man    Man  17.545840  15.119430  0.037141  0.001381  0.003984
# 1      Vrouw  Vrouw  15.368037  20.213754  0.068093  0.004658  0.013420
#    Unnamed: 0  Source          1          2          3      gini    Atkins  \
# 0           1     1.0  21.280484   5.721912   2.310259  0.431446  0.173542
# 1           2     2.0   4.358339  18.476381   8.301662  0.302284  0.080565
# 2           3     3.0   2.347097  11.087270  28.427844  0.415343  0.172614
#
#       Theil
# 0  0.315839
# 1  0.146766
# 2  0.293442
#   Unnamed: 0   Source     [0,20)    [20,30)    [30,40)   [40,50)   [50,60)  \
# 0     [0,20)   [0,20)  35.191980   3.803998   1.189999  0.743184  0.593236
# 1    [20,30)  [20,30)   3.825218  22.948501  10.617070  6.203040  5.334031
# 2    [30,40)  [30,40)   1.125110   9.936412  15.050681  8.939713  7.621036
# 3    [40,50)  [40,50)   0.501493   4.408352   6.936302  6.670555  6.825085
# ...

# %%
names = ['werkschool', 'buren', 'familie', 'huishouden']
categories = ['geslacht', 'oplniv', 'lft', 'etngrp']
for name in names:
    print('\n')
    print(name)
    for category in categories:
        df = pd.read_csv(f'Data/Descriptives/Theils_t/{name}_{category}2.csv')
        display(df[['Source', 'Theil']])
# Out:
# werkschool
#   Source     Theil
# 0    Man  0.003984
# 1  Vrouw  0.013420
#    Source     Theil
# 0     1.0  0.315839
# 1     2.0  0.146766
# 2     3.0  0.293442
#     Source     Theil
# 0   [0,20)  0.678147
# 1  [20,30)  0.208779
# 2  [30,40)  0.172467
# 3  [40,50)  0.152887
# 4  [50,60)  0.158001
# 5  [60,70)  0.156455
# 6  [70,80)  0.146938
#        Source     Theil
# 0  Autochtoon  0.025498
# 1  Marokkaans  0.095094
# 2      Overig  0.014920
# 3   Surinaams  0.074414
# 4       Turks  0.112187
# buren
#   Source     Theil
# 0    Man  0.102324
# 1  Vrouw  0.001051
#    Source     Theil
# 0     1.0  0.030018
# 1     2.0  0.005145
# 2     3.0  0.259346
#      Source     Theil
# 0    [0,20)  0.016494
# 1   [20,30)  0.400486
# 2   [30,40)  0.071052
# 3   [40,50)  0.030496
# 4   [50,60)  0.027878
# 5   [60,70)  0.028312
# 6   [70,80)  0.049383
# 7  [80,120]  0.117263
#        Source     Theil
# 0  Autochtoon  0.020221
# 1  Marokkaans  0.152311
# 2      Overig  0.187133
# ...
