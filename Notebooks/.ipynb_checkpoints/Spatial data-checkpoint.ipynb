# %%
from pyclbr import Class
from networkx.algorithms.centrality import group


# from CLS_thesis.static_network.node_initialization import hash_groups
from itertools import product
import math
import random
import pandas as pd
import networkx as nx
import numpy as np
import multiprocessing as mp
import matplotlib.pyplot as plt
from pathlib import Path
import time

import sys

sys.path.append('../')
# C:\Users\KGulp\Documents\Computational Science\CLS_thesis\static_network\node_initialization.py
# from CLS_thesis.static_network.node_initialization import hash_groups
from static_network import node_initialization

# %% [markdown]
# ## Import data and check what kind of possible variables there are in the data

# %%
df = pd.read_csv('../Data/Spatial_data/bbga_latest_and_greatest_948e83a9fa.csv', sep=';')

# %%
df.columns
# Out:
# Index(['jaar', 'gebiedcode15', 'variabele', 'waarde'], dtype='object')

# %%
df = df[df['jaar'] == 2019]

# %%
possibilities = list(df['variabele'].unique())

for possible in possibilities:

    if possible[-2:] == '_P' and possible[0:3] == 'BEV':
        print(possible)
# Out:
# BEVMAN_P
# BEVVROUW_P
# BEVINST_P
# BEVINST65PLUS_P
# BEVPOTBBV15_74_P
# BEVSUR_P
# BEVANTIL_P
# BEVTURK_P
# BEVMAROK_P
# BEVOVNW_P
# BEVWEST_P
# BEVAUTOCH_P
# BEVNW_P
# BEVNSTEDELING_P
# BEVOPLLAAG_P
# BEVOPLMID_P
# BEVOPLHOOG_P
# BEVEENOUDERHH_P
# BEVALLEENHH_P
# BEVPAARZKINDHH_P
# BEVPAARMKINDHH_P
# BEVOVERIGHH_P
# BEVHHMKIND_P
# BEV1P75PLUS_P
# BEVMUTNL_P
# BEVMUTTOT_P
# BEV0_3_P
# BEV65PLUS_P
# BEV4_12_P
# BEV13_17_P
# BEV0_17_P
# BEV0_18_P
# BEV18_26_P
# BEV18_64_P
# BEV27_65_P
# BEV66PLUS_P
# BEV65_74_P
# BEV75PLUS_P
# BEV80PLUS_P
# BEV17AUTO_P
# BEV18_22NL_P
# BEV23_39NL_P
# BEV40_64NL_P
# BEV65PLUSNL_P
# BEV65_79NL_P
# BEV80PLUSNL_P
# BEV17W_P
# BEV18_22W_P
# BEV23_39W_P
# BEV40_64W_P
# BEV65PLUSW_P
# BEV65_79W_P
# BEV80PLUSW_P
# BEV17NW_P
# BEV18_22NW_P
# BEV23_39NW_P
# BEV40_64NW_P
# BEV65PLUSNW_P
# BEV65_79NW_P
# BEV80PLUSNW_P

# %% [markdown]
# # Choose the area based on the fisrt and last code
#
# This can be Gebieden, Buurten or Wijken

# %%
area = 'wijken'

if area == 'buurten':
    begin = 'A00a'
    end = 'Z99z'
elif area == 'wijken':
    begin = 'A00'
    end = 'Z99'
elif area == 'gebieden':
    begin = 'DX01'
    end = 'ZX99'

x = 0

wijken = []

for i in df['gebiedcode15'].unique():

    if i == begin:
        x = 1
    
    if i == end:
        break
        
    if x == 1:
        wijken.append(i)

print(len(wijken))
# Out:
# 99

# %% [markdown]
# # Get amount of persons per area

# %%
df_t = df[df['variabele'] == 'BEVDICHT']

df_t = df_t[df_t['jaar'] == 2019]
df_t = df_t.loc[df['gebiedcode15'].isin(wijken)]

df_t['amount_of_persons'] = (df_t['waarde']/df_t.waarde.sum()) * 861000

df_t
# Out:
#         jaar gebiedcode15 variabele   waarde  amount_of_persons
# 102107  2019          A00  BEVDICHT  12321.0        9543.378170
# 102108  2019          A01  BEVDICHT   7367.0        5706.198115
# 102109  2019          A02  BEVDICHT  14234.0       11025.115240
# 102110  2019          A03  BEVDICHT  10355.0        8020.589315
# 102111  2019          A04  BEVDICHT  13951.0       10805.914199
# ...      ...          ...       ...      ...                ...
# 102201  2019          T94  BEVDICHT   7954.0        6160.865998
# 102202  2019          T95  BEVDICHT   1374.0        1064.248162
# 102203  2019          T96  BEVDICHT   7068.0        5474.604083
# 102204  2019          T97  BEVDICHT   6289.0        4871.220299
# 102205  2019          T98  BEVDICHT    929.0         719.568080
#
# [99 rows x 5 columns]

# %% [markdown]
# # Get area distribution based on ethnicity

# %%
groepen = ['BEVSUR_P',
'BEVANTIL_P',
'BEVTURK_P',
'BEVMAROK_P',
'BEVOVNW_P',
'BEVWEST_P',
'BEVAUTOCH_P',
]

df_sp = df[df['jaar'] == 2019]


df_sp = df_sp.loc[df['variabele'].isin(groepen)]

df_sp = df_sp.loc[df['gebiedcode15'].isin(wijken)]

df_sp = df_sp.replace(['BEVANTIL_P',
'BEVOVNW_P',
'BEVWEST_P'], 'OVERIG')

df_sp = df_sp.groupby(['variabele', 'gebiedcode15'], as_index=False).sum()

df_sp = df_sp.replace(['BEVAUTOCH_P','BEVSUR_P','BEVMAROK_P','BEVTURK_P', 'OVERIG' ],['Autochtoon','Surinaams','Marokkaans','Turks', 'Overig'])


amount = []

for i in df_sp.iterrows():
    row = i[1]
    area = row['gebiedcode15']
    waarde = row['waarde']
    etn = row['variabele']
    
    print(i)
    total = df_t[df_t['gebiedcode15'] == area]['amount_of_persons']
    print(total)
    if math.isnan(total):
        amount.append(0)
        continue
        
    if int(total) == 0:
        amount.append(0)
        continue
    

    amount.append(math.ceil((float(total)*float(waarde)/100)) )

df_sp['amount_per_area'] = amount


df_sp['area_code'] = [i%len(wijken) for i in range(len(wijken)*5)]
df_sp = df_sp.fillna(0)
df_sp

# df_sp.to_csv('../Data/Spatial_data/Ethnic_data.csv')
# Out:
# (0, variabele       Autochtoon
# gebiedcode15           A00
# jaar                  2019
# waarde                50.9
# Name: 0, dtype: object)
# 102107    9543.37817
# Name: amount_of_persons, dtype: float64
# (1, variabele       Autochtoon
# gebiedcode15           A01
# jaar                  2019
# waarde                45.4
# Name: 1, dtype: object)
# 102108    5706.198115
# Name: amount_of_persons, dtype: float64
# (2, variabele       Autochtoon
# gebiedcode15           A02
# jaar                  2019
# waarde                56.2
# Name: 2, dtype: object)
# 102109    11025.11524
# Name: amount_of_persons, dtype: float64
# (3, variabele       Autochtoon
# gebiedcode15           A03
# jaar                  2019
# waarde                55.2
# Name: 3, dtype: object)
# 102110    8020.589315
# Name: amount_of_persons, dtype: float64
# (4, variabele       Autochtoon
# gebiedcode15           A04
# jaar                  2019
# waarde                57.4
# Name: 4, dtype: object)
# 102111    10805.914199
# Name: amount_of_persons, dtype: float64
# (5, variabele       Autochtoon
# gebiedcode15           A05
# jaar                  2019
# waarde                57.5
# Name: 5, dtype: object)
# 102112    13499.066208
# Name: amount_of_persons, dtype: float64
# (6, variabele       Autochtoon
# gebiedcode15           A06
# jaar                  2019
# waarde                  59
# Name: 6, dtype: object)
# 102113    18073.629268
# Name: amount_of_persons, dtype: float64
# (7, variabele       Autochtoon
# gebiedcode15           A07
# jaar                  2019
# waarde                57.5
# Name: 7, dtype: object)
# 102114    10155.282135
# Name: amount_of_persons, dtype: float64
# (8, variabele       Autochtoon
# gebiedcode15           A08
# jaar                  2019
# waarde                56.4
# Name: 8, dtype: object)
# 102115    7823.850572
# Name: amount_of_persons, dtype: float64
# (9, variabele       Autochtoon
# gebiedcode15           A09
# jaar                  2019
# waarde                54.9
# Name: 9, dtype: object)
# 102116    10441.095506
# Name: amount_of_persons, dtype: float64
# (10, variabele       Autochtoon
# gebiedcode15           B10
# jaar                  2019
# waarde                  52
# Name: 10, dtype: object)
# 102117    6.971058
# Name: amount_of_persons, dtype: float64
# (11, variabele       Autochtoon
# gebiedcode15           E12
# jaar                  2019
# waarde                  65
# Name: 11, dtype: object)
# 102118    4721.729837
# Name: amount_of_persons, dtype: float64
# (12, variabele       Autochtoon
# gebiedcode15           E13
# jaar                  2019
# waarde                49.6
# Name: 12, dtype: object)
# 102119    6307.258213
# Name: amount_of_persons, dtype: float64
# (13, variabele       Autochtoon
# gebiedcode15           E14
# jaar                  2019
# waarde                51.6
# Name: 13, dtype: object)
# 102120    21562.256431
# Name: amount_of_persons, dtype: float64
# (14, variabele       Autochtoon
# gebiedcode15           E15
# jaar                  2019
# waarde                54.3
# Name: 14, dtype: object)
# 102121    3714.799262
# Name: amount_of_persons, dtype: float64
# (15, variabele       Autochtoon
# gebiedcode15           E16
# jaar                  2019
# waarde                  55
# Name: 15, dtype: object)
# 102122    18017.860806
# Name: amount_of_persons, dtype: float64
# (16, variabele       Autochtoon
# gebiedcode15           E17
# jaar                  2019
# waarde                  58
# Name: 16, dtype: object)
# 102123    16568.655339
# Name: amount_of_persons, dtype: float64
# (17, variabele       Autochtoon
# gebiedcode15           E18
# jaar                  2019
# waarde                53.9
# Name: 17, dtype: object)
# 102124    20049.536882
# Name: amount_of_persons, dtype: float64
# (18, variabele       Autochtoon
# gebiedcode15           E19
# jaar                  2019
# waarde                47.1
# Name: 18, dtype: object)
# 102125    21832.578563
# Name: amount_of_persons, dtype: float64
# (19, variabele       Autochtoon
# gebiedcode15           E20
# jaar                  2019
# waarde                59.8
# Name: 19, dtype: object)
# 102126    17271.957618
# Name: amount_of_persons, dtype: float64
# (20, variabele       Autochtoon
# gebiedcode15           E21
# jaar                  2019
# waarde                58.7
# Name: 20, dtype: object)
# 102127    20587.082897
# Name: amount_of_persons, dtype: float64
# (21, variabele       Autochtoon
# gebiedcode15           E22
# jaar                  2019
# waarde                55.4
# Name: 21, dtype: object)
# 102128    6585.325964
# Name: amount_of_persons, dtype: float64
# (22, variabele       Autochtoon
# gebiedcode15           E36
# jaar                  2019
# waarde                  59
# Name: 22, dtype: object)
# 102129    357.073073
# Name: amount_of_persons, dtype: float64
# (23, variabele       Autochtoon
# gebiedcode15           E37
# jaar                  2019
# waarde                39.6
# Name: 23, dtype: object)
# 102130    14323.974717
# Name: amount_of_persons, dtype: float64
# (24, variabele       Autochtoon
# gebiedcode15           E38
# jaar                  2019
# waarde                50.5
# Name: 24, dtype: object)
# 102131    12605.221681
# Name: amount_of_persons, dtype: float64
# (25, variabele       Autochtoon
# gebiedcode15           E39
# jaar                  2019
# waarde                26.9
# Name: 25, dtype: object)
# 102132    11166.860082
# Name: amount_of_persons, dtype: float64
# (26, variabele       Autochtoon
# gebiedcode15           E40
# jaar                  2019
# waarde                57.1
# Name: 26, dtype: object)
# 102133    19183.576587
# Name: amount_of_persons, dtype: float64
# (27, variabele       Autochtoon
# gebiedcode15           E41
# jaar                  2019
# waarde                36.5
# Name: 27, dtype: object)
# 102134    20305.142336
# Name: amount_of_persons, dtype: float64
# (28, variabele       Autochtoon
# gebiedcode15           E42
# jaar                  2019
# waarde                45.7
# Name: 28, dtype: object)
# 102135    20126.99308
# Name: amount_of_persons, dtype: float64
# (29, variabele       Autochtoon
# gebiedcode15           E43
# jaar                  2019
# waarde                  58
# Name: 29, dtype: object)
# 102136    16875.381883
# Name: amount_of_persons, dtype: float64
# (30, variabele       Autochtoon
# gebiedcode15           E75
# jaar                  2019
# waarde                47.4
# Name: 30, dtype: object)
# 102137    18947.335183
# Name: amount_of_persons, dtype: float64
# (31, variabele       Autochtoon
# gebiedcode15           F11
# jaar                  2019
# waarde                22.8
# Name: 31, dtype: object)
# 102138    95.271124
# Name: amount_of_persons, dtype: float64
# (32, variabele       Autochtoon
# gebiedcode15           F76
# jaar                  2019
# waarde                23.5
# Name: 32, dtype: object)
# 102139    7603.874969
# Name: amount_of_persons, dtype: float64
# (33, variabele       Autochtoon
# gebiedcode15           F77
# jaar                  2019
# waarde                25.6
# Name: 33, dtype: object)
# 102140    6184.102858
# Name: amount_of_persons, dtype: float64
# (34, variabele       Autochtoon
# gebiedcode15           F78
# jaar                  2019
# waarde                21.5
# Name: 34, dtype: object)
# 102141    9574.360649
# Name: amount_of_persons, dtype: float64
# (35, variabele       Autochtoon
# gebiedcode15           F79
# jaar                  2019
# waarde                40.6
# Name: 35, dtype: object)
# 102142    881.451535
# Name: amount_of_persons, dtype: float64
# (36, variabele       Autochtoon
# gebiedcode15           F80
# jaar                  2019
# waarde                56.4
# Name: 36, dtype: object)
# 102143    168.854512
# Name: amount_of_persons, dtype: float64
# (37, variabele       Autochtoon
# gebiedcode15           F81
# jaar                  2019
# waarde                35.3
# Name: 37, dtype: object)
# 102144    8027.560373
# Name: amount_of_persons, dtype: float64
# (38, variabele       Autochtoon
# gebiedcode15           F82
# jaar                  2019
# waarde                21.6
# Name: 38, dtype: object)
# 102145    11791.157039
# Name: amount_of_persons, dtype: float64
# (39, variabele       Autochtoon
# gebiedcode15           F83
# jaar                  2019
# waarde                29.8
# Name: 39, dtype: object)
# 102146    8280.84214
# Name: amount_of_persons, dtype: float64
# (40, variabele       Autochtoon
# gebiedcode15           F84
# jaar                  2019
# waarde                43.3
# Name: 40, dtype: object)
# 102147    7603.100407
# Name: amount_of_persons, dtype: float64
# (41, variabele       Autochtoon
# gebiedcode15           F85
# jaar                  2019
# waarde                38.1
# Name: 41, dtype: object)
# 102148    5545.089223
# Name: amount_of_persons, dtype: float64
# (42, variabele       Autochtoon
# gebiedcode15           F86
# jaar                  2019
# waarde                29.3
# Name: 42, dtype: object)
# 102149    7438.893267
# Name: amount_of_persons, dtype: float64
# (43, variabele       Autochtoon
# gebiedcode15           F87
# jaar                  2019
# waarde                  37
# Name: 43, dtype: object)
# 102150    5864.983321
# Name: amount_of_persons, dtype: float64
# (44, variabele       Autochtoon
# gebiedcode15           F88
# jaar                  2019
# waarde                54.5
# Name: 44, dtype: object)
# 102151    2360.090357
# Name: amount_of_persons, dtype: float64
# (45, variabele       Autochtoon
# gebiedcode15           F89
# jaar                  2019
# waarde                33.2
# Name: 45, dtype: object)
# 102152    6630.250559
# Name: amount_of_persons, dtype: float64
# (46, variabele       Autochtoon
# gebiedcode15           K23
# jaar                  2019
# waarde                34.6
# Name: 46, dtype: object)
# 102153    1444.558095
# Name: amount_of_persons, dtype: float64
# (47, variabele       Autochtoon
# gebiedcode15           K24
# jaar                  2019
# waarde                53.5
# Name: 47, dtype: object)
# 102154    18213.824987
# Name: amount_of_persons, dtype: float64
# (48, variabele       Autochtoon
# gebiedcode15           K25
# jaar                  2019
# waarde                53.9
# Name: 48, dtype: object)
# 102155    18684.758671
# Name: amount_of_persons, dtype: float64
# (49, variabele       Autochtoon
# gebiedcode15           K26
# jaar                  2019
# waarde                46.5
# Name: 49, dtype: object)
# 102156    18017.086244
# Name: amount_of_persons, dtype: float64
# (50, variabele       Autochtoon
# gebiedcode15           K44
# jaar                  2019
# waarde                62.4
# Name: 50, dtype: object)
# 102157    10802.815951
# Name: amount_of_persons, dtype: float64
# (51, variabele       Autochtoon
# gebiedcode15           K45
# jaar                  2019
# waarde                  56
# Name: 51, dtype: object)
# 102158    10396.170911
# Name: amount_of_persons, dtype: float64
# (52, variabele       Autochtoon
# gebiedcode15           K46
# jaar                  2019
# waarde                56.7
# Name: 52, dtype: object)
# 102159    6689.117269
# Name: amount_of_persons, dtype: float64
# (53, variabele       Autochtoon
# gebiedcode15           K47
# jaar                  2019
# waarde                59.1
# Name: 53, dtype: object)
# 102160    7531.066143
# Name: amount_of_persons, dtype: float64
# (54, variabele       Autochtoon
# gebiedcode15           K48
# jaar                  2019
# waarde                55.3
# Name: 54, dtype: object)
# 102161    9683.573888
# Name: amount_of_persons, dtype: float64
# (55, variabele       Autochtoon
# gebiedcode15           K49
# jaar                  2019
# waarde                58.3
# Name: 55, dtype: object)
# 102162    7578.314424
# Name: amount_of_persons, dtype: float64
# (56, variabele       Autochtoon
# gebiedcode15           K52
# jaar                  2019
# waarde                65.4
# Name: 56, dtype: object)
# 102163    11843.827254
# Name: amount_of_persons, dtype: float64
# (57, variabele       Autochtoon
# gebiedcode15           K53
# jaar                  2019
# waarde                  59
# Name: 57, dtype: object)
# 102164    16082.230415
# Name: amount_of_persons, dtype: float64
# (58, variabele       Autochtoon
# gebiedcode15           K54
# jaar                  2019
# waarde                61.3
# Name: 58, dtype: object)
# 102165    7366.084441
# Name: amount_of_persons, dtype: float64
# (59, variabele       Autochtoon
# gebiedcode15           K59
# jaar                  2019
# waarde                56.2
# Name: 59, dtype: object)
# 102166    2721.810802
# Name: amount_of_persons, dtype: float64
# (60, variabele       Autochtoon
# gebiedcode15           K90
# jaar                  2019
# waarde                48.5
# Name: 60, dtype: object)
# 102167    3699.308022
# Name: amount_of_persons, dtype: float64
# (61, variabele       Autochtoon
# gebiedcode15           K91
# jaar                  2019
# waarde                46.4
# Name: 61, dtype: object)
# 102168    4104.403938
# Name: amount_of_persons, dtype: float64
# (62, variabele       Autochtoon
# gebiedcode15           M27
# jaar                  2019
# waarde                56.1
# Name: 62, dtype: object)
# 102169    12413.904872
# Name: amount_of_persons, dtype: float64
# (63, variabele       Autochtoon
# gebiedcode15           M28
# jaar                  2019
# waarde                46.5
# Name: 63, dtype: object)
# 102170    11671.099932
# Name: amount_of_persons, dtype: float64
# (64, variabele       Autochtoon
# gebiedcode15           M29
# jaar                  2019
# waarde                46.3
# Name: 64, dtype: object)
# 102171    13326.338886
# Name: amount_of_persons, dtype: float64
# (65, variabele       Autochtoon
# gebiedcode15           M30
# jaar                  2019
# waarde                41.1
# Name: 65, dtype: object)
# 102172    19434.534669
# Name: amount_of_persons, dtype: float64
# (66, variabele       Autochtoon
# gebiedcode15           M31
# jaar                  2019
# waarde                37.6
# Name: 66, dtype: object)
# 102173    20900.005937
# Name: amount_of_persons, dtype: float64
# (67, variabele       Autochtoon
# gebiedcode15           M32
# jaar                  2019
# waarde                34.1
# Name: 67, dtype: object)
# 102174    8622.423974
# Name: amount_of_persons, dtype: float64
# (68, variabele       Autochtoon
# gebiedcode15           M33
# jaar                  2019
# waarde                58.7
# Name: 68, dtype: object)
# 102175    9668.082649
# Name: amount_of_persons, dtype: float64
# (69, variabele       Autochtoon
# gebiedcode15           M34
# jaar                  2019
# waarde                49.7
# Name: 69, dtype: object)
# 102176    1181.207021
# Name: amount_of_persons, dtype: float64
# (70, variabele       Autochtoon
# gebiedcode15           M35
# jaar                  2019
# waarde                48.4
# Name: 70, dtype: object)
# 102177    10719.163257
# Name: amount_of_persons, dtype: float64
# (71, variabele       Autochtoon
# gebiedcode15           M50
# jaar                  2019
# waarde                   0
# Name: 71, dtype: object)
# 102178   NaN
# Name: amount_of_persons, dtype: float64
# (72, variabele       Autochtoon
# gebiedcode15           M51
# jaar                  2019
# waarde                46.2
# Name: 72, dtype: object)
# 102179    9774.972202
# Name: amount_of_persons, dtype: float64
# (73, variabele       Autochtoon
# gebiedcode15           M55
# jaar                  2019
# waarde                  55
# Name: 73, dtype: object)
# 102180    5634.938413
# Name: amount_of_persons, dtype: float64
# (74, variabele       Autochtoon
# gebiedcode15           M56
# jaar                  2019
# waarde                63.8
# Name: 74, dtype: object)
# 102181    4473.870003
# Name: amount_of_persons, dtype: float64
# (75, variabele       Autochtoon
# gebiedcode15           M57
# jaar                  2019
# waarde                61.1
# Name: 75, dtype: object)
# 102182    2376.356158
# Name: amount_of_persons, dtype: float64
# (76, variabele       Autochtoon
# gebiedcode15           M58
# jaar                  2019
# waarde                56.6
# Name: 76, dtype: object)
# 102183    1334.570294
# Name: amount_of_persons, dtype: float64
# (77, variabele       Autochtoon
# gebiedcode15           N60
# jaar                  2019
# waarde                47.4
# Name: 77, dtype: object)
# 102184    6354.506493
# Name: amount_of_persons, dtype: float64
# (78, variabele       Autochtoon
# gebiedcode15           N61
# jaar                  2019
# waarde                41.5
# Name: 78, dtype: object)
# 102185    5464.534777
# Name: amount_of_persons, dtype: float64
# (79, variabele       Autochtoon
# gebiedcode15           N62
# jaar                  2019
# waarde                74.5
# Name: 79, dtype: object)
# 102186    6394.783716
# Name: amount_of_persons, dtype: float64
# (80, variabele       Autochtoon
# gebiedcode15           N63
# jaar                  2019
# waarde                68.1
# Name: 80, dtype: object)
# 102187    8651.857329
# Name: amount_of_persons, dtype: float64
# (81, variabele       Autochtoon
# gebiedcode15           N64
# jaar                  2019
# waarde                79.6
# Name: 81, dtype: object)
# 102188    3729.515939
# Name: amount_of_persons, dtype: float64
# (82, variabele       Autochtoon
# gebiedcode15           N65
# jaar                  2019
# waarde                61.7
# Name: 82, dtype: object)
# 102189    5772.810446
# Name: amount_of_persons, dtype: float64
# (83, variabele       Autochtoon
# gebiedcode15           N66
# jaar                  2019
# waarde                55.9
# Name: 83, dtype: object)
# 102190    2811.659992
# Name: amount_of_persons, dtype: float64
# (84, variabele       Autochtoon
# gebiedcode15           N67
# jaar                  2019
# waarde                71.1
# Name: 84, dtype: object)
# 102191    1935.630391
# Name: amount_of_persons, dtype: float64
# (85, variabele       Autochtoon
# gebiedcode15           N68
# jaar                  2019
# waarde                30.5
# Name: 85, dtype: object)
# 102192    7318.061598
# Name: amount_of_persons, dtype: float64
# (86, variabele       Autochtoon
# gebiedcode15           N69
# jaar                  2019
# waarde                40.1
# Name: 86, dtype: object)
# 102193    5872.728941
# Name: amount_of_persons, dtype: float64
# (87, variabele       Autochtoon
# gebiedcode15           N70
# jaar                  2019
# waarde                37.4
# Name: 87, dtype: object)
# 102194    6792.908575
# Name: amount_of_persons, dtype: float64
# (88, variabele       Autochtoon
# gebiedcode15           N71
# jaar                  2019
# waarde                59.2
# Name: 88, dtype: object)
# 102195    1264.859715
# Name: amount_of_persons, dtype: float64
# (89, variabele       Autochtoon
# gebiedcode15           N72
# jaar                  2019
# waarde                34.4
# Name: 89, dtype: object)
# 102196    368.691503
# Name: amount_of_persons, dtype: float64
# (90, variabele       Autochtoon
# gebiedcode15           N73
# jaar                  2019
# waarde                85.4
# Name: 90, dtype: object)
# 102197    74.35795
# Name: amount_of_persons, dtype: float64
# (91, variabele       Autochtoon
# gebiedcode15           N74
# jaar                  2019
# waarde                53.2
# Name: 91, dtype: object)
# 102198    2808.561744
# Name: amount_of_persons, dtype: float64
# (92, variabele       Autochtoon
# gebiedcode15           T92
# jaar                  2019
# waarde                43.6
# Name: 92, dtype: object)
# 102199    113.860611
# Name: amount_of_persons, dtype: float64
# (93, variabele       Autochtoon
# gebiedcode15           T93
# jaar                  2019
# waarde                16.8
# Name: 93, dtype: object)
# 102200    6328.171386
# Name: amount_of_persons, dtype: float64
# (94, variabele       Autochtoon
# gebiedcode15           T94
# jaar                  2019
# waarde                21.4
# Name: 94, dtype: object)
# 102201    6160.865998
# Name: amount_of_persons, dtype: float64
# (95, variabele       Autochtoon
# gebiedcode15           T95
# jaar                  2019
# waarde                  47
# Name: 95, dtype: object)
# 102202    1064.248162
# Name: amount_of_persons, dtype: float64
# (96, variabele       Autochtoon
# gebiedcode15           T96
# jaar                  2019
# waarde                27.8
# Name: 96, dtype: object)
# 102203    5474.604083
# Name: amount_of_persons, dtype: float64
# (97, variabele       Autochtoon
# gebiedcode15           T97
# jaar                  2019
# waarde                35.8
# Name: 97, dtype: object)
# 102204    4871.220299
# Name: amount_of_persons, dtype: float64
# (98, variabele       Autochtoon
# gebiedcode15           T98
# jaar                  2019
# waarde                79.2
# Name: 98, dtype: object)
# 102205    719.56808
# Name: amount_of_persons, dtype: float64
# (99, variabele       Marokkaans
# gebiedcode15           A00
# jaar                  2019
# waarde                 0.8
# Name: 99, dtype: object)
# 102107    9543.37817
# Name: amount_of_persons, dtype: float64
# (100, variabele       Marokkaans
# gebiedcode15           A01
# jaar                  2019
# waarde                 0.8
# Name: 100, dtype: object)
# 102108    5706.198115
# Name: amount_of_persons, dtype: float64
# (101, variabele       Marokkaans
# gebiedcode15           A02
# jaar                  2019
# waarde                 0.2
# Name: 101, dtype: object)
# 102109    11025.11524
# Name: amount_of_persons, dtype: float64
# (102, variabele       Marokkaans
# gebiedcode15           A03
# jaar                  2019
# waarde                 0.4
# Name: 102, dtype: object)
# 102110    8020.589315
# Name: amount_of_persons, dtype: float64
# (103, variabele       Marokkaans
# gebiedcode15           A04
# jaar                  2019
# waarde                   1
# Name: 103, dtype: object)
# 102111    10805.914199
# Name: amount_of_persons, dtype: float64
# (104, variabele       Marokkaans
# gebiedcode15           A05
# jaar                  2019
# waarde                 2.2
# Name: 104, dtype: object)
# 102112    13499.066208
# Name: amount_of_persons, dtype: float64
# (105, variabele       Marokkaans
# gebiedcode15           A06
# jaar                  2019
# waarde                 1.7
# Name: 105, dtype: object)
# 102113    18073.629268
# Name: amount_of_persons, dtype: float64
# (106, variabele       Marokkaans
# gebiedcode15           A07
# jaar                  2019
# waarde                 0.6
# Name: 106, dtype: object)
# 102114    10155.282135
# Name: amount_of_persons, dtype: float64
# (107, variabele       Marokkaans
# gebiedcode15           A08
# jaar                  2019
# waarde                 1.8
# Name: 107, dtype: object)
# 102115    7823.850572
# Name: amount_of_persons, dtype: float64
# (108, variabele       Marokkaans
# gebiedcode15           A09
# jaar                  2019
# waarde                 4.4
# Name: 108, dtype: object)
# 102116    10441.095506
# Name: amount_of_persons, dtype: float64
# (109, variabele       Marokkaans
# gebiedcode15           B10
# jaar                  2019
# waarde                 1.1
# Name: 109, dtype: object)
# 102117    6.971058
# Name: amount_of_persons, dtype: float64
# (110, variabele       Marokkaans
# gebiedcode15           E12
# jaar                  2019
# waarde                 1.5
# Name: 110, dtype: object)
# 102118    4721.729837
# Name: amount_of_persons, dtype: float64
# (111, variabele       Marokkaans
# gebiedcode15           E13
# jaar                  2019
# waarde                 8.4
# Name: 111, dtype: object)
# 102119    6307.258213
# Name: amount_of_persons, dtype: float64
# (112, variabele       Marokkaans
# gebiedcode15           E14
# jaar                  2019
# waarde                 6.7
# Name: 112, dtype: object)
# 102120    21562.256431
# Name: amount_of_persons, dtype: float64
# (113, variabele       Marokkaans
# gebiedcode15           E15
# jaar                  2019
# waarde                 8.3
# Name: 113, dtype: object)
# 102121    3714.799262
# Name: amount_of_persons, dtype: float64
# (114, variabele       Marokkaans
# gebiedcode15           E16
# jaar                  2019
# waarde                   6
# Name: 114, dtype: object)
# 102122    18017.860806
# Name: amount_of_persons, dtype: float64
# (115, variabele       Marokkaans
# gebiedcode15           E17
# jaar                  2019
# waarde                 2.9
# Name: 115, dtype: object)
# 102123    16568.655339
# Name: amount_of_persons, dtype: float64
# (116, variabele       Marokkaans
# gebiedcode15           E18
# jaar                  2019
# waarde                 6.1
# Name: 116, dtype: object)
# 102124    20049.536882
# Name: amount_of_persons, dtype: float64
# (117, variabele       Marokkaans
# gebiedcode15           E19
# jaar                  2019
# waarde                 8.7
# Name: 117, dtype: object)
# 102125    21832.578563
# Name: amount_of_persons, dtype: float64
# (118, variabele       Marokkaans
# gebiedcode15           E20
# jaar                  2019
# waarde                 1.4
# Name: 118, dtype: object)
# 102126    17271.957618
# Name: amount_of_persons, dtype: float64
# (119, variabele       Marokkaans
# gebiedcode15           E21
# jaar                  2019
# waarde                 1.7
# Name: 119, dtype: object)
# 102127    20587.082897
# Name: amount_of_persons, dtype: float64
# (120, variabele       Marokkaans
# gebiedcode15           E22
# jaar                  2019
# waarde                 2.2
# Name: 120, dtype: object)
# 102128    6585.325964
# Name: amount_of_persons, dtype: float64
# (121, variabele       Marokkaans
# gebiedcode15           E36
# jaar                  2019
# waarde                 0.9
# Name: 121, dtype: object)
# 102129    357.073073
# Name: amount_of_persons, dtype: float64
# (122, variabele       Marokkaans
# gebiedcode15           E37
# jaar                  2019
# waarde                17.2
# Name: 122, dtype: object)
# 102130    14323.974717
# Name: amount_of_persons, dtype: float64
# (123, variabele       Marokkaans
# gebiedcode15           E38
# jaar                  2019
# waarde                 9.6
# Name: 123, dtype: object)
# 102131    12605.221681
# Name: amount_of_persons, dtype: float64
# (124, variabele       Marokkaans
# gebiedcode15           E39
# jaar                  2019
# waarde                27.2
# Name: 124, dtype: object)
# 102132    11166.860082
# Name: amount_of_persons, dtype: float64
# (125, variabele       Marokkaans
# gebiedcode15           E40
# jaar                  2019
# waarde                 4.7
# Name: 125, dtype: object)
# 102133    19183.576587
# Name: amount_of_persons, dtype: float64
# (126, variabele       Marokkaans
# gebiedcode15           E41
# jaar                  2019
# waarde                13.9
# Name: 126, dtype: object)
# 102134    20305.142336
# Name: amount_of_persons, dtype: float64
# (127, variabele       Marokkaans
# gebiedcode15           E42
# jaar                  2019
# waarde                  11
# Name: 127, dtype: object)
# 102135    20126.99308
# Name: amount_of_persons, dtype: float64
# (128, variabele       Marokkaans
# gebiedcode15           E43
# jaar                  2019
# waarde                   4
# Name: 128, dtype: object)
# 102136    16875.381883
# Name: amount_of_persons, dtype: float64
# (129, variabele       Marokkaans
# gebiedcode15           E75
# jaar                  2019
# waarde                13.1
# Name: 129, dtype: object)
# 102137    18947.335183
# Name: amount_of_persons, dtype: float64
# (130, variabele       Marokkaans
# gebiedcode15           F11
# jaar                  2019
# waarde                 2.4
# Name: 130, dtype: object)
# 102138    95.271124
# Name: amount_of_persons, dtype: float64
# (131, variabele       Marokkaans
# gebiedcode15           F76
# jaar                  2019
# waarde                26.6
# Name: 131, dtype: object)
# 102139    7603.874969
# Name: amount_of_persons, dtype: float64
# (132, variabele       Marokkaans
# gebiedcode15           F77
# jaar                  2019
# waarde                27.7
# Name: 132, dtype: object)
# 102140    6184.102858
# Name: amount_of_persons, dtype: float64
# (133, variabele       Marokkaans
# gebiedcode15           F78
# jaar                  2019
# waarde                26.8
# Name: 133, dtype: object)
# 102141    9574.360649
# Name: amount_of_persons, dtype: float64
# (134, variabele       Marokkaans
# gebiedcode15           F79
# jaar                  2019
# waarde                12.8
# Name: 134, dtype: object)
# 102142    881.451535
# Name: amount_of_persons, dtype: float64
# (135, variabele       Marokkaans
# gebiedcode15           F80
# jaar                  2019
# waarde                 2.4
# Name: 135, dtype: object)
# 102143    168.854512
# Name: amount_of_persons, dtype: float64
# (136, variabele       Marokkaans
# gebiedcode15           F81
# jaar                  2019
# waarde                20.5
# Name: 136, dtype: object)
# 102144    8027.560373
# Name: amount_of_persons, dtype: float64
# (137, variabele       Marokkaans
# gebiedcode15           F82
# jaar                  2019
# waarde                27.9
# Name: 137, dtype: object)
# 102145    11791.157039
# Name: amount_of_persons, dtype: float64
# (138, variabele       Marokkaans
# gebiedcode15           F83
# jaar                  2019
# waarde                18.1
# Name: 138, dtype: object)
# 102146    8280.84214
# Name: amount_of_persons, dtype: float64
# (139, variabele       Marokkaans
# gebiedcode15           F84
# jaar                  2019
# waarde                14.1
# Name: 139, dtype: object)
# 102147    7603.100407
# Name: amount_of_persons, dtype: float64
# (140, variabele       Marokkaans
# gebiedcode15           F85
# jaar                  2019
# waarde                18.2
# Name: 140, dtype: object)
# 102148    5545.089223
# Name: amount_of_persons, dtype: float64
# (141, variabele       Marokkaans
# gebiedcode15           F86
# jaar                  2019
# waarde                26.5
# Name: 141, dtype: object)
# 102149    7438.893267
# Name: amount_of_persons, dtype: float64
# (142, variabele       Marokkaans
# gebiedcode15           F87
# jaar                  2019
# waarde                 9.8
# Name: 142, dtype: object)
# 102150    5864.983321
# Name: amount_of_persons, dtype: float64
# (143, variabele       Marokkaans
# gebiedcode15           F88
# jaar                  2019
# waarde                 7.3
# Name: 143, dtype: object)
# 102151    2360.090357
# Name: amount_of_persons, dtype: float64
# (144, variabele       Marokkaans
# gebiedcode15           F89
# jaar                  2019
# waarde                21.2
# Name: 144, dtype: object)
# 102152    6630.250559
# Name: amount_of_persons, dtype: float64
# (145, variabele       Marokkaans
# gebiedcode15           K23
# jaar                  2019
# waarde                 1.5
# Name: 145, dtype: object)
# 102153    1444.558095
# Name: amount_of_persons, dtype: float64
# (146, variabele       Marokkaans
# gebiedcode15           K24
# jaar                  2019
# waarde                 2.6
# Name: 146, dtype: object)
# 102154    18213.824987
# Name: amount_of_persons, dtype: float64
# (147, variabele       Marokkaans
# gebiedcode15           K25
# jaar                  2019
# waarde                 4.6
# Name: 147, dtype: object)
# 102155    18684.758671
# Name: amount_of_persons, dtype: float64
# (148, variabele       Marokkaans
# gebiedcode15           K26
# jaar                  2019
# waarde                 9.9
# Name: 148, dtype: object)
# 102156    18017.086244
# Name: amount_of_persons, dtype: float64
# (149, variabele       Marokkaans
# gebiedcode15           K44
# jaar                  2019
# waarde                 1.8
# Name: 149, dtype: object)
# 102157    10802.815951
# Name: amount_of_persons, dtype: float64
# (150, variabele       Marokkaans
# gebiedcode15           K45
# jaar                  2019
# waarde                 2.7
# Name: 150, dtype: object)
# 102158    10396.170911
# Name: amount_of_persons, dtype: float64
# (151, variabele       Marokkaans
# gebiedcode15           K46
# jaar                  2019
# waarde                   1
# Name: 151, dtype: object)
# 102159    6689.117269
# Name: amount_of_persons, dtype: float64
# (152, variabele       Marokkaans
# gebiedcode15           K47
# jaar                  2019
# waarde                 0.3
# Name: 152, dtype: object)
# 102160    7531.066143
# Name: amount_of_persons, dtype: float64
# (153, variabele       Marokkaans
# gebiedcode15           K48
# jaar                  2019
# waarde                 4.7
# Name: 153, dtype: object)
# 102161    9683.573888
# Name: amount_of_persons, dtype: float64
# (154, variabele       Marokkaans
# gebiedcode15           K49
# jaar                  2019
# waarde                 0.3
# Name: 154, dtype: object)
# 102162    7578.314424
# Name: amount_of_persons, dtype: float64
# (155, variabele       Marokkaans
# gebiedcode15           K52
# jaar                  2019
# waarde                 1.8
# Name: 155, dtype: object)
# 102163    11843.827254
# Name: amount_of_persons, dtype: float64
# (156, variabele       Marokkaans
# gebiedcode15           K53
# jaar                  2019
# waarde                 5.1
# Name: 156, dtype: object)
# 102164    16082.230415
# Name: amount_of_persons, dtype: float64
# (157, variabele       Marokkaans
# gebiedcode15           K54
# jaar                  2019
# waarde                 4.2
# Name: 157, dtype: object)
# 102165    7366.084441
# Name: amount_of_persons, dtype: float64
# (158, variabele       Marokkaans
# gebiedcode15           K59
# jaar                  2019
# waarde                   1
# Name: 158, dtype: object)
# 102166    2721.810802
# Name: amount_of_persons, dtype: float64
# (159, variabele       Marokkaans
# gebiedcode15           K90
# jaar                  2019
# waarde                 1.8
# Name: 159, dtype: object)
# 102167    3699.308022
# Name: amount_of_persons, dtype: float64
# (160, variabele       Marokkaans
# gebiedcode15           K91
# jaar                  2019
# waarde                 2.3
# Name: 160, dtype: object)
# 102168    4104.403938
# Name: amount_of_persons, dtype: float64
# (161, variabele       Marokkaans
# gebiedcode15           M27
# jaar                  2019
# waarde                   4
# Name: 161, dtype: object)
# 102169    12413.904872
# Name: amount_of_persons, dtype: float64
# (162, variabele       Marokkaans
# gebiedcode15           M28
# jaar                  2019
# waarde                 9.8
# Name: 162, dtype: object)
# 102170    11671.099932
# Name: amount_of_persons, dtype: float64
# (163, variabele       Marokkaans
# gebiedcode15           M29
# jaar                  2019
# waarde                  11
# Name: 163, dtype: object)
# 102171    13326.338886
# Name: amount_of_persons, dtype: float64
# (164, variabele       Marokkaans
# gebiedcode15           M30
# jaar                  2019
# waarde                16.5
# Name: 164, dtype: object)
# 102172    19434.534669
# Name: amount_of_persons, dtype: float64
# (165, variabele       Marokkaans
# gebiedcode15           M31
# jaar                  2019
# waarde                17.6
# Name: 165, dtype: object)
# 102173    20900.005937
# Name: amount_of_persons, dtype: float64
# (166, variabele       Marokkaans
# gebiedcode15           M32
# jaar                  2019
# waarde                20.4
# Name: 166, dtype: object)
# 102174    8622.423974
# Name: amount_of_persons, dtype: float64
# (167, variabele       Marokkaans
# gebiedcode15           M33
# jaar                  2019
# waarde                 4.3
# Name: 167, dtype: object)
# 102175    9668.082649
# Name: amount_of_persons, dtype: float64
# (168, variabele       Marokkaans
# gebiedcode15           M34
# jaar                  2019
# waarde                 2.9
# Name: 168, dtype: object)
# 102176    1181.207021
# Name: amount_of_persons, dtype: float64
# (169, variabele       Marokkaans
# gebiedcode15           M35
# jaar                  2019
# waarde                 8.7
# Name: 169, dtype: object)
# 102177    10719.163257
# Name: amount_of_persons, dtype: float64
# (170, variabele       Marokkaans
# gebiedcode15           M50
# jaar                  2019
# waarde                   0
# Name: 170, dtype: object)
# 102178   NaN
# Name: amount_of_persons, dtype: float64
# (171, variabele       Marokkaans
# gebiedcode15           M51
# jaar                  2019
# waarde                10.5
# Name: 171, dtype: object)
# 102179    9774.972202
# Name: amount_of_persons, dtype: float64
# (172, variabele       Marokkaans
# gebiedcode15           M55
# jaar                  2019
# waarde                 6.5
# Name: 172, dtype: object)
# 102180    5634.938413
# Name: amount_of_persons, dtype: float64
# (173, variabele       Marokkaans
# gebiedcode15           M56
# jaar                  2019
# waarde                 2.1
# Name: 173, dtype: object)
# 102181    4473.870003
# Name: amount_of_persons, dtype: float64
# (174, variabele       Marokkaans
# gebiedcode15           M57
# jaar                  2019
# waarde                 6.1
# Name: 174, dtype: object)
# 102182    2376.356158
# Name: amount_of_persons, dtype: float64
# (175, variabele       Marokkaans
# gebiedcode15           M58
# jaar                  2019
# waarde                 1.5
# Name: 175, dtype: object)
# 102183    1334.570294
# Name: amount_of_persons, dtype: float64
# (176, variabele       Marokkaans
# gebiedcode15           N60
# jaar                  2019
# waarde                11.3
# Name: 176, dtype: object)
# 102184    6354.506493
# Name: amount_of_persons, dtype: float64
# (177, variabele       Marokkaans
# gebiedcode15           N61
# jaar                  2019
# waarde                  14
# Name: 177, dtype: object)
# 102185    5464.534777
# Name: amount_of_persons, dtype: float64
# (178, variabele       Marokkaans
# gebiedcode15           N62
# jaar                  2019
# waarde                 2.9
# Name: 178, dtype: object)
# 102186    6394.783716
# Name: amount_of_persons, dtype: float64
# (179, variabele       Marokkaans
# gebiedcode15           N63
# jaar                  2019
# waarde                 4.7
# Name: 179, dtype: object)
# 102187    8651.857329
# Name: amount_of_persons, dtype: float64
# (180, variabele       Marokkaans
# gebiedcode15           N64
# jaar                  2019
# waarde                 0.5
# Name: 180, dtype: object)
# 102188    3729.515939
# Name: amount_of_persons, dtype: float64
# (181, variabele       Marokkaans
# gebiedcode15           N65
# jaar                  2019
# waarde                 7.5
# Name: 181, dtype: object)
# 102189    5772.810446
# Name: amount_of_persons, dtype: float64
# (182, variabele       Marokkaans
# gebiedcode15           N66
# jaar                  2019
# waarde                 5.9
# Name: 182, dtype: object)
# 102190    2811.659992
# Name: amount_of_persons, dtype: float64
# (183, variabele       Marokkaans
# gebiedcode15           N67
# jaar                  2019
# waarde                 4.2
# Name: 183, dtype: object)
# 102191    1935.630391
# Name: amount_of_persons, dtype: float64
# (184, variabele       Marokkaans
# gebiedcode15           N68
# jaar                  2019
# waarde                17.2
# Name: 184, dtype: object)
# 102192    7318.061598
# Name: amount_of_persons, dtype: float64
# (185, variabele       Marokkaans
# gebiedcode15           N69
# jaar                  2019
# waarde                 9.6
# Name: 185, dtype: object)
# 102193    5872.728941
# Name: amount_of_persons, dtype: float64
# (186, variabele       Marokkaans
# gebiedcode15           N70
# jaar                  2019
# waarde                13.9
# Name: 186, dtype: object)
# 102194    6792.908575
# Name: amount_of_persons, dtype: float64
# (187, variabele       Marokkaans
# gebiedcode15           N71
# jaar                  2019
# waarde                 1.8
# Name: 187, dtype: object)
# 102195    1264.859715
# Name: amount_of_persons, dtype: float64
# (188, variabele       Marokkaans
# gebiedcode15           N72
# jaar                  2019
# waarde                 0.3
# Name: 188, dtype: object)
# 102196    368.691503
# Name: amount_of_persons, dtype: float64
# (189, variabele       Marokkaans
# gebiedcode15           N73
# jaar                  2019
# waarde                   0
# Name: 189, dtype: object)
# 102197    74.35795
# Name: amount_of_persons, dtype: float64
# (190, variabele       Marokkaans
# gebiedcode15           N74
# jaar                  2019
# waarde                 5.7
# Name: 190, dtype: object)
# 102198    2808.561744
# Name: amount_of_persons, dtype: float64
# (191, variabele       Marokkaans
# gebiedcode15           T92
# jaar                  2019
# waarde                 5.7
# Name: 191, dtype: object)
# 102199    113.860611
# Name: amount_of_persons, dtype: float64
# (192, variabele       Marokkaans
# gebiedcode15           T93
# jaar                  2019
# waarde                 2.9
# Name: 192, dtype: object)
# 102200    6328.171386
# Name: amount_of_persons, dtype: float64
# (193, variabele       Marokkaans
# gebiedcode15           T94
# jaar                  2019
# waarde                 2.2
# Name: 193, dtype: object)
# 102201    6160.865998
# Name: amount_of_persons, dtype: float64
# (194, variabele       Marokkaans
# gebiedcode15           T95
# jaar                  2019
# waarde                 0.8
# Name: 194, dtype: object)
# 102202    1064.248162
# Name: amount_of_persons, dtype: float64
# (195, variabele       Marokkaans
# gebiedcode15           T96
# jaar                  2019
# waarde                 2.3
# Name: 195, dtype: object)
# 102203    5474.604083
# Name: amount_of_persons, dtype: float64
# (196, variabele       Marokkaans
# gebiedcode15           T97
# jaar                  2019
# waarde                 1.8
# Name: 196, dtype: object)
# 102204    4871.220299
# Name: amount_of_persons, dtype: float64
# (197, variabele       Marokkaans
# gebiedcode15           T98
# jaar                  2019
# waarde                 1.1
# Name: 197, dtype: object)
# 102205    719.56808
# Name: amount_of_persons, dtype: float64
# (198, variabele       Surinaams
# gebiedcode15          A00
# jaar                 2019
# waarde                  2
# Name: 198, dtype: object)
# 102107    9543.37817
# Name: amount_of_persons, dtype: float64
# (199, variabele       Surinaams
# gebiedcode15          A01
# jaar                 2019
# waarde                1.7
# Name: 199, dtype: object)
# 102108    5706.198115
# Name: amount_of_persons, dtype: float64
# (200, variabele       Surinaams
# gebiedcode15          A02
# jaar                 2019
# waarde                0.8
# Name: 200, dtype: object)
# 102109    11025.11524
# Name: amount_of_persons, dtype: float64
# (201, variabele       Surinaams
# gebiedcode15          A03
# jaar                 2019
# waarde                0.8
# Name: 201, dtype: object)
# 102110    8020.589315
# Name: amount_of_persons, dtype: float64
# (202, variabele       Surinaams
# gebiedcode15          A04
# jaar                 2019
# waarde                2.7
# Name: 202, dtype: object)
# 102111    10805.914199
# Name: amount_of_persons, dtype: float64
# (203, variabele       Surinaams
# gebiedcode15          A05
# jaar                 2019
# waarde                  4
# Name: 203, dtype: object)
# 102112    13499.066208
# Name: amount_of_persons, dtype: float64
# (204, variabele       Surinaams
# gebiedcode15          A06
# jaar                 2019
# waarde                2.4
# Name: 204, dtype: object)
# 102113    18073.629268
# Name: amount_of_persons, dtype: float64
# (205, variabele       Surinaams
# gebiedcode15          A07
# jaar                 2019
# waarde                1.4
# Name: 205, dtype: object)
# 102114    10155.282135
# Name: amount_of_persons, dtype: float64
# (206, variabele       Surinaams
# gebiedcode15          A08
# jaar                 2019
# waarde                3.3
# Name: 206, dtype: object)
# 102115    7823.850572
# Name: amount_of_persons, dtype: float64
# (207, variabele       Surinaams
# gebiedcode15          A09
# jaar                 2019
# waarde                6.1
# Name: 207, dtype: object)
# 102116    10441.095506
# Name: amount_of_persons, dtype: float64
# (208, variabele       Surinaams
# gebiedcode15          B10
# jaar                 2019
# waarde                4.5
# Name: 208, dtype: object)
# 102117    6.971058
# Name: amount_of_persons, dtype: float64
# (209, variabele       Surinaams
# gebiedcode15          E12
# jaar                 2019
# waarde                2.5
# Name: 209, dtype: object)
# 102118    4721.729837
# Name: amount_of_persons, dtype: float64
# (210, variabele       Surinaams
# gebiedcode15          E13
# jaar                 2019
# waarde                7.9
# Name: 210, dtype: object)
# 102119    6307.258213
# Name: amount_of_persons, dtype: float64
# (211, variabele       Surinaams
# gebiedcode15          E14
# jaar                 2019
# waarde                4.5
# Name: 211, dtype: object)
# 102120    21562.256431
# Name: amount_of_persons, dtype: float64
# (212, variabele       Surinaams
# gebiedcode15          E15
# jaar                 2019
# waarde                4.2
# Name: 212, dtype: object)
# 102121    3714.799262
# Name: amount_of_persons, dtype: float64
# (213, variabele       Surinaams
# gebiedcode15          E16
# jaar                 2019
# waarde                2.7
# Name: 213, dtype: object)
# 102122    18017.860806
# Name: amount_of_persons, dtype: float64
# (214, variabele       Surinaams
# gebiedcode15          E17
# jaar                 2019
# waarde                2.9
# Name: 214, dtype: object)
# 102123    16568.655339
# Name: amount_of_persons, dtype: float64
# (215, variabele       Surinaams
# gebiedcode15          E18
# jaar                 2019
# waarde                  4
# Name: 215, dtype: object)
# 102124    20049.536882
# Name: amount_of_persons, dtype: float64
# (216, variabele       Surinaams
# gebiedcode15          E19
# jaar                 2019
# waarde                5.8
# Name: 216, dtype: object)
# 102125    21832.578563
# Name: amount_of_persons, dtype: float64
# (217, variabele       Surinaams
# gebiedcode15          E20
# jaar                 2019
# waarde                2.4
# Name: 217, dtype: object)
# 102126    17271.957618
# Name: amount_of_persons, dtype: float64
# (218, variabele       Surinaams
# gebiedcode15          E21
# jaar                 2019
# waarde                2.1
# Name: 218, dtype: object)
# 102127    20587.082897
# Name: amount_of_persons, dtype: float64
# (219, variabele       Surinaams
# gebiedcode15          E22
# jaar                 2019
# waarde                2.6
# Name: 219, dtype: object)
# 102128    6585.325964
# Name: amount_of_persons, dtype: float64
# (220, variabele       Surinaams
# gebiedcode15          E36
# jaar                 2019
# waarde                3.5
# Name: 220, dtype: object)
# 102129    357.073073
# Name: amount_of_persons, dtype: float64
# (221, variabele       Surinaams
# gebiedcode15          E37
# jaar                 2019
# waarde                4.6
# Name: 221, dtype: object)
# 102130    14323.974717
# Name: amount_of_persons, dtype: float64
# (222, variabele       Surinaams
# gebiedcode15          E38
# jaar                 2019
# waarde                2.5
# Name: 222, dtype: object)
# 102131    12605.221681
# Name: amount_of_persons, dtype: float64
# (223, variabele       Surinaams
# gebiedcode15          E39
# jaar                 2019
# waarde                5.3
# Name: 223, dtype: object)
# 102132    11166.860082
# Name: amount_of_persons, dtype: float64
# (224, variabele       Surinaams
# gebiedcode15          E40
# jaar                 2019
# waarde                3.2
# Name: 224, dtype: object)
# 102133    19183.576587
# Name: amount_of_persons, dtype: float64
# (225, variabele       Surinaams
# gebiedcode15          E41
# jaar                 2019
# waarde                9.9
# Name: 225, dtype: object)
# 102134    20305.142336
# Name: amount_of_persons, dtype: float64
# (226, variabele       Surinaams
# gebiedcode15          E42
# jaar                 2019
# waarde                  5
# Name: 226, dtype: object)
# 102135    20126.99308
# Name: amount_of_persons, dtype: float64
# (227, variabele       Surinaams
# gebiedcode15          E43
# jaar                 2019
# waarde                  3
# Name: 227, dtype: object)
# 102136    16875.381883
# Name: amount_of_persons, dtype: float64
# (228, variabele       Surinaams
# gebiedcode15          E75
# jaar                 2019
# waarde                3.9
# Name: 228, dtype: object)
# 102137    18947.335183
# Name: amount_of_persons, dtype: float64
# (229, variabele       Surinaams
# gebiedcode15          F11
# jaar                 2019
# waarde                3.6
# Name: 229, dtype: object)
# 102138    95.271124
# Name: amount_of_persons, dtype: float64
# (230, variabele       Surinaams
# gebiedcode15          F76
# jaar                 2019
# waarde                5.6
# Name: 230, dtype: object)
# 102139    7603.874969
# Name: amount_of_persons, dtype: float64
# (231, variabele       Surinaams
# gebiedcode15          F77
# jaar                 2019
# waarde                5.1
# Name: 231, dtype: object)
# 102140    6184.102858
# Name: amount_of_persons, dtype: float64
# (232, variabele       Surinaams
# gebiedcode15          F78
# jaar                 2019
# waarde                5.2
# Name: 232, dtype: object)
# 102141    9574.360649
# Name: amount_of_persons, dtype: float64
# (233, variabele       Surinaams
# gebiedcode15          F79
# jaar                 2019
# waarde                7.3
# Name: 233, dtype: object)
# 102142    881.451535
# Name: amount_of_persons, dtype: float64
# (234, variabele       Surinaams
# gebiedcode15          F80
# jaar                 2019
# waarde                2.5
# Name: 234, dtype: object)
# 102143    168.854512
# Name: amount_of_persons, dtype: float64
# (235, variabele       Surinaams
# gebiedcode15          F81
# jaar                 2019
# waarde                6.5
# Name: 235, dtype: object)
# 102144    8027.560373
# Name: amount_of_persons, dtype: float64
# (236, variabele       Surinaams
# gebiedcode15          F82
# jaar                 2019
# waarde                7.5
# Name: 236, dtype: object)
# 102145    11791.157039
# Name: amount_of_persons, dtype: float64
# (237, variabele       Surinaams
# gebiedcode15          F83
# jaar                 2019
# waarde                7.9
# Name: 237, dtype: object)
# 102146    8280.84214
# Name: amount_of_persons, dtype: float64
# (238, variabele       Surinaams
# gebiedcode15          F84
# jaar                 2019
# waarde                9.2
# Name: 238, dtype: object)
# 102147    7603.100407
# Name: amount_of_persons, dtype: float64
# (239, variabele       Surinaams
# gebiedcode15          F85
# ...
# Name: amount_of_persons, dtype: float64
# (414, variabele       Overig
# gebiedcode15       E19
# jaar              6057
# waarde            34.7
# Name: 414, dtype: object)
# 102125    21832.578563
# Name: amount_of_persons, dtype: float64
# (415, variabele       Overig
# gebiedcode15       E20
# jaar              6057
# waarde            35.4
# Name: 415, dtype: object)
# 102126    17271.957618
# Name: amount_of_persons, dtype: float64
# (416, variabele       Overig
# gebiedcode15       E21
# jaar              6057
# waarde            36.1
# Name: 416, dtype: object)
# 102127    20587.082897
# Name: amount_of_persons, dtype: float64
# (417, variabele       Overig
# gebiedcode15       E22
# jaar              6057
# waarde            38.9
# Name: 417, dtype: object)
# 102128    6585.325964
# Name: amount_of_persons, dtype: float64
# (418, variabele       Overig
# gebiedcode15       E36
# jaar              6057
# waarde            35.5
# Name: 418, dtype: object)
# 102129    357.073073
# Name: amount_of_persons, dtype: float64
# (419, variabele       Overig
# gebiedcode15       E37
# jaar              6057
# waarde              29
# Name: 419, dtype: object)
# 102130    14323.974717
# Name: amount_of_persons, dtype: float64
# (420, variabele       Overig
# gebiedcode15       E38
# jaar              6057
# waarde            28.9
# Name: 420, dtype: object)
# 102131    12605.221681
# Name: amount_of_persons, dtype: float64
# (421, variabele       Overig
# gebiedcode15       E39
# jaar              6057
# waarde            25.4
# Name: 421, dtype: object)
# 102132    11166.860082
# Name: amount_of_persons, dtype: float64
# (422, variabele       Overig
# gebiedcode15       E40
# jaar              6057
# waarde            32.1
# Name: 422, dtype: object)
# 102133    19183.576587
# Name: amount_of_persons, dtype: float64
# (423, variabele       Overig
# gebiedcode15       E41
# jaar              6057
# waarde            32.3
# Name: 423, dtype: object)
# 102134    20305.142336
# Name: amount_of_persons, dtype: float64
# (424, variabele       Overig
# gebiedcode15       E42
# jaar              6057
# waarde            30.5
# Name: 424, dtype: object)
# 102135    20126.99308
# Name: amount_of_persons, dtype: float64
# (425, variabele       Overig
# gebiedcode15       E43
# jaar              6057
# waarde            31.9
# Name: 425, dtype: object)
# 102136    16875.381883
# Name: amount_of_persons, dtype: float64
# (426, variabele       Overig
# gebiedcode15       E75
# jaar              6057
# waarde            28.4
# Name: 426, dtype: object)
# 102137    18947.335183
# Name: amount_of_persons, dtype: float64
# (427, variabele       Overig
# gebiedcode15       F11
# jaar              6057
# waarde            68.6
# Name: 427, dtype: object)
# 102138    95.271124
# Name: amount_of_persons, dtype: float64
# (428, variabele       Overig
# gebiedcode15       F76
# jaar              6057
# waarde            26.5
# Name: 428, dtype: object)
# 102139    7603.874969
# Name: amount_of_persons, dtype: float64
# (429, variabele       Overig
# gebiedcode15       F77
# jaar              6057
# waarde            25.1
# Name: 429, dtype: object)
# 102140    6184.102858
# Name: amount_of_persons, dtype: float64
# (430, variabele       Overig
# gebiedcode15       F78
# jaar              6057
# waarde            22.6
# Name: 430, dtype: object)
# 102141    9574.360649
# Name: amount_of_persons, dtype: float64
# (431, variabele       Overig
# gebiedcode15       F79
# jaar              6057
# waarde            22.3
# Name: 431, dtype: object)
# 102142    881.451535
# Name: amount_of_persons, dtype: float64
# (432, variabele       Overig
# gebiedcode15       F80
# jaar              6057
# waarde            35.1
# Name: 432, dtype: object)
# 102143    168.854512
# Name: amount_of_persons, dtype: float64
# (433, variabele       Overig
# gebiedcode15       F81
# jaar              6057
# waarde            27.2
# Name: 433, dtype: object)
# 102144    8027.560373
# Name: amount_of_persons, dtype: float64
# (434, variabele       Overig
# gebiedcode15       F82
# jaar              6057
# waarde            26.6
# Name: 434, dtype: object)
# 102145    11791.157039
# Name: amount_of_persons, dtype: float64
# (435, variabele       Overig
# gebiedcode15       F83
# jaar              6057
# waarde            29.8
# Name: 435, dtype: object)
# 102146    8280.84214
# Name: amount_of_persons, dtype: float64
# (436, variabele       Overig
# gebiedcode15       F84
# jaar              6057
# waarde              23
# Name: 436, dtype: object)
# 102147    7603.100407
# Name: amount_of_persons, dtype: float64
# (437, variabele       Overig
# gebiedcode15       F85
# jaar              6057
# waarde            26.9
# Name: 437, dtype: object)
# 102148    5545.089223
# Name: amount_of_persons, dtype: float64
# (438, variabele       Overig
# gebiedcode15       F86
# jaar              6057
# waarde            29.9
# Name: 438, dtype: object)
# 102149    7438.893267
# Name: amount_of_persons, dtype: float64
# (439, variabele       Overig
# gebiedcode15       F87
# jaar              6057
# waarde            43.6
# Name: 439, dtype: object)
# 102150    5864.983321
# Name: amount_of_persons, dtype: float64
# (440, variabele       Overig
# gebiedcode15       F88
# jaar              6057
# waarde              27
# Name: 440, dtype: object)
# 102151    2360.090357
# Name: amount_of_persons, dtype: float64
# (441, variabele       Overig
# gebiedcode15       F89
# jaar              6057
# waarde            31.3
# Name: 441, dtype: object)
# 102152    6630.250559
# Name: amount_of_persons, dtype: float64
# (442, variabele       Overig
# gebiedcode15       K23
# jaar              6057
# waarde            58.7
# Name: 442, dtype: object)
# 102153    1444.558095
# Name: amount_of_persons, dtype: float64
# (443, variabele       Overig
# gebiedcode15       K24
# jaar              6057
# waarde              39
# Name: 443, dtype: object)
# 102154    18213.824987
# Name: amount_of_persons, dtype: float64
# (444, variabele       Overig
# gebiedcode15       K25
# jaar              6057
# waarde            35.2
# Name: 444, dtype: object)
# 102155    18684.758671
# Name: amount_of_persons, dtype: float64
# (445, variabele       Overig
# gebiedcode15       K26
# jaar              6057
# waarde            32.6
# Name: 445, dtype: object)
# 102156    18017.086244
# Name: amount_of_persons, dtype: float64
# (446, variabele       Overig
# gebiedcode15       K44
# jaar              6057
# waarde              32
# Name: 446, dtype: object)
# 102157    10802.815951
# Name: amount_of_persons, dtype: float64
# (447, variabele       Overig
# gebiedcode15       K45
# jaar              6057
# waarde            34.8
# Name: 447, dtype: object)
# 102158    10396.170911
# Name: amount_of_persons, dtype: float64
# (448, variabele       Overig
# gebiedcode15       K46
# jaar              6057
# waarde            39.6
# Name: 448, dtype: object)
# 102159    6689.117269
# Name: amount_of_persons, dtype: float64
# (449, variabele       Overig
# gebiedcode15       K47
# jaar              6057
# waarde            38.6
# Name: 449, dtype: object)
# 102160    7531.066143
# Name: amount_of_persons, dtype: float64
# (450, variabele       Overig
# gebiedcode15       K48
# jaar              6057
# waarde            32.9
# Name: 450, dtype: object)
# 102161    9683.573888
# Name: amount_of_persons, dtype: float64
# (451, variabele       Overig
# gebiedcode15       K49
# jaar              6057
# waarde            39.3
# Name: 451, dtype: object)
# 102162    7578.314424
# Name: amount_of_persons, dtype: float64
# (452, variabele       Overig
# gebiedcode15       K52
# jaar              6057
# waarde            29.8
# Name: 452, dtype: object)
# 102163    11843.827254
# Name: amount_of_persons, dtype: float64
# (453, variabele       Overig
# gebiedcode15       K53
# jaar              6057
# waarde            29.3
# Name: 453, dtype: object)
# 102164    16082.230415
# Name: amount_of_persons, dtype: float64
# (454, variabele       Overig
# gebiedcode15       K54
# jaar              6057
# waarde            29.1
# Name: 454, dtype: object)
# 102165    7366.084441
# Name: amount_of_persons, dtype: float64
# (455, variabele       Overig
# gebiedcode15       K59
# jaar              6057
# waarde            40.7
# Name: 455, dtype: object)
# 102166    2721.810802
# Name: amount_of_persons, dtype: float64
# (456, variabele       Overig
# gebiedcode15       K90
# jaar              6057
# waarde            44.5
# Name: 456, dtype: object)
# 102167    3699.308022
# Name: amount_of_persons, dtype: float64
# (457, variabele       Overig
# gebiedcode15       K91
# jaar              6057
# waarde            45.7
# Name: 457, dtype: object)
# 102168    4104.403938
# Name: amount_of_persons, dtype: float64
# (458, variabele       Overig
# gebiedcode15       M27
# jaar              6057
# waarde            35.1
# Name: 458, dtype: object)
# 102169    12413.904872
# Name: amount_of_persons, dtype: float64
# (459, variabele       Overig
# gebiedcode15       M28
# jaar              6057
# waarde            31.6
# Name: 459, dtype: object)
# 102170    11671.099932
# Name: amount_of_persons, dtype: float64
# (460, variabele       Overig
# gebiedcode15       M29
# jaar              6057
# waarde            28.9
# Name: 460, dtype: object)
# 102171    13326.338886
# Name: amount_of_persons, dtype: float64
# (461, variabele       Overig
# gebiedcode15       M30
# jaar              6057
# waarde            27.3
# Name: 461, dtype: object)
# 102172    19434.534669
# Name: amount_of_persons, dtype: float64
# (462, variabele       Overig
# gebiedcode15       M31
# jaar              6057
# waarde            30.1
# Name: 462, dtype: object)
# 102173    20900.005937
# Name: amount_of_persons, dtype: float64
# (463, variabele       Overig
# gebiedcode15       M32
# jaar              6057
# waarde            27.1
# Name: 463, dtype: object)
# 102174    8622.423974
# Name: amount_of_persons, dtype: float64
# (464, variabele       Overig
# gebiedcode15       M33
# jaar              6057
# waarde            29.5
# Name: 464, dtype: object)
# 102175    9668.082649
# Name: amount_of_persons, dtype: float64
# (465, variabele       Overig
# gebiedcode15       M34
# jaar              6057
# waarde            39.6
# Name: 465, dtype: object)
# 102176    1181.207021
# Name: amount_of_persons, dtype: float64
# (466, variabele       Overig
# gebiedcode15       M35
# jaar              6057
# waarde            31.1
# Name: 466, dtype: object)
# 102177    10719.163257
# Name: amount_of_persons, dtype: float64
# (467, variabele       Overig
# gebiedcode15       M50
# jaar              6057
# waarde               0
# Name: 467, dtype: object)
# 102178   NaN
# Name: amount_of_persons, dtype: float64
# (468, variabele       Overig
# gebiedcode15       M51
# jaar              6057
# waarde            30.6
# Name: 468, dtype: object)
# 102179    9774.972202
# Name: amount_of_persons, dtype: float64
# (469, variabele       Overig
# gebiedcode15       M55
# jaar              6057
# waarde            30.8
# Name: 469, dtype: object)
# 102180    5634.938413
# Name: amount_of_persons, dtype: float64
# (470, variabele       Overig
# gebiedcode15       M56
# jaar              6057
# waarde            30.6
# Name: 470, dtype: object)
# 102181    4473.870003
# Name: amount_of_persons, dtype: float64
# (471, variabele       Overig
# gebiedcode15       M57
# jaar              6057
# waarde            24.1
# Name: 471, dtype: object)
# 102182    2376.356158
# Name: amount_of_persons, dtype: float64
# (472, variabele       Overig
# gebiedcode15       M58
# jaar              6057
# waarde            36.7
# Name: 472, dtype: object)
# 102183    1334.570294
# Name: amount_of_persons, dtype: float64
# (473, variabele       Overig
# gebiedcode15       N60
# jaar              6057
# waarde            29.2
# Name: 473, dtype: object)
# 102184    6354.506493
# Name: amount_of_persons, dtype: float64
# (474, variabele       Overig
# gebiedcode15       N61
# jaar              6057
# waarde            31.9
# Name: 474, dtype: object)
# 102185    5464.534777
# Name: amount_of_persons, dtype: float64
# (475, variabele       Overig
# gebiedcode15       N62
# jaar              6057
# waarde              18
# Name: 475, dtype: object)
# 102186    6394.783716
# Name: amount_of_persons, dtype: float64
# (476, variabele       Overig
# gebiedcode15       N63
# jaar              6057
# waarde            21.1
# Name: 476, dtype: object)
# 102187    8651.857329
# Name: amount_of_persons, dtype: float64
# (477, variabele       Overig
# gebiedcode15       N64
# jaar              6057
# waarde            19.2
# Name: 477, dtype: object)
# 102188    3729.515939
# Name: amount_of_persons, dtype: float64
# (478, variabele       Overig
# gebiedcode15       N65
# jaar              6057
# waarde            21.7
# Name: 478, dtype: object)
# 102189    5772.810446
# Name: amount_of_persons, dtype: float64
# (479, variabele       Overig
# gebiedcode15       N66
# jaar              6057
# waarde            25.2
# Name: 479, dtype: object)
# 102190    2811.659992
# Name: amount_of_persons, dtype: float64
# (480, variabele       Overig
# gebiedcode15       N67
# jaar              6057
# waarde            17.8
# Name: 480, dtype: object)
# 102191    1935.630391
# Name: amount_of_persons, dtype: float64
# (481, variabele       Overig
# gebiedcode15       N68
# jaar              6057
# waarde              31
# Name: 481, dtype: object)
# 102192    7318.061598
# Name: amount_of_persons, dtype: float64
# (482, variabele       Overig
# gebiedcode15       N69
# jaar              6057
# waarde            35.4
# Name: 482, dtype: object)
# 102193    5872.728941
# Name: amount_of_persons, dtype: float64
# (483, variabele       Overig
# gebiedcode15       N70
# jaar              6057
# waarde            28.9
# Name: 483, dtype: object)
# 102194    6792.908575
# Name: amount_of_persons, dtype: float64
# (484, variabele       Overig
# gebiedcode15       N71
# jaar              6057
# waarde            33.9
# Name: 484, dtype: object)
# 102195    1264.859715
# Name: amount_of_persons, dtype: float64
# (485, variabele       Overig
# gebiedcode15       N72
# jaar              6057
# waarde            61.3
# Name: 485, dtype: object)
# 102196    368.691503
# Name: amount_of_persons, dtype: float64
# (486, variabele       Overig
# gebiedcode15       N73
# jaar              6057
# waarde              13
# Name: 486, dtype: object)
# 102197    74.35795
# Name: amount_of_persons, dtype: float64
# (487, variabele       Overig
# gebiedcode15       N74
# jaar              6057
# waarde            28.2
# Name: 487, dtype: object)
# 102198    2808.561744
# Name: amount_of_persons, dtype: float64
# (488, variabele       Overig
# gebiedcode15       T92
# jaar              6057
# waarde            38.1
# Name: 488, dtype: object)
# 102199    113.860611
# Name: amount_of_persons, dtype: float64
# (489, variabele       Overig
# gebiedcode15       T93
# jaar              6057
# waarde            49.4
# Name: 489, dtype: object)
# 102200    6328.171386
# Name: amount_of_persons, dtype: float64
# (490, variabele       Overig
# gebiedcode15       T94
# jaar              6057
# waarde            44.3
# Name: 490, dtype: object)
# 102201    6160.865998
# Name: amount_of_persons, dtype: float64
# (491, variabele       Overig
# gebiedcode15       T95
# jaar              6057
# waarde            38.7
# Name: 491, dtype: object)
# 102202    1064.248162
# Name: amount_of_persons, dtype: float64
# (492, variabele       Overig
# gebiedcode15       T96
# jaar              6057
# waarde            37.1
# Name: 492, dtype: object)
# 102203    5474.604083
# Name: amount_of_persons, dtype: float64
# (493, variabele       Overig
# gebiedcode15       T97
# jaar              6057
# waarde            36.6
# Name: 493, dtype: object)
# 102204    4871.220299
# Name: amount_of_persons, dtype: float64
# (494, variabele       Overig
# gebiedcode15       T98
# jaar              6057
# waarde            13.8
# Name: 494, dtype: object)
# 102205    719.56808
# Name: amount_of_persons, dtype: float64
#       variabele gebiedcode15  jaar  waarde  amount_per_area  area_code
# 0    Autochtoon          A00  2019    50.9             4858          0
# 1    Autochtoon          A01  2019    45.4             2591          1
# 2    Autochtoon          A02  2019    56.2             6197          2
# 3    Autochtoon          A03  2019    55.2             4428          3
# 4    Autochtoon          A04  2019    57.4             6203          4
# ..          ...          ...   ...     ...              ...        ...
# 490      Overig          T94  6057    44.3             2730         94
# 491      Overig          T95  6057    38.7              412         95
# 492      Overig          T96  6057    37.1             2032         96
# 493      Overig          T97  6057    36.6             1783         97
# 494      Overig          T98  6057    13.8              100         98
#
# [495 rows x 6 columns]

# %%
df_sp.sort_values(by='variabele')[df_sp['variabele'] == 'Turks']

school = {}
for ethniciteit in df_sp['variabele'].unique():
    school[ethniciteit] = []
    for i in df_sp[df_sp['variabele'] == ethniciteit].itertuples():
        print(i[-2])
        school[ethniciteit].extend([i[-1]] * (i[-2]/10))
   
print(school)
# Out:
# 4858
# 2591
# 6197
# 4428
# 6203
# 7762
# 10664
# 5840
# 4413
# 5733
# 4
# 3070
# 3129
# 11127
# 2018
# 9910
# 9610
# 10807
# 10284
# 10329
# 12085
# 3649
# 211
# 5673
# 6366
# 3004
# 10954
# 7412
# 9199
# 9788
# 8982
# 22
# 1787
# 1584
# 2059
# 358
# 96
# 2834
# 2547
# 2468
# 3293
# 2113
# 2180
# 2171
# 1287
# 2202
# 500
# 9745
# 10072
# 8378
# 6741
# 5822
# 3793
# 4451
# 5356
# 4419
# 7746
# 9489
# 4516
# 1530
# 1795
# 1905
# 6965
# 5428
# 6171
# 7988
# 7859
# 2941
# 5676
# 588
# 5189
# 0
# 4517
# 3100
# 2855
# 1452
# 756
# 3013
# 2268
# 4765
# 5892
# 2969
# 3562
# 1572
# 1377
# 2233
# 2355
# 2541
# 749
# 127
# 64
# 1495
# 50
# 1064
# 1319
# 501
# 1522
# 1744
# 570
# 77
# 46
# 23
# 33
# 109
# 297
# 308
# 61
# 141
# 460
# 1
# 71
# 530
# 1445
# 309
# 1082
# 481
# 1224
# 1900
# 242
# 350
# 145
# 4
# 2464
# 1211
# 3038
# 902
# 2823
# 2214
# 676
# 2483
# 3
# 2023
# 1713
# 2566
# 113
# 5
# 1646
# 3290
# 1499
# 1073
# 1010
# 1972
# 575
# 173
# 1406
# 22
# 474
# 860
# 1784
# 195
# 281
# 67
# 23
# 456
# 23
# 214
# 821
# 310
# 28
# 67
# 95
# 497
# 1144
# 1466
# 3207
# 3679
# 1759
# 416
# 35
# 933
# 0
# 1027
# 367
# 94
# 145
# 21
# 719
# 766
# 186
# 407
# 19
# 433
# 166
# 82
# 1259
# 564
# 945
# 23
# 2
# 0
# 161
# 7
# 184
# 136
# 9
# 126
# 88
# 8
# 191
# 98
# 89
# 65
# 292
# 540
# 434
# 143
# 259
# 637
# 1
# 119
# 499
# 971
# 157
# 487
# 481
# 802
# 1267
# 415
# 433
# 172
# 13
# 659
# 316
# 592
# 614
# 2011
# 1007
# 507
# 739
# 4
# 426
# 316
# 498
# 65
# 5
# 522
# 885
# 655
# 700
# 322
# 320
# 235
# 149
# 425
# 37
# 565
# 804
# 1298
# 260
# 479
# 101
# 98
# 446
# 84
# 261
# 724
# 288
# 25
# 137
# 148
# 398
# 876
# 1040
# 1594
# 1547
# 725
# 503
# 63
# 933
# 0
# 812
# 327
# 117
# 164
# 46
# 464
# 460
# 237
# 381
# 23
# 341
# 195
# 86
# 666
# 488
# 578
# 42
# 8
# 1
# 214
# 11
# 1848
# 1898
# 132
# 1741
# 1228
# 39
# 86
# 63
# 89
# 97
# 119
# 122
# 199
# 92
# 87
# 168
# 1
# 57
# 152
# 453
# 79
# 325
# 249
# 602
# 786
# 190
# 289
# 60
# 4
# 1361
# 1085
# 1698
# 538
# 1503
# 1550
# 524
# 1365
# 3
# 1346
# 1021
# 2298
# 149
# 7
# 851
# 1934
# 1193
# 784
# 616
# 744
# 329
# 116
# 531
# 40
# 328
# 374
# 703
# 152
# 198
# 81
# 61
# 252
# 84
# 119
# 354
# 104
# 33
# 60
# 87
# 212
# 549
# 800
# 1341
# 1526
# 880
# 223
# 30
# 333
# 0
# 431
# 113
# 45
# 43
# 25
# 299
# 235
# 58
# 148
# 4
# 191
# 169
# 49
# 901
# 394
# 761
# 22
# 7
# 1
# 149
# 4
# 114
# 74
# 12
# 50
# 30
# 5
# 4333
# 2905
# 4631
# 3393
# 4096
# 4779
# 6471
# 4022
# 2919
# 3446
# 3
# 1408
# 2006
# 7547
# 1156
# 6217
# 5766
# 6597
# 7576
# 6115
# 7432
# 2562
# 127
# 4154
# 3643
# 2837
# 6158
# 6559
# 6139
# 5384
# 5382
# 66
# 2016
# 1553
# 2164
# 197
# 60
# 2184
# 3137
# 2468
# 1749
# 1492
# 2225
# 2558
# 638
# 2076
# 848
# 7104
# 6578
# 5874
# 3457
# 3618
# 2649
# 2907
# 3186
# 2979
# 3530
# 4713
# 2144
# 1108
# 1647
# 1876
# 4358
# 3689
# 3852
# 5306
# 6291
# 2337
# 2853
# 468
# 3334
# 0
# 2992
# 1736
# 1370
# 573
# 490
# 1856
# 1744
# 1152
# 1826
# 717
# 1253
# 709
# 345
# 2269
# 2079
# 1964
# 429
# 227
# 10
# 793
# 44
# 3127
# 2730
# 412
# 2032
# 1783
# 100
# <ipython-input-62-1c6ce1eddc1d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_sp.sort_values(by='variabele')[df_sp['variabele'] == 'Turks']

# %% [markdown]
# # Get Area distribution based on gender

# %%
groepen = ['BEVMAN_P', 'BEVVROUW_P']
df_sp = df[df['jaar'] == 2019]


df_sp = df_sp.loc[df['variabele'].isin(groepen)]

df_sp = df_sp.loc[df['gebiedcode15'].isin(wijken)]
df_sp = df_sp.replace(['BEVMAN_P','BEVVROUW_P'],['Man','Vrouw'])

df_sp = df_sp.groupby(['variabele', 'gebiedcode15'], as_index=False).sum()


amount = []

for i in df_sp.iterrows():
    row = i[1]
    area = row['gebiedcode15']
    waarde = row['waarde']
    etn = row['variabele']
    
    total = df_t[df_t['gebiedcode15'] == area]['amount_of_persons']
    
    print(total)
    if math.isnan(total):
        amount.append(0)
        continue
        
    if int(total) == 0:
        amount.append(0)
        continue
    amount.append(math.ceil((float(total)*float(waarde)/100)) )

df_sp['amount_per_area'] = amount

print(sum(amount))

df_sp['area_code'] = [i%len(wijken) for i in range(len(wijken)*2)]



df_sp.to_csv('../Data/Spatial_data/Gender_data.csv')
# Out:
# 102434    3005.278208
# Name: amount_of_persons, dtype: float64
# 102435    1381.177869
# Name: amount_of_persons, dtype: float64
# 102436    4368.96843
# Name: amount_of_persons, dtype: float64
# 102437    1139.467413
# Name: amount_of_persons, dtype: float64
# 102438    1285.42867
# Name: amount_of_persons, dtype: float64
# 102439    2.597175
# Name: amount_of_persons, dtype: float64
# 102440    1903.556411
# Name: amount_of_persons, dtype: float64
# 102441    1503.591402
# Name: amount_of_persons, dtype: float64
# 102442    2797.504178
# Name: amount_of_persons, dtype: float64
# 102443    1698.379556
# Name: amount_of_persons, dtype: float64
# 102444    2121.545998
# Name: amount_of_persons, dtype: float64
# 102445    1041.986764
# Name: amount_of_persons, dtype: float64
# 102446    873.689799
# Name: amount_of_persons, dtype: float64
# 102447    3282.656539
# Name: amount_of_persons, dtype: float64
# 102448    2303.86771
# Name: amount_of_persons, dtype: float64
# 102449    2188.553123
# Name: amount_of_persons, dtype: float64
# 102450    2217.814632
# Name: amount_of_persons, dtype: float64
# 102451    1767.810711
# Name: amount_of_persons, dtype: float64
# 102452   NaN
# Name: amount_of_persons, dtype: float64
# 102453    1903.902701
# Name: amount_of_persons, dtype: float64
# 102454    2344.729936
# Name: amount_of_persons, dtype: float64
# 102455    1416.326309
# Name: amount_of_persons, dtype: float64
# 102456   NaN
# Name: amount_of_persons, dtype: float64
# 102457    2062.676689
# Name: amount_of_persons, dtype: float64
# 102458    713.18436
# Name: amount_of_persons, dtype: float64
# 102459   NaN
# Name: amount_of_persons, dtype: float64
# 102460    1915.849708
# Name: amount_of_persons, dtype: float64
# 102461    3541.162063
# Name: amount_of_persons, dtype: float64
# 102462    4755.428127
# Name: amount_of_persons, dtype: float64
# 102463    2535.535754
# Name: amount_of_persons, dtype: float64
# 102464    3095.140477
# Name: amount_of_persons, dtype: float64
# 102465    3843.473277
# Name: amount_of_persons, dtype: float64
# 102466    1351.223779
# Name: amount_of_persons, dtype: float64
# 102467    2166.909995
# Name: amount_of_persons, dtype: float64
# 102468    2833.345198
# Name: amount_of_persons, dtype: float64
# 102469    3940.953927
# Name: amount_of_persons, dtype: float64
# 102470    3369.748487
# Name: amount_of_persons, dtype: float64
# 102471   NaN
# Name: amount_of_persons, dtype: float64
# 102472   NaN
# Name: amount_of_persons, dtype: float64
# 102473    4787.633101
# Name: amount_of_persons, dtype: float64
# 102474    4466.795369
# Name: amount_of_persons, dtype: float64
# 102475    4635.784914
# Name: amount_of_persons, dtype: float64
# 102476   NaN
# Name: amount_of_persons, dtype: float64
# 102477   NaN
# Name: amount_of_persons, dtype: float64
# 102478    3971.773741
# Name: amount_of_persons, dtype: float64
# 102479   NaN
# Name: amount_of_persons, dtype: float64
# 102480   NaN
# Name: amount_of_persons, dtype: float64
# 102481   NaN
# Name: amount_of_persons, dtype: float64
# 102482    3842.607552
# Name: amount_of_persons, dtype: float64
# 102483    4632.495159
# Name: amount_of_persons, dtype: float64
# 102484   NaN
# Name: amount_of_persons, dtype: float64
# 102485   NaN
# Name: amount_of_persons, dtype: float64
# 102486    3182.578715
# Name: amount_of_persons, dtype: float64
# 102487   NaN
# Name: amount_of_persons, dtype: float64
# 102488    3529.041911
# Name: amount_of_persons, dtype: float64
# 102489    1952.556453
# Name: amount_of_persons, dtype: float64
# 102490    3479.176143
# Name: amount_of_persons, dtype: float64
# 102491    1183.44625
# Name: amount_of_persons, dtype: float64
# 102492    2725.648992
# Name: amount_of_persons, dtype: float64
# 102493    2064.75443
# Name: amount_of_persons, dtype: float64
# 102494    957.318846
# Name: amount_of_persons, dtype: float64
# 102495   NaN
# Name: amount_of_persons, dtype: float64
# 102496    86.572513
# Name: amount_of_persons, dtype: float64
# 102497    3347.066489
# Name: amount_of_persons, dtype: float64
# 102498    3066.052112
# Name: amount_of_persons, dtype: float64
# 102499    1476.753923
# Name: amount_of_persons, dtype: float64
# 102500    3983.547603
# Name: amount_of_persons, dtype: float64
# 102501    3227.423276
# Name: amount_of_persons, dtype: float64
# 102502    3067.956708
# Name: amount_of_persons, dtype: float64
# 102503    2887.020156
# Name: amount_of_persons, dtype: float64
# 102504    3.636046
# Name: amount_of_persons, dtype: float64
# 102505    3.982336
# Name: amount_of_persons, dtype: float64
# 102506    0.173145
# Name: amount_of_persons, dtype: float64
# 102507    1.212015
# Name: amount_of_persons, dtype: float64
# 102508    2.250885
# Name: amount_of_persons, dtype: float64
# 102509    2.07774
# Name: amount_of_persons, dtype: float64
# 102510    0.173145
# Name: amount_of_persons, dtype: float64
# 102511    4.501771
# Name: amount_of_persons, dtype: float64
# 102512    806.855819
# Name: amount_of_persons, dtype: float64
# 102513   NaN
# Name: amount_of_persons, dtype: float64
# 102514    3963.11649
# Name: amount_of_persons, dtype: float64
# 102515    4807.025344
# Name: amount_of_persons, dtype: float64
# 102516   NaN
# Name: amount_of_persons, dtype: float64
# 102517    3820.271844
# Name: amount_of_persons, dtype: float64
# 102518    3922.427409
# Name: amount_of_persons, dtype: float64
# 102519    2877.324035
# Name: amount_of_persons, dtype: float64
# 102520   NaN
# Name: amount_of_persons, dtype: float64
# 102521    2.597175
# Name: amount_of_persons, dtype: float64
# 102522    3812.653463
# Name: amount_of_persons, dtype: float64
# 102523   NaN
# Name: amount_of_persons, dtype: float64
# 102524    3549.819314
# Name: amount_of_persons, dtype: float64
# 102525    6197.553045
# Name: amount_of_persons, dtype: float64
# 102526    5047.523785
# Name: amount_of_persons, dtype: float64
# 102527    4734.477579
# Name: amount_of_persons, dtype: float64
# 102528    3726.77353
# Name: amount_of_persons, dtype: float64
# 102529    10.042411
# Name: amount_of_persons, dtype: float64
# 102530    87.611383
# Name: amount_of_persons, dtype: float64
# 102531    3143.794229
# Name: amount_of_persons, dtype: float64
# 102532    3656.13036
# Name: amount_of_persons, dtype: float64
# 102533    5002.332933
# Name: amount_of_persons, dtype: float64
# 102534    3357.282045
# Name: amount_of_persons, dtype: float64
# 102535    3703.745242
# Name: amount_of_persons, dtype: float64
# 102536    4920.954771
# Name: amount_of_persons, dtype: float64
# 102537    4211.579601
# Name: amount_of_persons, dtype: float64
# 102538    5387.40747
# Name: amount_of_persons, dtype: float64
# 102539    4396.671634
# Name: amount_of_persons, dtype: float64
# 102540    5164.223532
# Name: amount_of_persons, dtype: float64
# 102541    4419.873067
# Name: amount_of_persons, dtype: float64
# 102542    2658.295577
# Name: amount_of_persons, dtype: float64
# 102543    5932.8143
# Name: amount_of_persons, dtype: float64
# 102544    5027.438962
# Name: amount_of_persons, dtype: float64
# 102545    3774.388412
# Name: amount_of_persons, dtype: float64
# 102546    1294.951646
# Name: amount_of_persons, dtype: float64
# 102547    1716.386638
# Name: amount_of_persons, dtype: float64
# 102548    153.233348
# Name: amount_of_persons, dtype: float64
# 102549    24.759739
# Name: amount_of_persons, dtype: float64
# 102550    887.195111
# Name: amount_of_persons, dtype: float64
# 102551    2936.539633
# Name: amount_of_persons, dtype: float64
# 102552    3422.038285
# Name: amount_of_persons, dtype: float64
# 102553    4056.268514
# Name: amount_of_persons, dtype: float64
# 102554    3841.568682
# Name: amount_of_persons, dtype: float64
# 102555    4242.053126
# Name: amount_of_persons, dtype: float64
# 102556    2403.77239
# Name: amount_of_persons, dtype: float64
# 102557    4673.011095
# Name: amount_of_persons, dtype: float64
# 102558    2569.299034
# Name: amount_of_persons, dtype: float64
# 102559    2563.412103
# Name: amount_of_persons, dtype: float64
# 102560    3056.009701
# Name: amount_of_persons, dtype: float64
# 102561    2203.789885
# Name: amount_of_persons, dtype: float64
# 102562    3641.413032
# Name: amount_of_persons, dtype: float64
# 102563    4502.982679
# Name: amount_of_persons, dtype: float64
# 102564    4651.367966
# Name: amount_of_persons, dtype: float64
# 102565    4707.29381
# Name: amount_of_persons, dtype: float64
# 102566    4992.463667
# Name: amount_of_persons, dtype: float64
# 102567   NaN
# Name: amount_of_persons, dtype: float64
# 102568    3509.822813
# Name: amount_of_persons, dtype: float64
# 102569    4577.608185
# Name: amount_of_persons, dtype: float64
# 102570    4162.233269
# Name: amount_of_persons, dtype: float64
# 102571    5535.619612
# Name: amount_of_persons, dtype: float64
# 102572    4192.014214
# Name: amount_of_persons, dtype: float64
# 102573    4335.55144
# Name: amount_of_persons, dtype: float64
# 102574    3228.981581
# Name: amount_of_persons, dtype: float64
# 102575    4034.971675
# Name: amount_of_persons, dtype: float64
# 102576   NaN
# Name: amount_of_persons, dtype: float64
# 102577    4477.010926
# Name: amount_of_persons, dtype: float64
# 102578   NaN
# Name: amount_of_persons, dtype: float64
# 102579    10.042411
# Name: amount_of_persons, dtype: float64
# 102580   NaN
# Name: amount_of_persons, dtype: float64
# 102581    7.098946
# Name: amount_of_persons, dtype: float64
# 102582    4.155481
# Name: amount_of_persons, dtype: float64
# 102583    149.424157
# Name: amount_of_persons, dtype: float64
# 102584    0.519435
# Name: amount_of_persons, dtype: float64
# 102585   NaN
# Name: amount_of_persons, dtype: float64
# 102586    1589.64448
# Name: amount_of_persons, dtype: float64
# 102587    1962.07943
# Name: amount_of_persons, dtype: float64
# 102588    1466.365221
# Name: amount_of_persons, dtype: float64
# 102589    1609.729303
# Name: amount_of_persons, dtype: float64
# 102590    1857.672979
# Name: amount_of_persons, dtype: float64
# 102591    2912.29933
# Name: amount_of_persons, dtype: float64
# 102592    13.678457
# Name: amount_of_persons, dtype: float64
# 102593    2186.821673
# Name: amount_of_persons, dtype: float64
# 102594    2019.563578
# Name: amount_of_persons, dtype: float64
# 102595    1722.273569
# Name: amount_of_persons, dtype: float64
# 102596    2864.165013
# Name: amount_of_persons, dtype: float64
# 102597    2585.920957
# Name: amount_of_persons, dtype: float64
# 102598    436.671754
# Name: amount_of_persons, dtype: float64
# 102599    2.77032
# Name: amount_of_persons, dtype: float64
# 102600    1445.760963
# Name: amount_of_persons, dtype: float64
# 102601    66.660835
# Name: amount_of_persons, dtype: float64
# 102602    57.484148
# Name: amount_of_persons, dtype: float64
# 102603    5.713786
# Name: amount_of_persons, dtype: float64
# 102604    2721.493512
# Name: amount_of_persons, dtype: float64
# 102605    2586.959827
# Name: amount_of_persons, dtype: float64
# 102606    1718.464379
# Name: amount_of_persons, dtype: float64
# 102607    815.85936
# Name: amount_of_persons, dtype: float64
# 102608    1429.485331
# Name: amount_of_persons, dtype: float64
# 102609    2348.539127
# Name: amount_of_persons, dtype: float64
# 102610    2569.125889
# Name: amount_of_persons, dtype: float64
# 102611    2391.305948
# Name: amount_of_persons, dtype: float64
# 102612    3005.624499
# Name: amount_of_persons, dtype: float64
# 102613    2249.846462
# Name: amount_of_persons, dtype: float64
# 102614    193.056703
# Name: amount_of_persons, dtype: float64
# 102615    2081.722642
# Name: amount_of_persons, dtype: float64
# 102616    1561.594985
# Name: amount_of_persons, dtype: float64
# 102617    1613.711638
# Name: amount_of_persons, dtype: float64
# 102618    1152.107
# Name: amount_of_persons, dtype: float64
# 102619    868.668593
# Name: amount_of_persons, dtype: float64
# 102620    1879.662397
# Name: amount_of_persons, dtype: float64
# 102621    3094.794187
# Name: amount_of_persons, dtype: float64
# 102622    2479.436766
# Name: amount_of_persons, dtype: float64
# 102623    603.237269
# Name: amount_of_persons, dtype: float64
# 102624    533.632969
# Name: amount_of_persons, dtype: float64
# 102625    1403.859867
# Name: amount_of_persons, dtype: float64
# 102626    1082.84899
# Name: amount_of_persons, dtype: float64
# 102627    1872.390306
# Name: amount_of_persons, dtype: float64
# 102628    1575.273442
# Name: amount_of_persons, dtype: float64
# 102629    1582.718679
# Name: amount_of_persons, dtype: float64
# 102630    1845.552827
# Name: amount_of_persons, dtype: float64
# 102631    246.039081
# Name: amount_of_persons, dtype: float64
# 102632    1675.351267
# Name: amount_of_persons, dtype: float64
# 102633    23.720869
# Name: amount_of_persons, dtype: float64
# 102634    1524.88824
# Name: amount_of_persons, dtype: float64
# 102635    22.335708
# Name: amount_of_persons, dtype: float64
# 102636    56.964713
# Name: amount_of_persons, dtype: float64
# 102637    1569.040222
# Name: amount_of_persons, dtype: float64
# 102638    1255.994015
# Name: amount_of_persons, dtype: float64
# 102639    2287.245788
# Name: amount_of_persons, dtype: float64
# 102640    1869.446841
# Name: amount_of_persons, dtype: float64
# 102641    1587.047304
# Name: amount_of_persons, dtype: float64
# 102642    232.014334
# Name: amount_of_persons, dtype: float64
# 102643    1576.485458
# Name: amount_of_persons, dtype: float64
# 102644    2098.690855
# Name: amount_of_persons, dtype: float64
# 102645    1697.860121
# Name: amount_of_persons, dtype: float64
# 102646    503.332589
# Name: amount_of_persons, dtype: float64
# 102647    106.137901
# Name: amount_of_persons, dtype: float64
# 102648   NaN
# Name: amount_of_persons, dtype: float64
# 102649    63.890514
# Name: amount_of_persons, dtype: float64
# 102650    1894.033434
# Name: amount_of_persons, dtype: float64
# 102651    604.968719
# Name: amount_of_persons, dtype: float64
# 102652    3851.611093
# Name: amount_of_persons, dtype: float64
# 102653    3509.822813
# Name: amount_of_persons, dtype: float64
# 102654    3992.724289
# Name: amount_of_persons, dtype: float64
# 102655    5575.442968
# Name: amount_of_persons, dtype: float64
# 102656    3930.04579
# Name: amount_of_persons, dtype: float64
# 102657    4243.784576
# Name: amount_of_persons, dtype: float64
# 102658    4835.940564
# Name: amount_of_persons, dtype: float64
# 102659    3406.108943
# Name: amount_of_persons, dtype: float64
# 102660    4165.69617
# Name: amount_of_persons, dtype: float64
# 102661    3955.844399
# Name: amount_of_persons, dtype: float64
# 102662    4141.629011
# Name: amount_of_persons, dtype: float64
# 102663    3991.858564
# Name: amount_of_persons, dtype: float64
# 102664    3167.515097
# Name: amount_of_persons, dtype: float64
# 102665    3968.310841
# Name: amount_of_persons, dtype: float64
# 102666    4505.926145
# Name: amount_of_persons, dtype: float64
# 102667    3311.918049
# Name: amount_of_persons, dtype: float64
# 102668    4194.438244
# Name: amount_of_persons, dtype: float64
# 102669    141.805776
# Name: amount_of_persons, dtype: float64
# 102670    4195.477114
# Name: amount_of_persons, dtype: float64
# 102671    1352.95523
# Name: amount_of_persons, dtype: float64
# 102672    2075.489421
# Name: amount_of_persons, dtype: float64
# 102673    3267.592922
# Name: amount_of_persons, dtype: float64
# 102674    1429.658476
# Name: amount_of_persons, dtype: float64
# 102675   NaN
# Name: amount_of_persons, dtype: float64
# 102676    1689.722304
# Name: amount_of_persons, dtype: float64
# 102677    1231.926857
# Name: amount_of_persons, dtype: float64
# 102678    2410.525046
# Name: amount_of_persons, dtype: float64
# 102679    2603.408604
# Name: amount_of_persons, dtype: float64
# 102680    1339.276773
# Name: amount_of_persons, dtype: float64
# 102681    2866.935333
# Name: amount_of_persons, dtype: float64
# 102682    2464.892584
# Name: amount_of_persons, dtype: float64
# 102683    10.908137
# Name: amount_of_persons, dtype: float64
# 102684    3.462901
# Name: amount_of_persons, dtype: float64
# 102685    4096.957595
# Name: amount_of_persons, dtype: float64
# 102686    3413.727324
# Name: amount_of_persons, dtype: float64
# 102687    1702.881326
# Name: amount_of_persons, dtype: float64
# 102688    3561.07374
# Name: amount_of_persons, dtype: float64
# 102689    1916.022853
# Name: amount_of_persons, dtype: float64
# 102690    312.180481
# Name: amount_of_persons, dtype: float64
# 102691    3612.151523
# Name: amount_of_persons, dtype: float64
# 102692    711.626055
# Name: amount_of_persons, dtype: float64
# 102693    1484.026014
# Name: amount_of_persons, dtype: float64
# 102694    141.459486
# Name: amount_of_persons, dtype: float64
# 102695    1664.962566
# Name: amount_of_persons, dtype: float64
# 102696    2810.31691
# Name: amount_of_persons, dtype: float64
# 102697    3024.151016
# Name: amount_of_persons, dtype: float64
# 102698    3751.706414
# Name: amount_of_persons, dtype: float64
# 102699    3030.730527
# Name: amount_of_persons, dtype: float64
# 102700    3408.706118
# Name: amount_of_persons, dtype: float64
# 102701    2973.592669
# Name: amount_of_persons, dtype: float64
# 102702    1992.552954
# Name: amount_of_persons, dtype: float64
# 102703    639.944014
# Name: amount_of_persons, dtype: float64
# 102704    3364.900427
# Name: amount_of_persons, dtype: float64
# 102705    3810.402577
# Name: amount_of_persons, dtype: float64
# 102706    2582.631201
# Name: amount_of_persons, dtype: float64
# 102707    2468.009194
# Name: amount_of_persons, dtype: float64
# 102708    1460.478291
# Name: amount_of_persons, dtype: float64
# 102709    3749.109238
# Name: amount_of_persons, dtype: float64
# 102710    29.261509
# Name: amount_of_persons, dtype: float64
# 102711    948.14216
# Name: amount_of_persons, dtype: float64
# 102712   NaN
# Name: amount_of_persons, dtype: float64
# 102713    1795.34077
# Name: amount_of_persons, dtype: float64
# 102714    1322.481705
# Name: amount_of_persons, dtype: float64
# 102715    1028.481452
# Name: amount_of_persons, dtype: float64
# 102716    15.063617
# Name: amount_of_persons, dtype: float64
# 102717    706.085414
# Name: amount_of_persons, dtype: float64
# 102718    20.777403
# Name: amount_of_persons, dtype: float64
# 102719    1041.640474
# Name: amount_of_persons, dtype: float64
# 102720    1971.775551
# Name: amount_of_persons, dtype: float64
# 102721    1140.333138
# Name: amount_of_persons, dtype: float64
# 102722    4.155481
# Name: amount_of_persons, dtype: float64
# 102723    3082.50089
# Name: amount_of_persons, dtype: float64
# 102724    3121.631666
# Name: amount_of_persons, dtype: float64
# 102725    1360.054176
# Name: amount_of_persons, dtype: float64
# 102726    3144.659954
# Name: amount_of_persons, dtype: float64
# 102727    93.325169
# Name: amount_of_persons, dtype: float64
# 102728    4145.438202
# Name: amount_of_persons, dtype: float64
# 102729    4391.130993
# Name: amount_of_persons, dtype: float64
# 102730    3839.837232
# Name: amount_of_persons, dtype: float64
# 102731    3795.512105
# Name: amount_of_persons, dtype: float64
# 102732    1579.428923
# Name: amount_of_persons, dtype: float64
# 102733    4104.402831
# Name: amount_of_persons, dtype: float64
# 102734    4561.332553
# Name: amount_of_persons, dtype: float64
# 102735    4074.448741
# Name: amount_of_persons, dtype: float64
# 102736    5528.520666
# Name: amount_of_persons, dtype: float64
# 102737    4504.540985
# Name: amount_of_persons, dtype: float64
# 102738    4057.307384
# Name: amount_of_persons, dtype: float64
# 102739    4520.470327
# Name: amount_of_persons, dtype: float64
# 102740    972.728754
# Name: amount_of_persons, dtype: float64
# 102741    6.925801
# Name: amount_of_persons, dtype: float64
# 102742    1151.76071
# Name: amount_of_persons, dtype: float64
# 102743    1618.559699
# Name: amount_of_persons, dtype: float64
# 102744    3200.066362
# Name: amount_of_persons, dtype: float64
# 102745    3214.610544
# Name: amount_of_persons, dtype: float64
# 102746    3534.582552
# Name: amount_of_persons, dtype: float64
# 102747    4142.494736
# Name: amount_of_persons, dtype: float64
# 102748    2363.949034
# Name: amount_of_persons, dtype: float64
# 102749    3007.009659
# Name: amount_of_persons, dtype: float64
# 102750   NaN
# Name: amount_of_persons, dtype: float64
# 102751    452.947387
# Name: amount_of_persons, dtype: float64
# 102752   NaN
# Name: amount_of_persons, dtype: float64
# 102753    11.947007
# Name: amount_of_persons, dtype: float64
# 102754    406.89081
# Name: amount_of_persons, dtype: float64
# 102755    322.049748
# Name: amount_of_persons, dtype: float64
# 102756    10.908137
# Name: amount_of_persons, dtype: float64
# 102757    1744.782422
# Name: amount_of_persons, dtype: float64
# 102758   NaN
# Name: amount_of_persons, dtype: float64
# 102759    1858.019269
# Name: amount_of_persons, dtype: float64
# 102760    2060.079514
# Name: amount_of_persons, dtype: float64
# 102761    1803.998021
# Name: amount_of_persons, dtype: float64
# 102762    2912.29933
# Name: amount_of_persons, dtype: float64
# 102763    3123.536261
# Name: amount_of_persons, dtype: float64
# 102764   NaN
# Name: amount_of_persons, dtype: float64
# 102765   NaN
# Name: amount_of_persons, dtype: float64
# 102766   NaN
# Name: amount_of_persons, dtype: float64
# 102767   NaN
# Name: amount_of_persons, dtype: float64
# 102768   NaN
# Name: amount_of_persons, dtype: float64
# 102769   NaN
# Name: amount_of_persons, dtype: float64
# 102770   NaN
# Name: amount_of_persons, dtype: float64
# 102771    548.177151
# Name: amount_of_persons, dtype: float64
# 102772    2420.394312
# Name: amount_of_persons, dtype: float64
# 102773    2770.666699
# Name: amount_of_persons, dtype: float64
# 102774    2402.214084
# Name: amount_of_persons, dtype: float64
# 102775    960.608602
# Name: amount_of_persons, dtype: float64
# 102776    2357.888958
# Name: amount_of_persons, dtype: float64
# 102777    7.272091
# Name: amount_of_persons, dtype: float64
# 102778    1364.382801
# Name: amount_of_persons, dtype: float64
# 102779    1224.654766
# Name: amount_of_persons, dtype: float64
# 102780    1160.071671
# Name: amount_of_persons, dtype: float64
# 102781    1481.082549
# Name: amount_of_persons, dtype: float64
# 102782    2712.14368
# Name: amount_of_persons, dtype: float64
# 102783    2753.179051
# Name: amount_of_persons, dtype: float64
# 102784    2266.98782
# Name: amount_of_persons, dtype: float64
# 102785    266.123904
# Name: amount_of_persons, dtype: float64
# 102786    184.918887
# Name: amount_of_persons, dtype: float64
# 102787    1184.311975
# Name: amount_of_persons, dtype: float64
# 102788   NaN
# Name: amount_of_persons, dtype: float64
# 102789    1173.576983
# Name: amount_of_persons, dtype: float64
# 102790    68.56543
# Name: amount_of_persons, dtype: float64
# 102791    1291.315601
# Name: amount_of_persons, dtype: float64
# 102792    2.77032
# Name: amount_of_persons, dtype: float64
# 102793   NaN
# Name: amount_of_persons, dtype: float64
# 102794    543.502235
# Name: amount_of_persons, dtype: float64
# 102795    30.819815
# Name: amount_of_persons, dtype: float64
# 102796    6.925801
# Name: amount_of_persons, dtype: float64
# 102797    1132.022177
# Name: amount_of_persons, dtype: float64
# 102798    1132.887902
# Name: amount_of_persons, dtype: float64
# 102799    25.106029
# Name: amount_of_persons, dtype: float64
# 102800    590.770827
# Name: amount_of_persons, dtype: float64
# 102801    1717.944944
# Name: amount_of_persons, dtype: float64
# 102802    1182.926815
# Name: amount_of_persons, dtype: float64
# 102803    1237.121208
# Name: amount_of_persons, dtype: float64
# 102804    2195.478924
# Name: amount_of_persons, dtype: float64
# 102805    2324.818258
# Name: amount_of_persons, dtype: float64
# 102806    760.452952
# Name: amount_of_persons, dtype: float64
# 102807    86.053078
# Name: amount_of_persons, dtype: float64
# 102808    1619.425424
# Name: amount_of_persons, dtype: float64
# 102809    1362.305061
# Name: amount_of_persons, dtype: float64
# 102810    1934.029935
# Name: amount_of_persons, dtype: float64
# 102811   NaN
# Name: amount_of_persons, dtype: float64
# 102812   NaN
# Name: amount_of_persons, dtype: float64
# 102813    1824.429134
# Name: amount_of_persons, dtype: float64
# 102814    952.817076
# Name: amount_of_persons, dtype: float64
# 102815    8.830396
# Name: amount_of_persons, dtype: float64
# 102816    1186.56286
# Name: amount_of_persons, dtype: float64
# 102817    1460.132
# Name: amount_of_persons, dtype: float64
# 102818    1075.057464
# Name: amount_of_persons, dtype: float64
# 102819    1575.100297
# Name: amount_of_persons, dtype: float64
# 102820    164.660919
# Name: amount_of_persons, dtype: float64
# 102821    520.993382
# Name: amount_of_persons, dtype: float64
# 102822    1165.612312
# Name: amount_of_persons, dtype: float64
# 102823    33.936425
# Name: amount_of_persons, dtype: float64
# 102824    1893.340854
# Name: amount_of_persons, dtype: float64
# 102825    1516.404134
# Name: amount_of_persons, dtype: float64
# 102826    333.477319
# Name: amount_of_persons, dtype: float64
# 102827    1066.400212
# Name: amount_of_persons, dtype: float64
# 102828    938.272893
# Name: amount_of_persons, dtype: float64
# 102829    575.01463
# Name: amount_of_persons, dtype: float64
# 102830    2397.712314
# Name: amount_of_persons, dtype: float64
# 102831    1576.485458
# Name: amount_of_persons, dtype: float64
# 102832    1672.234657
# Name: amount_of_persons, dtype: float64
# 102833    1466.884656
# Name: amount_of_persons, dtype: float64
# 102834    232.187479
# Name: amount_of_persons, dtype: float64
# 102835    1693.531495
# Name: amount_of_persons, dtype: float64
# 102836    752.488281
# Name: amount_of_persons, dtype: float64
# 102837    1992.726099
# Name: amount_of_persons, dtype: float64
# 102838    2108.733266
# Name: amount_of_persons, dtype: float64
# 102839    1006.492034
# Name: amount_of_persons, dtype: float64
# 102840    1930.0476
# Name: amount_of_persons, dtype: float64
# 102841    1277.117708
# Name: amount_of_persons, dtype: float64
# 102842    1522.291065
# Name: amount_of_persons, dtype: float64
# 102843    1596.050846
# Name: amount_of_persons, dtype: float64
# 102844    705.739124
# Name: amount_of_persons, dtype: float64
# 102845   NaN
# Name: amount_of_persons, dtype: float64
# 102846    289.152193
# Name: amount_of_persons, dtype: float64
# 102847   NaN
# Name: amount_of_persons, dtype: float64
# 102848    719.763871
# Name: amount_of_persons, dtype: float64
# 102849    88.477108
# Name: amount_of_persons, dtype: float64
# 102850    797.852278
# Name: amount_of_persons, dtype: float64
# 102851    159.639714
# Name: amount_of_persons, dtype: float64
# 102852    6.406366
# Name: amount_of_persons, dtype: float64
# 102853    43.459401
# Name: amount_of_persons, dtype: float64
# 102854    83.975337
# Name: amount_of_persons, dtype: float64
# 102855    161.024874
# Name: amount_of_persons, dtype: float64
# 102856    2.943465
# Name: amount_of_persons, dtype: float64
# 102857    34.80215
# Name: amount_of_persons, dtype: float64
# 102858    2.77032
# Name: amount_of_persons, dtype: float64
# 102859    30.64667
# Name: amount_of_persons, dtype: float64
# 102860    6.233221
# Name: amount_of_persons, dtype: float64
# 102861    10.215557
# Name: amount_of_persons, dtype: float64
# 102862    3.462901
# Name: amount_of_persons, dtype: float64
# 102863    3.289755
# Name: amount_of_persons, dtype: float64
# 102864   NaN
# Name: amount_of_persons, dtype: float64
# 102865    203.791695
# Name: amount_of_persons, dtype: float64
# 102866    914.03259
# Name: amount_of_persons, dtype: float64
# 102867    10.388702
# Name: amount_of_persons, dtype: float64
# 102868    11.773862
# Name: amount_of_persons, dtype: float64
# 102869    4.501771
# Name: amount_of_persons, dtype: float64
# 102870    211.236931
# Name: amount_of_persons, dtype: float64
# 102871    1.558305
# Name: amount_of_persons, dtype: float64
# 102872    7.964671
# Name: amount_of_persons, dtype: float64
# 102873    18.526518
# Name: amount_of_persons, dtype: float64
# 102874    2009.867457
# Name: amount_of_persons, dtype: float64
# 102875    1917.234868
# Name: amount_of_persons, dtype: float64
# 102876    1288.372135
# Name: amount_of_persons, dtype: float64
# 102877    3070.553883
# Name: amount_of_persons, dtype: float64
# 102878    593.021713
# Name: amount_of_persons, dtype: float64
# 102879    1411.478248
# Name: amount_of_persons, dtype: float64
# 102880    2741.75148
# Name: amount_of_persons, dtype: float64
# 102881    1664.962566
# Name: amount_of_persons, dtype: float64
# 102882    319.972007
# Name: amount_of_persons, dtype: float64
# 102883    1797.591655
# Name: amount_of_persons, dtype: float64
# 102884   NaN
# Name: amount_of_persons, dtype: float64
# 102885    1243.873864
# Name: amount_of_persons, dtype: float64
# 102886    1619.425424
# Name: amount_of_persons, dtype: float64
# 102887    2793.868132
# Name: amount_of_persons, dtype: float64
# 102888    2162.927659
# Name: amount_of_persons, dtype: float64
# 102889    834.212733
# Name: amount_of_persons, dtype: float64
# 102890    2614.143596
# Name: amount_of_persons, dtype: float64
# 102891    1270.711343
# Name: amount_of_persons, dtype: float64
# 102892    1581.333518
# Name: amount_of_persons, dtype: float64
# 102893    2526.012778
# Name: amount_of_persons, dtype: float64
# 102894    653.103036
# Name: amount_of_persons, dtype: float64
# 102895    733.269183
# Name: amount_of_persons, dtype: float64
# 102896    413.816611
# Name: amount_of_persons, dtype: float64
# 102897    4141.629011
# Name: amount_of_persons, dtype: float64
# 102898    2270.970155
# Name: amount_of_persons, dtype: float64
# 102899    723.053627
# Name: amount_of_persons, dtype: float64
# 102900    5.713786
# Name: amount_of_persons, dtype: float64
# 102901    8.484106
# Name: amount_of_persons, dtype: float64
# 102902    1469.135542
# Name: amount_of_persons, dtype: float64
# 102903    2038.436386
# Name: amount_of_persons, dtype: float64
# 102904    698.120743
# Name: amount_of_persons, dtype: float64
# 102905    1465.672641
# Name: amount_of_persons, dtype: float64
# 102906    1362.305061
# Name: amount_of_persons, dtype: float64
# 102907    1777.333687
# Name: amount_of_persons, dtype: float64
# 102908    760.279807
# Name: amount_of_persons, dtype: float64
# 102909    1705.824792
# Name: amount_of_persons, dtype: float64
# 102910    1666.694016
# Name: amount_of_persons, dtype: float64
# 102911    917.322345
# Name: amount_of_persons, dtype: float64
# 102912    832.308138
# Name: amount_of_persons, dtype: float64
# 102913    887.021966
# Name: amount_of_persons, dtype: float64
# 102914    14.371037
# Name: amount_of_persons, dtype: float64
# 102434    3005.278208
# Name: amount_of_persons, dtype: float64
# 102435    1381.177869
# Name: amount_of_persons, dtype: float64
# 102436    4368.96843
# Name: amount_of_persons, dtype: float64
# 102437    1139.467413
# Name: amount_of_persons, dtype: float64
# 102438    1285.42867
# Name: amount_of_persons, dtype: float64
# 102439    2.597175
# Name: amount_of_persons, dtype: float64
# 102440    1903.556411
# Name: amount_of_persons, dtype: float64
# 102441    1503.591402
# Name: amount_of_persons, dtype: float64
# 102442    2797.504178
# Name: amount_of_persons, dtype: float64
# 102443    1698.379556
# Name: amount_of_persons, dtype: float64
# 102444    2121.545998
# Name: amount_of_persons, dtype: float64
# 102445    1041.986764
# Name: amount_of_persons, dtype: float64
# 102446    873.689799
# Name: amount_of_persons, dtype: float64
# 102447    3282.656539
# Name: amount_of_persons, dtype: float64
# 102448    2303.86771
# Name: amount_of_persons, dtype: float64
# 102449    2188.553123
# Name: amount_of_persons, dtype: float64
# 102450    2217.814632
# Name: amount_of_persons, dtype: float64
# 102451    1767.810711
# Name: amount_of_persons, dtype: float64
# 102452   NaN
# Name: amount_of_persons, dtype: float64
# 102453    1903.902701
# Name: amount_of_persons, dtype: float64
# 102454    2344.729936
# Name: amount_of_persons, dtype: float64
# 102455    1416.326309
# Name: amount_of_persons, dtype: float64
# 102456   NaN
# Name: amount_of_persons, dtype: float64
# 102457    2062.676689
# Name: amount_of_persons, dtype: float64
# 102458    713.18436
# Name: amount_of_persons, dtype: float64
# 102459   NaN
# Name: amount_of_persons, dtype: float64
# 102460    1915.849708
# Name: amount_of_persons, dtype: float64
# 102461    3541.162063
# Name: amount_of_persons, dtype: float64
# 102462    4755.428127
# Name: amount_of_persons, dtype: float64
# 102463    2535.535754
# Name: amount_of_persons, dtype: float64
# 102464    3095.140477
# Name: amount_of_persons, dtype: float64
# 102465    3843.473277
# Name: amount_of_persons, dtype: float64
# 102466    1351.223779
# Name: amount_of_persons, dtype: float64
# 102467    2166.909995
# Name: amount_of_persons, dtype: float64
# 102468    2833.345198
# Name: amount_of_persons, dtype: float64
# 102469    3940.953927
# Name: amount_of_persons, dtype: float64
# 102470    3369.748487
# Name: amount_of_persons, dtype: float64
# 102471   NaN
# Name: amount_of_persons, dtype: float64
# 102472   NaN
# Name: amount_of_persons, dtype: float64
# 102473    4787.633101
# Name: amount_of_persons, dtype: float64
# 102474    4466.795369
# Name: amount_of_persons, dtype: float64
# 102475    4635.784914
# Name: amount_of_persons, dtype: float64
# 102476   NaN
# Name: amount_of_persons, dtype: float64
# 102477   NaN
# Name: amount_of_persons, dtype: float64
# 102478    3971.773741
# Name: amount_of_persons, dtype: float64
# 102479   NaN
# Name: amount_of_persons, dtype: float64
# 102480   NaN
# Name: amount_of_persons, dtype: float64
# 102481   NaN
# Name: amount_of_persons, dtype: float64
# 102482    3842.607552
# Name: amount_of_persons, dtype: float64
# 102483    4632.495159
# Name: amount_of_persons, dtype: float64
# 102484   NaN
# Name: amount_of_persons, dtype: float64
# 102485   NaN
# Name: amount_of_persons, dtype: float64
# 102486    3182.578715
# Name: amount_of_persons, dtype: float64
# 102487   NaN
# Name: amount_of_persons, dtype: float64
# 102488    3529.041911
# Name: amount_of_persons, dtype: float64
# 102489    1952.556453
# Name: amount_of_persons, dtype: float64
# 102490    3479.176143
# Name: amount_of_persons, dtype: float64
# 102491    1183.44625
# Name: amount_of_persons, dtype: float64
# 102492    2725.648992
# Name: amount_of_persons, dtype: float64
# 102493    2064.75443
# Name: amount_of_persons, dtype: float64
# 102494    957.318846
# Name: amount_of_persons, dtype: float64
# 102495   NaN
# Name: amount_of_persons, dtype: float64
# 102496    86.572513
# Name: amount_of_persons, dtype: float64
# 102497    3347.066489
# Name: amount_of_persons, dtype: float64
# 102498    3066.052112
# Name: amount_of_persons, dtype: float64
# 102499    1476.753923
# Name: amount_of_persons, dtype: float64
# 102500    3983.547603
# Name: amount_of_persons, dtype: float64
# 102501    3227.423276
# Name: amount_of_persons, dtype: float64
# 102502    3067.956708
# Name: amount_of_persons, dtype: float64
# 102503    2887.020156
# Name: amount_of_persons, dtype: float64
# 102504    3.636046
# Name: amount_of_persons, dtype: float64
# 102505    3.982336
# Name: amount_of_persons, dtype: float64
# 102506    0.173145
# Name: amount_of_persons, dtype: float64
# 102507    1.212015
# Name: amount_of_persons, dtype: float64
# 102508    2.250885
# Name: amount_of_persons, dtype: float64
# 102509    2.07774
# Name: amount_of_persons, dtype: float64
# 102510    0.173145
# Name: amount_of_persons, dtype: float64
# 102511    4.501771
# Name: amount_of_persons, dtype: float64
# 102512    806.855819
# Name: amount_of_persons, dtype: float64
# 102513   NaN
# Name: amount_of_persons, dtype: float64
# 102514    3963.11649
# Name: amount_of_persons, dtype: float64
# 102515    4807.025344
# Name: amount_of_persons, dtype: float64
# 102516   NaN
# Name: amount_of_persons, dtype: float64
# 102517    3820.271844
# Name: amount_of_persons, dtype: float64
# 102518    3922.427409
# Name: amount_of_persons, dtype: float64
# 102519    2877.324035
# Name: amount_of_persons, dtype: float64
# 102520   NaN
# Name: amount_of_persons, dtype: float64
# 102521    2.597175
# Name: amount_of_persons, dtype: float64
# 102522    3812.653463
# Name: amount_of_persons, dtype: float64
# 102523   NaN
# Name: amount_of_persons, dtype: float64
# 102524    3549.819314
# Name: amount_of_persons, dtype: float64
# 102525    6197.553045
# Name: amount_of_persons, dtype: float64
# 102526    5047.523785
# Name: amount_of_persons, dtype: float64
# 102527    4734.477579
# Name: amount_of_persons, dtype: float64
# 102528    3726.77353
# Name: amount_of_persons, dtype: float64
# 102529    10.042411
# Name: amount_of_persons, dtype: float64
# 102530    87.611383
# Name: amount_of_persons, dtype: float64
# 102531    3143.794229
# Name: amount_of_persons, dtype: float64
# 102532    3656.13036
# Name: amount_of_persons, dtype: float64
# 102533    5002.332933
# Name: amount_of_persons, dtype: float64
# 102534    3357.282045
# Name: amount_of_persons, dtype: float64
# 102535    3703.745242
# Name: amount_of_persons, dtype: float64
# 102536    4920.954771
# Name: amount_of_persons, dtype: float64
# 102537    4211.579601
# Name: amount_of_persons, dtype: float64
# 102538    5387.40747
# Name: amount_of_persons, dtype: float64
# 102539    4396.671634
# Name: amount_of_persons, dtype: float64
# 102540    5164.223532
# Name: amount_of_persons, dtype: float64
# 102541    4419.873067
# Name: amount_of_persons, dtype: float64
# 102542    2658.295577
# Name: amount_of_persons, dtype: float64
# 102543    5932.8143
# Name: amount_of_persons, dtype: float64
# 102544    5027.438962
# Name: amount_of_persons, dtype: float64
# 102545    3774.388412
# Name: amount_of_persons, dtype: float64
# 102546    1294.951646
# Name: amount_of_persons, dtype: float64
# 102547    1716.386638
# Name: amount_of_persons, dtype: float64
# 102548    153.233348
# Name: amount_of_persons, dtype: float64
# 102549    24.759739
# Name: amount_of_persons, dtype: float64
# 102550    887.195111
# Name: amount_of_persons, dtype: float64
# 102551    2936.539633
# Name: amount_of_persons, dtype: float64
# 102552    3422.038285
# Name: amount_of_persons, dtype: float64
# 102553    4056.268514
# Name: amount_of_persons, dtype: float64
# 102554    3841.568682
# Name: amount_of_persons, dtype: float64
# 102555    4242.053126
# Name: amount_of_persons, dtype: float64
# 102556    2403.77239
# Name: amount_of_persons, dtype: float64
# 102557    4673.011095
# Name: amount_of_persons, dtype: float64
# 102558    2569.299034
# Name: amount_of_persons, dtype: float64
# 102559    2563.412103
# Name: amount_of_persons, dtype: float64
# 102560    3056.009701
# Name: amount_of_persons, dtype: float64
# 102561    2203.789885
# Name: amount_of_persons, dtype: float64
# 102562    3641.413032
# Name: amount_of_persons, dtype: float64
# 102563    4502.982679
# Name: amount_of_persons, dtype: float64
# 102564    4651.367966
# Name: amount_of_persons, dtype: float64
# 102565    4707.29381
# Name: amount_of_persons, dtype: float64
# 102566    4992.463667
# Name: amount_of_persons, dtype: float64
# 102567   NaN
# Name: amount_of_persons, dtype: float64
# 102568    3509.822813
# Name: amount_of_persons, dtype: float64
# 102569    4577.608185
# Name: amount_of_persons, dtype: float64
# 102570    4162.233269
# Name: amount_of_persons, dtype: float64
# 102571    5535.619612
# Name: amount_of_persons, dtype: float64
# 102572    4192.014214
# Name: amount_of_persons, dtype: float64
# 102573    4335.55144
# Name: amount_of_persons, dtype: float64
# 102574    3228.981581
# Name: amount_of_persons, dtype: float64
# 102575    4034.971675
# Name: amount_of_persons, dtype: float64
# 102576   NaN
# Name: amount_of_persons, dtype: float64
# 102577    4477.010926
# Name: amount_of_persons, dtype: float64
# 102578   NaN
# Name: amount_of_persons, dtype: float64
# 102579    10.042411
# Name: amount_of_persons, dtype: float64
# 102580   NaN
# Name: amount_of_persons, dtype: float64
# 102581    7.098946
# Name: amount_of_persons, dtype: float64
# 102582    4.155481
# Name: amount_of_persons, dtype: float64
# 102583    149.424157
# Name: amount_of_persons, dtype: float64
# 102584    0.519435
# Name: amount_of_persons, dtype: float64
# 102585   NaN
# Name: amount_of_persons, dtype: float64
# 102586    1589.64448
# Name: amount_of_persons, dtype: float64
# 102587    1962.07943
# Name: amount_of_persons, dtype: float64
# 102588    1466.365221
# Name: amount_of_persons, dtype: float64
# 102589    1609.729303
# Name: amount_of_persons, dtype: float64
# 102590    1857.672979
# Name: amount_of_persons, dtype: float64
# 102591    2912.29933
# Name: amount_of_persons, dtype: float64
# 102592    13.678457
# Name: amount_of_persons, dtype: float64
# 102593    2186.821673
# Name: amount_of_persons, dtype: float64
# 102594    2019.563578
# Name: amount_of_persons, dtype: float64
# 102595    1722.273569
# Name: amount_of_persons, dtype: float64
# 102596    2864.165013
# Name: amount_of_persons, dtype: float64
# 102597    2585.920957
# Name: amount_of_persons, dtype: float64
# 102598    436.671754
# Name: amount_of_persons, dtype: float64
# 102599    2.77032
# Name: amount_of_persons, dtype: float64
# 102600    1445.760963
# Name: amount_of_persons, dtype: float64
# 102601    66.660835
# Name: amount_of_persons, dtype: float64
# 102602    57.484148
# Name: amount_of_persons, dtype: float64
# 102603    5.713786
# Name: amount_of_persons, dtype: float64
# 102604    2721.493512
# Name: amount_of_persons, dtype: float64
# 102605    2586.959827
# Name: amount_of_persons, dtype: float64
# 102606    1718.464379
# Name: amount_of_persons, dtype: float64
# 102607    815.85936
# Name: amount_of_persons, dtype: float64
# 102608    1429.485331
# Name: amount_of_persons, dtype: float64
# 102609    2348.539127
# Name: amount_of_persons, dtype: float64
# 102610    2569.125889
# Name: amount_of_persons, dtype: float64
# 102611    2391.305948
# Name: amount_of_persons, dtype: float64
# 102612    3005.624499
# Name: amount_of_persons, dtype: float64
# 102613    2249.846462
# Name: amount_of_persons, dtype: float64
# 102614    193.056703
# Name: amount_of_persons, dtype: float64
# 102615    2081.722642
# Name: amount_of_persons, dtype: float64
# 102616    1561.594985
# Name: amount_of_persons, dtype: float64
# 102617    1613.711638
# Name: amount_of_persons, dtype: float64
# 102618    1152.107
# Name: amount_of_persons, dtype: float64
# 102619    868.668593
# Name: amount_of_persons, dtype: float64
# 102620    1879.662397
# Name: amount_of_persons, dtype: float64
# 102621    3094.794187
# Name: amount_of_persons, dtype: float64
# 102622    2479.436766
# Name: amount_of_persons, dtype: float64
# 102623    603.237269
# Name: amount_of_persons, dtype: float64
# 102624    533.632969
# Name: amount_of_persons, dtype: float64
# 102625    1403.859867
# Name: amount_of_persons, dtype: float64
# 102626    1082.84899
# Name: amount_of_persons, dtype: float64
# 102627    1872.390306
# Name: amount_of_persons, dtype: float64
# 102628    1575.273442
# Name: amount_of_persons, dtype: float64
# 102629    1582.718679
# Name: amount_of_persons, dtype: float64
# 102630    1845.552827
# Name: amount_of_persons, dtype: float64
# 102631    246.039081
# Name: amount_of_persons, dtype: float64
# 102632    1675.351267
# Name: amount_of_persons, dtype: float64
# 102633    23.720869
# Name: amount_of_persons, dtype: float64
# 102634    1524.88824
# Name: amount_of_persons, dtype: float64
# 102635    22.335708
# Name: amount_of_persons, dtype: float64
# 102636    56.964713
# Name: amount_of_persons, dtype: float64
# 102637    1569.040222
# Name: amount_of_persons, dtype: float64
# 102638    1255.994015
# Name: amount_of_persons, dtype: float64
# 102639    2287.245788
# Name: amount_of_persons, dtype: float64
# 102640    1869.446841
# Name: amount_of_persons, dtype: float64
# 102641    1587.047304
# Name: amount_of_persons, dtype: float64
# 102642    232.014334
# Name: amount_of_persons, dtype: float64
# 102643    1576.485458
# Name: amount_of_persons, dtype: float64
# 102644    2098.690855
# Name: amount_of_persons, dtype: float64
# 102645    1697.860121
# Name: amount_of_persons, dtype: float64
# 102646    503.332589
# Name: amount_of_persons, dtype: float64
# 102647    106.137901
# Name: amount_of_persons, dtype: float64
# 102648   NaN
# Name: amount_of_persons, dtype: float64
# 102649    63.890514
# Name: amount_of_persons, dtype: float64
# 102650    1894.033434
# Name: amount_of_persons, dtype: float64
# 102651    604.968719
# Name: amount_of_persons, dtype: float64
# 102652    3851.611093
# Name: amount_of_persons, dtype: float64
# 102653    3509.822813
# Name: amount_of_persons, dtype: float64
# 102654    3992.724289
# Name: amount_of_persons, dtype: float64
# 102655    5575.442968
# Name: amount_of_persons, dtype: float64
# 102656    3930.04579
# Name: amount_of_persons, dtype: float64
# 102657    4243.784576
# Name: amount_of_persons, dtype: float64
# 102658    4835.940564
# Name: amount_of_persons, dtype: float64
# 102659    3406.108943
# Name: amount_of_persons, dtype: float64
# 102660    4165.69617
# Name: amount_of_persons, dtype: float64
# 102661    3955.844399
# Name: amount_of_persons, dtype: float64
# 102662    4141.629011
# Name: amount_of_persons, dtype: float64
# 102663    3991.858564
# Name: amount_of_persons, dtype: float64
# 102664    3167.515097
# Name: amount_of_persons, dtype: float64
# 102665    3968.310841
# Name: amount_of_persons, dtype: float64
# 102666    4505.926145
# Name: amount_of_persons, dtype: float64
# 102667    3311.918049
# Name: amount_of_persons, dtype: float64
# 102668    4194.438244
# Name: amount_of_persons, dtype: float64
# 102669    141.805776
# Name: amount_of_persons, dtype: float64
# 102670    4195.477114
# Name: amount_of_persons, dtype: float64
# 102671    1352.95523
# Name: amount_of_persons, dtype: float64
# 102672    2075.489421
# Name: amount_of_persons, dtype: float64
# 102673    3267.592922
# Name: amount_of_persons, dtype: float64
# 102674    1429.658476
# Name: amount_of_persons, dtype: float64
# 102675   NaN
# Name: amount_of_persons, dtype: float64
# 102676    1689.722304
# Name: amount_of_persons, dtype: float64
# 102677    1231.926857
# Name: amount_of_persons, dtype: float64
# 102678    2410.525046
# Name: amount_of_persons, dtype: float64
# 102679    2603.408604
# Name: amount_of_persons, dtype: float64
# 102680    1339.276773
# Name: amount_of_persons, dtype: float64
# 102681    2866.935333
# Name: amount_of_persons, dtype: float64
# 102682    2464.892584
# Name: amount_of_persons, dtype: float64
# 102683    10.908137
# Name: amount_of_persons, dtype: float64
# 102684    3.462901
# Name: amount_of_persons, dtype: float64
# 102685    4096.957595
# Name: amount_of_persons, dtype: float64
# 102686    3413.727324
# Name: amount_of_persons, dtype: float64
# 102687    1702.881326
# Name: amount_of_persons, dtype: float64
# 102688    3561.07374
# Name: amount_of_persons, dtype: float64
# 102689    1916.022853
# Name: amount_of_persons, dtype: float64
# 102690    312.180481
# Name: amount_of_persons, dtype: float64
# 102691    3612.151523
# Name: amount_of_persons, dtype: float64
# 102692    711.626055
# Name: amount_of_persons, dtype: float64
# 102693    1484.026014
# Name: amount_of_persons, dtype: float64
# 102694    141.459486
# Name: amount_of_persons, dtype: float64
# 102695    1664.962566
# Name: amount_of_persons, dtype: float64
# 102696    2810.31691
# Name: amount_of_persons, dtype: float64
# 102697    3024.151016
# Name: amount_of_persons, dtype: float64
# 102698    3751.706414
# Name: amount_of_persons, dtype: float64
# 102699    3030.730527
# Name: amount_of_persons, dtype: float64
# 102700    3408.706118
# Name: amount_of_persons, dtype: float64
# 102701    2973.592669
# Name: amount_of_persons, dtype: float64
# 102702    1992.552954
# Name: amount_of_persons, dtype: float64
# 102703    639.944014
# Name: amount_of_persons, dtype: float64
# 102704    3364.900427
# Name: amount_of_persons, dtype: float64
# 102705    3810.402577
# Name: amount_of_persons, dtype: float64
# 102706    2582.631201
# Name: amount_of_persons, dtype: float64
# 102707    2468.009194
# Name: amount_of_persons, dtype: float64
# 102708    1460.478291
# Name: amount_of_persons, dtype: float64
# 102709    3749.109238
# Name: amount_of_persons, dtype: float64
# 102710    29.261509
# Name: amount_of_persons, dtype: float64
# 102711    948.14216
# Name: amount_of_persons, dtype: float64
# 102712   NaN
# Name: amount_of_persons, dtype: float64
# 102713    1795.34077
# Name: amount_of_persons, dtype: float64
# 102714    1322.481705
# Name: amount_of_persons, dtype: float64
# 102715    1028.481452
# Name: amount_of_persons, dtype: float64
# 102716    15.063617
# Name: amount_of_persons, dtype: float64
# 102717    706.085414
# Name: amount_of_persons, dtype: float64
# 102718    20.777403
# Name: amount_of_persons, dtype: float64
# 102719    1041.640474
# Name: amount_of_persons, dtype: float64
# 102720    1971.775551
# Name: amount_of_persons, dtype: float64
# 102721    1140.333138
# Name: amount_of_persons, dtype: float64
# 102722    4.155481
# Name: amount_of_persons, dtype: float64
# 102723    3082.50089
# Name: amount_of_persons, dtype: float64
# 102724    3121.631666
# Name: amount_of_persons, dtype: float64
# 102725    1360.054176
# Name: amount_of_persons, dtype: float64
# 102726    3144.659954
# Name: amount_of_persons, dtype: float64
# 102727    93.325169
# Name: amount_of_persons, dtype: float64
# 102728    4145.438202
# Name: amount_of_persons, dtype: float64
# 102729    4391.130993
# Name: amount_of_persons, dtype: float64
# 102730    3839.837232
# Name: amount_of_persons, dtype: float64
# 102731    3795.512105
# Name: amount_of_persons, dtype: float64
# 102732    1579.428923
# Name: amount_of_persons, dtype: float64
# 102733    4104.402831
# Name: amount_of_persons, dtype: float64
# 102734    4561.332553
# Name: amount_of_persons, dtype: float64
# 102735    4074.448741
# Name: amount_of_persons, dtype: float64
# 102736    5528.520666
# Name: amount_of_persons, dtype: float64
# 102737    4504.540985
# Name: amount_of_persons, dtype: float64
# 102738    4057.307384
# Name: amount_of_persons, dtype: float64
# 102739    4520.470327
# Name: amount_of_persons, dtype: float64
# 102740    972.728754
# Name: amount_of_persons, dtype: float64
# 102741    6.925801
# Name: amount_of_persons, dtype: float64
# 102742    1151.76071
# Name: amount_of_persons, dtype: float64
# 102743    1618.559699
# Name: amount_of_persons, dtype: float64
# 102744    3200.066362
# Name: amount_of_persons, dtype: float64
# 102745    3214.610544
# Name: amount_of_persons, dtype: float64
# 102746    3534.582552
# Name: amount_of_persons, dtype: float64
# 102747    4142.494736
# Name: amount_of_persons, dtype: float64
# 102748    2363.949034
# Name: amount_of_persons, dtype: float64
# 102749    3007.009659
# Name: amount_of_persons, dtype: float64
# 102750   NaN
# Name: amount_of_persons, dtype: float64
# 102751    452.947387
# Name: amount_of_persons, dtype: float64
# 102752   NaN
# Name: amount_of_persons, dtype: float64
# 102753    11.947007
# Name: amount_of_persons, dtype: float64
# 102754    406.89081
# Name: amount_of_persons, dtype: float64
# 102755    322.049748
# Name: amount_of_persons, dtype: float64
# 102756    10.908137
# Name: amount_of_persons, dtype: float64
# 102757    1744.782422
# Name: amount_of_persons, dtype: float64
# 102758   NaN
# Name: amount_of_persons, dtype: float64
# 102759    1858.019269
# Name: amount_of_persons, dtype: float64
# 102760    2060.079514
# Name: amount_of_persons, dtype: float64
# 102761    1803.998021
# Name: amount_of_persons, dtype: float64
# 102762    2912.29933
# Name: amount_of_persons, dtype: float64
# 102763    3123.536261
# Name: amount_of_persons, dtype: float64
# 102764   NaN
# Name: amount_of_persons, dtype: float64
# 102765   NaN
# Name: amount_of_persons, dtype: float64
# 102766   NaN
# Name: amount_of_persons, dtype: float64
# 102767   NaN
# Name: amount_of_persons, dtype: float64
# 102768   NaN
# Name: amount_of_persons, dtype: float64
# 102769   NaN
# Name: amount_of_persons, dtype: float64
# 102770   NaN
# Name: amount_of_persons, dtype: float64
# 102771    548.177151
# Name: amount_of_persons, dtype: float64
# 102772    2420.394312
# Name: amount_of_persons, dtype: float64
# 102773    2770.666699
# Name: amount_of_persons, dtype: float64
# 102774    2402.214084
# Name: amount_of_persons, dtype: float64
# 102775    960.608602
# Name: amount_of_persons, dtype: float64
# 102776    2357.888958
# Name: amount_of_persons, dtype: float64
# 102777    7.272091
# Name: amount_of_persons, dtype: float64
# 102778    1364.382801
# Name: amount_of_persons, dtype: float64
# 102779    1224.654766
# Name: amount_of_persons, dtype: float64
# 102780    1160.071671
# Name: amount_of_persons, dtype: float64
# 102781    1481.082549
# Name: amount_of_persons, dtype: float64
# 102782    2712.14368
# Name: amount_of_persons, dtype: float64
# 102783    2753.179051
# Name: amount_of_persons, dtype: float64
# 102784    2266.98782
# Name: amount_of_persons, dtype: float64
# 102785    266.123904
# Name: amount_of_persons, dtype: float64
# 102786    184.918887
# Name: amount_of_persons, dtype: float64
# 102787    1184.311975
# Name: amount_of_persons, dtype: float64
# 102788   NaN
# Name: amount_of_persons, dtype: float64
# 102789    1173.576983
# Name: amount_of_persons, dtype: float64
# 102790    68.56543
# Name: amount_of_persons, dtype: float64
# 102791    1291.315601
# Name: amount_of_persons, dtype: float64
# 102792    2.77032
# Name: amount_of_persons, dtype: float64
# 102793   NaN
# Name: amount_of_persons, dtype: float64
# 102794    543.502235
# Name: amount_of_persons, dtype: float64
# 102795    30.819815
# Name: amount_of_persons, dtype: float64
# 102796    6.925801
# Name: amount_of_persons, dtype: float64
# 102797    1132.022177
# Name: amount_of_persons, dtype: float64
# 102798    1132.887902
# Name: amount_of_persons, dtype: float64
# 102799    25.106029
# Name: amount_of_persons, dtype: float64
# 102800    590.770827
# Name: amount_of_persons, dtype: float64
# 102801    1717.944944
# Name: amount_of_persons, dtype: float64
# 102802    1182.926815
# Name: amount_of_persons, dtype: float64
# 102803    1237.121208
# Name: amount_of_persons, dtype: float64
# 102804    2195.478924
# Name: amount_of_persons, dtype: float64
# 102805    2324.818258
# Name: amount_of_persons, dtype: float64
# 102806    760.452952
# Name: amount_of_persons, dtype: float64
# 102807    86.053078
# Name: amount_of_persons, dtype: float64
# 102808    1619.425424
# Name: amount_of_persons, dtype: float64
# 102809    1362.305061
# Name: amount_of_persons, dtype: float64
# 102810    1934.029935
# Name: amount_of_persons, dtype: float64
# 102811   NaN
# Name: amount_of_persons, dtype: float64
# 102812   NaN
# Name: amount_of_persons, dtype: float64
# 102813    1824.429134
# Name: amount_of_persons, dtype: float64
# 102814    952.817076
# Name: amount_of_persons, dtype: float64
# 102815    8.830396
# Name: amount_of_persons, dtype: float64
# 102816    1186.56286
# Name: amount_of_persons, dtype: float64
# 102817    1460.132
# Name: amount_of_persons, dtype: float64
# 102818    1075.057464
# Name: amount_of_persons, dtype: float64
# 102819    1575.100297
# Name: amount_of_persons, dtype: float64
# 102820    164.660919
# Name: amount_of_persons, dtype: float64
# 102821    520.993382
# Name: amount_of_persons, dtype: float64
# 102822    1165.612312
# Name: amount_of_persons, dtype: float64
# 102823    33.936425
# Name: amount_of_persons, dtype: float64
# 102824    1893.340854
# Name: amount_of_persons, dtype: float64
# 102825    1516.404134
# Name: amount_of_persons, dtype: float64
# 102826    333.477319
# Name: amount_of_persons, dtype: float64
# 102827    1066.400212
# Name: amount_of_persons, dtype: float64
# 102828    938.272893
# Name: amount_of_persons, dtype: float64
# 102829    575.01463
# Name: amount_of_persons, dtype: float64
# 102830    2397.712314
# Name: amount_of_persons, dtype: float64
# 102831    1576.485458
# Name: amount_of_persons, dtype: float64
# 102832    1672.234657
# Name: amount_of_persons, dtype: float64
# 102833    1466.884656
# Name: amount_of_persons, dtype: float64
# 102834    232.187479
# Name: amount_of_persons, dtype: float64
# 102835    1693.531495
# Name: amount_of_persons, dtype: float64
# 102836    752.488281
# Name: amount_of_persons, dtype: float64
# 102837    1992.726099
# Name: amount_of_persons, dtype: float64
# 102838    2108.733266
# Name: amount_of_persons, dtype: float64
# 102839    1006.492034
# Name: amount_of_persons, dtype: float64
# 102840    1930.0476
# Name: amount_of_persons, dtype: float64
# 102841    1277.117708
# Name: amount_of_persons, dtype: float64
# 102842    1522.291065
# Name: amount_of_persons, dtype: float64
# 102843    1596.050846
# Name: amount_of_persons, dtype: float64
# 102844    705.739124
# Name: amount_of_persons, dtype: float64
# 102845   NaN
# Name: amount_of_persons, dtype: float64
# 102846    289.152193
# Name: amount_of_persons, dtype: float64
# 102847   NaN
# Name: amount_of_persons, dtype: float64
# 102848    719.763871
# Name: amount_of_persons, dtype: float64
# 102849    88.477108
# Name: amount_of_persons, dtype: float64
# 102850    797.852278
# Name: amount_of_persons, dtype: float64
# 102851    159.639714
# Name: amount_of_persons, dtype: float64
# 102852    6.406366
# Name: amount_of_persons, dtype: float64
# 102853    43.459401
# Name: amount_of_persons, dtype: float64
# 102854    83.975337
# Name: amount_of_persons, dtype: float64
# 102855    161.024874
# Name: amount_of_persons, dtype: float64
# 102856    2.943465
# Name: amount_of_persons, dtype: float64
# 102857    34.80215
# Name: amount_of_persons, dtype: float64
# 102858    2.77032
# Name: amount_of_persons, dtype: float64
# 102859    30.64667
# Name: amount_of_persons, dtype: float64
# 102860    6.233221
# Name: amount_of_persons, dtype: float64
# 102861    10.215557
# Name: amount_of_persons, dtype: float64
# 102862    3.462901
# Name: amount_of_persons, dtype: float64
# 102863    3.289755
# Name: amount_of_persons, dtype: float64
# 102864   NaN
# Name: amount_of_persons, dtype: float64
# 102865    203.791695
# Name: amount_of_persons, dtype: float64
# 102866    914.03259
# Name: amount_of_persons, dtype: float64
# 102867    10.388702
# Name: amount_of_persons, dtype: float64
# 102868    11.773862
# Name: amount_of_persons, dtype: float64
# 102869    4.501771
# Name: amount_of_persons, dtype: float64
# 102870    211.236931
# Name: amount_of_persons, dtype: float64
# 102871    1.558305
# Name: amount_of_persons, dtype: float64
# 102872    7.964671
# Name: amount_of_persons, dtype: float64
# 102873    18.526518
# Name: amount_of_persons, dtype: float64
# 102874    2009.867457
# Name: amount_of_persons, dtype: float64
# 102875    1917.234868
# Name: amount_of_persons, dtype: float64
# 102876    1288.372135
# Name: amount_of_persons, dtype: float64
# 102877    3070.553883
# Name: amount_of_persons, dtype: float64
# 102878    593.021713
# Name: amount_of_persons, dtype: float64
# 102879    1411.478248
# Name: amount_of_persons, dtype: float64
# 102880    2741.75148
# Name: amount_of_persons, dtype: float64
# 102881    1664.962566
# Name: amount_of_persons, dtype: float64
# 102882    319.972007
# Name: amount_of_persons, dtype: float64
# 102883    1797.591655
# Name: amount_of_persons, dtype: float64
# 102884   NaN
# Name: amount_of_persons, dtype: float64
# 102885    1243.873864
# Name: amount_of_persons, dtype: float64
# 102886    1619.425424
# Name: amount_of_persons, dtype: float64
# 102887    2793.868132
# Name: amount_of_persons, dtype: float64
# 102888    2162.927659
# Name: amount_of_persons, dtype: float64
# 102889    834.212733
# Name: amount_of_persons, dtype: float64
# 102890    2614.143596
# Name: amount_of_persons, dtype: float64
# 102891    1270.711343
# Name: amount_of_persons, dtype: float64
# 102892    1581.333518
# Name: amount_of_persons, dtype: float64
# 102893    2526.012778
# Name: amount_of_persons, dtype: float64
# 102894    653.103036
# Name: amount_of_persons, dtype: float64
# 102895    733.269183
# Name: amount_of_persons, dtype: float64
# 102896    413.816611
# Name: amount_of_persons, dtype: float64
# 102897    4141.629011
# Name: amount_of_persons, dtype: float64
# 102898    2270.970155
# Name: amount_of_persons, dtype: float64
# 102899    723.053627
# Name: amount_of_persons, dtype: float64
# 102900    5.713786
# Name: amount_of_persons, dtype: float64
# 102901    8.484106
# Name: amount_of_persons, dtype: float64
# 102902    1469.135542
# Name: amount_of_persons, dtype: float64
# 102903    2038.436386
# Name: amount_of_persons, dtype: float64
# 102904    698.120743
# Name: amount_of_persons, dtype: float64
# 102905    1465.672641
# Name: amount_of_persons, dtype: float64
# 102906    1362.305061
# Name: amount_of_persons, dtype: float64
# 102907    1777.333687
# Name: amount_of_persons, dtype: float64
# 102908    760.279807
# Name: amount_of_persons, dtype: float64
# 102909    1705.824792
# Name: amount_of_persons, dtype: float64
# 102910    1666.694016
# Name: amount_of_persons, dtype: float64
# 102911    917.322345
# Name: amount_of_persons, dtype: float64
# 102912    832.308138
# Name: amount_of_persons, dtype: float64
# 102913    887.021966
# Name: amount_of_persons, dtype: float64
# 102914    14.371037
# Name: amount_of_persons, dtype: float64
# 861428

# %% [markdown]
# # Get area distribution based on education level

# %%
#get groups

groepen = ['BEVOPLLAAG_P',
'BEVOPLMID_P',
'BEVOPLHOOG_P']

# use year 2018 because 2019 is not available

df_sp = df[df['jaar'] == 2018]

df_sp = df_sp.loc[df['variabele'].isin(groepen)]


df_sp = df_sp.loc[df['gebiedcode15'].isin(wijken)]

df_sp = df_sp.replace(['BEVOPLLAAG_P','BEVOPLMID_P','BEVOPLHOOG_P'],[1,2,3])


amount = []

# get amount per area for each group
for i in df_sp.iterrows():
 
    row = i[1]
    area = row['gebiedcode15']
    waarde = row['waarde']
    etn = row['variabele']
    
    total = df_t[df_t['gebiedcode15'] == area]['amount_of_persons']

    if math.isnan(total) or math.isnan(waarde):
        amount.append(0)
        continue
        
    if int(total) == 0:
        amount.append(0)
        continue
    amount.append(math.ceil((float(total)*float(waarde)/100)) )

df_sp['amount_per_area'] = amount


# Include area code

df_sp['area_code'] = [i%len(wijken) for i in range(len(wijken)*3)]
df_sp = df_sp.fillna(0)


# Because there is a bias in the data towards education level 
# Because in our data the people with age 0-20 (almost) all have education level 1
# Therefor bias needs to be fixed

# groepen  = ['BEV0_17']
# df_sp2 = df[df['jaar'] == 2018]

# df_sp2 = df_sp2.loc[df['variabele'].isin(groepen)]



# df_sp2 = df_sp2.loc[df['gebiedcode15'].isin(wijken)]

# df_sp2 = df_sp2.replace(['BEV0_17'],['[0,20)'])


# df_sp.amount_per_area.sum()

# d = df_sp[df_sp['variabele'] == 1].copy()




# y = df_sp[df_sp['variabele'] == 1]['amount_per_area']+ (np.array(df_sp2['waarde']))



# d['amount_per_area'] += y



# df_sp[df_sp['variabele'] == 3]
# x = df_sp[(df_sp['variabele'] == 2) | (df_sp['variabele'] == 3)]

# x
# df_sp = pd.concat([x, d])


# df_sp = df_sp.drop('waarde', axis=1 )

# df_sp = df_sp.sort_values(by='area_code').reset_index()

# print(df_sp.amount_per_area.sum()/861000)
# df_sp.amount_per_area = df_sp.amount_per_area/( df_sp.amount_per_area.sum()/861000)


df_sp.to_csv('../Data/Spatial_data/Edu_data_withbias.csv', index=False)

# %% [markdown]
# # Make one dataframe based on all three distributions

# %%
gender_data = pd.read_csv('../Data/Spatial_data/Gender_data.csv')

etn_data = pd.read_csv('../Data/Spatial_data/Ethnic_data.csv')

edu_data = pd.read_csv('../Data/Spatial_data/Edu_data_withbias.csv')
codes = []
etnicities = []
amounts = []
percentages = []
genders = []
educations = []

df = pd.DataFrame()
for i in etn_data.itertuples():
#     print(i)
    e = i[2]
    c = i[-1]

    amount = i[-2]
    
    waarde = round(i[-3]/100,100)
    
    
    for j in ['Man', 'Vrouw']:
        
        gender = gender_data[gender_data['area_code'] == c ]
        gender = gender[gender['variabele'] == j]
        gender_waarde = round(float((gender['waarde'])/100),100)

        for k in [1,2,3]:
            
            education = edu_data[edu_data['area_code'] == c]
            education = education[education['variabele'] == k]
            
           

            print(amount, (education['amount_per_area']),)
            amount2 = amount + float(education['amount_per_area']) + float(gender['amount_per_area'])
        
            amounts.append(amount2)
            codes.append(c)
#             percentages.append(waarde2)
            etnicities.append(e)
            genders.append(j)
            educations.append(k)
        
df['etngrp'] = etnicities
df['code'] = codes
df['geslacht'] = genders
df['amount'] = amounts
df['oplniv'] = educations
df['percentage'] = percentages
# Out:
# 1515 0    241
# Name: amount_per_area, dtype: int64
# 1515 481    872
# Name: amount_per_area, dtype: int64
# 1515 962    1864
# Name: amount_per_area, dtype: int64
# 1515 0    241
# Name: amount_per_area, dtype: int64
# 1515 481    872
# Name: amount_per_area, dtype: int64
# 1515 962    1864
# Name: amount_per_area, dtype: int64
# 673 1    139
# Name: amount_per_area, dtype: int64
# 673 482    484
# Name: amount_per_area, dtype: int64
# 673 963    760
# Name: amount_per_area, dtype: int64
# 673 1    139
# Name: amount_per_area, dtype: int64
# 673 482    484
# Name: amount_per_area, dtype: int64
# 673 963    760
# Name: amount_per_area, dtype: int64
# 2128 2    568
# Name: amount_per_area, dtype: int64
# 2128 483    1442
# Name: amount_per_area, dtype: int64
# 2128 964    2360
# Name: amount_per_area, dtype: int64
# 2128 2    568
# Name: amount_per_area, dtype: int64
# 2128 483    1442
# Name: amount_per_area, dtype: int64
# 2128 964    2360
# Name: amount_per_area, dtype: int64
# 628 3    57
# Name: amount_per_area, dtype: int64
# 628 484    320
# Name: amount_per_area, dtype: int64
# 628 965    764
# Name: amount_per_area, dtype: int64
# 628 3    57
# Name: amount_per_area, dtype: int64
# 628 484    320
# Name: amount_per_area, dtype: int64
# 628 965    764
# Name: amount_per_area, dtype: int64
# 734 4    103
# Name: amount_per_area, dtype: int64
# 734 485    373
# Name: amount_per_area, dtype: int64
# 734 966    810
# Name: amount_per_area, dtype: int64
# 734 4    103
# Name: amount_per_area, dtype: int64
# 734 485    373
# Name: amount_per_area, dtype: int64
# 734 966    810
# Name: amount_per_area, dtype: int64
# 0 5    0
# Name: amount_per_area, dtype: int64
# 0 486    0
# Name: amount_per_area, dtype: int64
# 0 967    0
# Name: amount_per_area, dtype: int64
# 0 5    0
# Name: amount_per_area, dtype: int64
# 0 486    0
# Name: amount_per_area, dtype: int64
# 0 967    0
# Name: amount_per_area, dtype: int64
# 853 6    210
# Name: amount_per_area, dtype: int64
# 853 487    514
# Name: amount_per_area, dtype: int64
# 853 968    1181
# Name: amount_per_area, dtype: int64
# 853 6    210
# Name: amount_per_area, dtype: int64
# 853 487    514
# Name: amount_per_area, dtype: int64
# 853 968    1181
# Name: amount_per_area, dtype: int64
# 594 7    106
# Name: amount_per_area, dtype: int64
# 594 488    542
# Name: amount_per_area, dtype: int64
# 594 969    843
# Name: amount_per_area, dtype: int64
# 594 7    106
# Name: amount_per_area, dtype: int64
# 594 488    542
# Name: amount_per_area, dtype: int64
# 594 969    843
# Name: amount_per_area, dtype: int64
# 1273 8    196
# Name: amount_per_area, dtype: int64
# 1273 489    812
# Name: amount_per_area, dtype: int64
# 1273 970    1791
# Name: amount_per_area, dtype: int64
# 1273 8    196
# Name: amount_per_area, dtype: int64
# 1273 489    812
# Name: amount_per_area, dtype: int64
# 1273 970    1791
# Name: amount_per_area, dtype: int64
# 772 9    170
# Name: amount_per_area, dtype: int64
# 772 490    459
# Name: amount_per_area, dtype: int64
# 772 971    1087
# Name: amount_per_area, dtype: int64
# 772 9    170
# Name: amount_per_area, dtype: int64
# 772 490    459
# Name: amount_per_area, dtype: int64
# 772 971    1087
# Name: amount_per_area, dtype: int64
# 987 10    170
# Name: amount_per_area, dtype: int64
# 987 491    679
# Name: amount_per_area, dtype: int64
# 987 972    1295
# Name: amount_per_area, dtype: int64
# 987 10    170
# Name: amount_per_area, dtype: int64
# 987 491    679
# Name: amount_per_area, dtype: int64
# 987 972    1295
# Name: amount_per_area, dtype: int64
# 537 11    94
# Name: amount_per_area, dtype: int64
# 537 492    282
# Name: amount_per_area, dtype: int64
# 537 973    667
# Name: amount_per_area, dtype: int64
# 537 11    94
# Name: amount_per_area, dtype: int64
# 537 492    282
# Name: amount_per_area, dtype: int64
# 537 973    667
# Name: amount_per_area, dtype: int64
# 395 12    70
# Name: amount_per_area, dtype: int64
# 395 493    315
# Name: amount_per_area, dtype: int64
# 395 974    490
# Name: amount_per_area, dtype: int64
# 395 12    70
# Name: amount_per_area, dtype: int64
# 395 493    315
# Name: amount_per_area, dtype: int64
# 395 974    490
# Name: amount_per_area, dtype: int64
# 2006 13    230
# Name: amount_per_area, dtype: int64
# 2006 494    854
# Name: amount_per_area, dtype: int64
# 2006 975    2200
# Name: amount_per_area, dtype: int64
# 2006 13    230
# Name: amount_per_area, dtype: int64
# 2006 494    854
# Name: amount_per_area, dtype: int64
# 2006 975    2200
# Name: amount_per_area, dtype: int64
# 1187 14    185
# Name: amount_per_area, dtype: int64
# 1187 495    600
# Name: amount_per_area, dtype: int64
# 1187 976    1521
# Name: amount_per_area, dtype: int64
# 1187 14    185
# Name: amount_per_area, dtype: int64
# 1187 495    600
# Name: amount_per_area, dtype: int64
# 1187 976    1521
# Name: amount_per_area, dtype: int64
# 1220 15    154
# Name: amount_per_area, dtype: int64
# 1220 496    591
# Name: amount_per_area, dtype: int64
# 1220 977    1423
# Name: amount_per_area, dtype: int64
# 1220 15    154
# Name: amount_per_area, dtype: int64
# 1220 496    591
# Name: amount_per_area, dtype: int64
# 1220 977    1423
# Name: amount_per_area, dtype: int64
# 1262 16    111
# Name: amount_per_area, dtype: int64
# 1262 497    621
# Name: amount_per_area, dtype: int64
# 1262 978    1486
# Name: amount_per_area, dtype: int64
# 1262 16    111
# Name: amount_per_area, dtype: int64
# 1262 497    621
# Name: amount_per_area, dtype: int64
# 1262 978    1486
# Name: amount_per_area, dtype: int64
# 846 17    195
# Name: amount_per_area, dtype: int64
# 846 498    442
# Name: amount_per_area, dtype: int64
# 846 979    1132
# Name: amount_per_area, dtype: int64
# 846 17    195
# Name: amount_per_area, dtype: int64
# 846 498    442
# Name: amount_per_area, dtype: int64
# 846 979    1132
# Name: amount_per_area, dtype: int64
# 0 18    0
# Name: amount_per_area, dtype: int64
# 0 499    0
# Name: amount_per_area, dtype: int64
# 0 980    0
# Name: amount_per_area, dtype: int64
# 0 18    0
# Name: amount_per_area, dtype: int64
# 0 499    0
# Name: amount_per_area, dtype: int64
# 0 980    0
# Name: amount_per_area, dtype: int64
# 1185 19    153
# Name: amount_per_area, dtype: int64
# 1185 500    496
# Name: amount_per_area, dtype: int64
# 1185 981    1257
# Name: amount_per_area, dtype: int64
# 1185 19    153
# Name: amount_per_area, dtype: int64
# 1185 500    496
# Name: amount_per_area, dtype: int64
# 1185 981    1257
# Name: amount_per_area, dtype: int64
# 1445 20    212
# Name: amount_per_area, dtype: int64
# 1445 501    704
# Name: amount_per_area, dtype: int64
# 1445 982    1431
# Name: amount_per_area, dtype: int64
# 1445 20    212
# Name: amount_per_area, dtype: int64
# 1445 501    704
# Name: amount_per_area, dtype: int64
# 1445 982    1431
# Name: amount_per_area, dtype: int64
# 587 21    114
# Name: amount_per_area, dtype: int64
# 587 502    397
# Name: amount_per_area, dtype: int64
# 587 983    907
# Name: amount_per_area, dtype: int64
# 587 21    114
# Name: amount_per_area, dtype: int64
# 587 502    397
# Name: amount_per_area, dtype: int64
# 587 983    907
# Name: amount_per_area, dtype: int64
# 0 22    0
# Name: amount_per_area, dtype: int64
# 0 503    0
# Name: amount_per_area, dtype: int64
# 0 984    0
# Name: amount_per_area, dtype: int64
# 0 22    0
# Name: amount_per_area, dtype: int64
# 0 503    0
# Name: amount_per_area, dtype: int64
# 0 984    0
# Name: amount_per_area, dtype: int64
# 1147 23    145
# Name: amount_per_area, dtype: int64
# 1147 504    578
# Name: amount_per_area, dtype: int64
# 1147 985    1341
# Name: amount_per_area, dtype: int64
# 1147 23    145
# Name: amount_per_area, dtype: int64
# 1147 504    578
# Name: amount_per_area, dtype: int64
# 1147 985    1341
# Name: amount_per_area, dtype: int64
# 354 24    86
# Name: amount_per_area, dtype: int64
# 354 505    193
# Name: amount_per_area, dtype: int64
# 354 986    436
# Name: amount_per_area, dtype: int64
# 354 24    86
# Name: amount_per_area, dtype: int64
# 354 505    193
# Name: amount_per_area, dtype: int64
# 354 986    436
# Name: amount_per_area, dtype: int64
# 0 25    0
# Name: amount_per_area, dtype: int64
# 0 506    0
# Name: amount_per_area, dtype: int64
# 0 987    0
# Name: amount_per_area, dtype: int64
# 0 25    0
# Name: amount_per_area, dtype: int64
# 0 506    0
# Name: amount_per_area, dtype: int64
# 0 987    0
# Name: amount_per_area, dtype: int64
# 922 26    192
# Name: amount_per_area, dtype: int64
# 922 507    518
# Name: amount_per_area, dtype: int64
# 922 988    1207
# Name: amount_per_area, dtype: int64
# 922 26    192
# Name: amount_per_area, dtype: int64
# 922 507    518
# Name: amount_per_area, dtype: int64
# 922 988    1207
# Name: amount_per_area, dtype: int64
# 2260 27    213
# Name: amount_per_area, dtype: int64
# 2260 508    1063
# Name: amount_per_area, dtype: int64
# 2260 989    2267
# Name: amount_per_area, dtype: int64
# 2260 27    213
# Name: amount_per_area, dtype: int64
# 2260 508    1063
# Name: amount_per_area, dtype: int64
# 2260 989    2267
# Name: amount_per_area, dtype: int64
# 2906 28    761
# Name: amount_per_area, dtype: int64
# 2906 509    1427
# Name: amount_per_area, dtype: int64
# 2906 990    2568
# Name: amount_per_area, dtype: int64
# 2906 28    761
# Name: amount_per_area, dtype: int64
# 2906 509    1427
# Name: amount_per_area, dtype: int64
# 2906 990    2568
# Name: amount_per_area, dtype: int64
# 1365 29    254
# Name: amount_per_area, dtype: int64
# 1365 510    736
# Name: amount_per_area, dtype: int64
# 1365 991    1547
# Name: amount_per_area, dtype: int64
# 1365 29    254
# Name: amount_per_area, dtype: int64
# 1365 510    736
# Name: amount_per_area, dtype: int64
# 1365 991    1547
# Name: amount_per_area, dtype: int64
# 1712 30    310
# Name: amount_per_area, dtype: int64
# 1712 511    836
# Name: amount_per_area, dtype: int64
# 1712 992    1950
# Name: amount_per_area, dtype: int64
# 1712 30    310
# Name: amount_per_area, dtype: int64
# 1712 511    836
# Name: amount_per_area, dtype: int64
# 1712 992    1950
# Name: amount_per_area, dtype: int64
# 2314 31    500
# Name: amount_per_area, dtype: int64
# 2314 512    1230
# Name: amount_per_area, dtype: int64
# 2314 993    2114
# Name: amount_per_area, dtype: int64
# 2314 31    500
# Name: amount_per_area, dtype: int64
# 2314 512    1230
# Name: amount_per_area, dtype: int64
# 2314 993    2114
# Name: amount_per_area, dtype: int64
# 767 32    176
# Name: amount_per_area, dtype: int64
# 767 513    419
# Name: amount_per_area, dtype: int64
# 767 994    771
# Name: amount_per_area, dtype: int64
# 767 32    176
# Name: amount_per_area, dtype: int64
# 767 513    419
# Name: amount_per_area, dtype: int64
# 767 994    771
# Name: amount_per_area, dtype: int64
# 1162 33    347
# Name: amount_per_area, dtype: int64
# 1162 514    542
# Name: amount_per_area, dtype: int64
# 1162 995    1279
# Name: amount_per_area, dtype: int64
# 1162 33    347
# Name: amount_per_area, dtype: int64
# 1162 514    542
# Name: amount_per_area, dtype: int64
# 1162 995    1279
# Name: amount_per_area, dtype: int64
# 1678 34    312
# Name: amount_per_area, dtype: int64
# 1678 515    794
# Name: amount_per_area, dtype: int64
# 1678 996    1729
# Name: amount_per_area, dtype: int64
# 1678 34    312
# Name: amount_per_area, dtype: int64
# 1678 515    794
# Name: amount_per_area, dtype: int64
# 1678 996    1729
# Name: amount_per_area, dtype: int64
# 2207 35    670
# Name: amount_per_area, dtype: int64
# 2207 516    1262
# Name: amount_per_area, dtype: int64
# 2207 997    2010
# Name: amount_per_area, dtype: int64
# 2207 35    670
# Name: amount_per_area, dtype: int64
# 2207 516    1262
# Name: amount_per_area, dtype: int64
# 2207 997    2010
# Name: amount_per_area, dtype: int64
# 2049 36    405
# Name: amount_per_area, dtype: int64
# 2049 517    978
# Name: amount_per_area, dtype: int64
# 2049 998    1989
# Name: amount_per_area, dtype: int64
# 2049 36    405
# Name: amount_per_area, dtype: int64
# 2049 517    978
# Name: amount_per_area, dtype: int64
# 2049 998    1989
# Name: amount_per_area, dtype: int64
# 0 37    0
# Name: amount_per_area, dtype: int64
# 0 518    0
# Name: amount_per_area, dtype: int64
# 0 999    0
# Name: amount_per_area, dtype: int64
# 0 37    0
# Name: amount_per_area, dtype: int64
# 0 518    0
# Name: amount_per_area, dtype: int64
# 0 999    0
# Name: amount_per_area, dtype: int64
# 0 38    0
# Name: amount_per_area, dtype: int64
# 0 519    0
# Name: amount_per_area, dtype: int64
# 0 1000    0
# Name: amount_per_area, dtype: int64
# 0 38    0
# Name: amount_per_area, dtype: int64
# 0 519    0
# Name: amount_per_area, dtype: int64
# 0 1000    0
# Name: amount_per_area, dtype: int64
# 2887 39    575
# Name: amount_per_area, dtype: int64
# 2887 520    1341
# Name: amount_per_area, dtype: int64
# 2887 1001    2873
# Name: amount_per_area, dtype: int64
# 2887 39    575
# Name: amount_per_area, dtype: int64
# 2887 520    1341
# Name: amount_per_area, dtype: int64
# 2887 1001    2873
# Name: amount_per_area, dtype: int64
# 2658 40    492
# Name: amount_per_area, dtype: int64
# 2658 521    1251
# Name: amount_per_area, dtype: int64
# 2658 1002    2681
# Name: amount_per_area, dtype: int64
# 2658 40    492
# Name: amount_per_area, dtype: int64
# 2658 521    1251
# Name: amount_per_area, dtype: int64
# 2658 1002    2681
# Name: amount_per_area, dtype: int64
# 2578 41    789
# Name: amount_per_area, dtype: int64
# 2578 522    1484
# Name: amount_per_area, dtype: int64
# 2578 1003    2365
# Name: amount_per_area, dtype: int64
# 2578 41    789
# Name: amount_per_area, dtype: int64
# 2578 522    1484
# Name: amount_per_area, dtype: int64
# 2578 1003    2365
# Name: amount_per_area, dtype: int64
# 0 42    0
# Name: amount_per_area, dtype: int64
# 0 523    0
# Name: amount_per_area, dtype: int64
# 0 1004    0
# Name: amount_per_area, dtype: int64
# 0 42    0
# Name: amount_per_area, dtype: int64
# 0 523    0
# Name: amount_per_area, dtype: int64
# 0 1004    0
# Name: amount_per_area, dtype: int64
# 0 43    0
# Name: amount_per_area, dtype: int64
# 0 524    0
# Name: amount_per_area, dtype: int64
# 0 1005    0
# Name: amount_per_area, dtype: int64
# 0 43    0
# Name: amount_per_area, dtype: int64
# 0 524    0
# Name: amount_per_area, dtype: int64
# 0 1005    0
# Name: amount_per_area, dtype: int64
# 2272 44    517
# Name: amount_per_area, dtype: int64
# 2272 525    1152
# Name: amount_per_area, dtype: int64
# 2272 1006    2304
# Name: amount_per_area, dtype: int64
# 2272 44    517
# Name: amount_per_area, dtype: int64
# 2272 525    1152
# Name: amount_per_area, dtype: int64
# 2272 1006    2304
# Name: amount_per_area, dtype: int64
# 0 45    0
# Name: amount_per_area, dtype: int64
# 0 526    0
# Name: amount_per_area, dtype: int64
# 0 1007    0
# Name: amount_per_area, dtype: int64
# 0 45    0
# Name: amount_per_area, dtype: int64
# 0 526    0
# Name: amount_per_area, dtype: int64
# 0 1007    0
# Name: amount_per_area, dtype: int64
# 0 46    0
# Name: amount_per_area, dtype: int64
# 0 527    0
# Name: amount_per_area, dtype: int64
# 0 1008    0
# Name: amount_per_area, dtype: int64
# 0 46    0
# Name: amount_per_area, dtype: int64
# 0 527    0
# Name: amount_per_area, dtype: int64
# 0 1008    0
# Name: amount_per_area, dtype: int64
# 0 47    0
# Name: amount_per_area, dtype: int64
# 0 528    0
# Name: amount_per_area, dtype: int64
# 0 1009    0
# Name: amount_per_area, dtype: int64
# 0 47    0
# Name: amount_per_area, dtype: int64
# 0 528    0
# Name: amount_per_area, dtype: int64
# 0 1009    0
# Name: amount_per_area, dtype: int64
# 2479 48    538
# Name: amount_per_area, dtype: int64
# 2479 529    1038
# Name: amount_per_area, dtype: int64
# 2479 1010    2268
# Name: amount_per_area, dtype: int64
# 2479 48    538
# Name: amount_per_area, dtype: int64
# 2479 529    1038
# Name: amount_per_area, dtype: int64
# 2479 1010    2268
# Name: amount_per_area, dtype: int64
# 2877 49    603
# Name: amount_per_area, dtype: int64
# 2877 530    1390
# Name: amount_per_area, dtype: int64
# 2877 1011    2687
# Name: amount_per_area, dtype: int64
# 2877 49    603
# Name: amount_per_area, dtype: int64
# 2877 530    1390
# Name: amount_per_area, dtype: int64
# 2877 1011    2687
# Name: amount_per_area, dtype: int64
# 0 50    0
# Name: amount_per_area, dtype: int64
# 0 531    0
# Name: amount_per_area, dtype: int64
# 0 1012    0
# Name: amount_per_area, dtype: int64
# 0 50    0
# Name: amount_per_area, dtype: int64
# 0 531    0
# Name: amount_per_area, dtype: int64
# 0 1012    0
# Name: amount_per_area, dtype: int64
# 0 51    0
# Name: amount_per_area, dtype: int64
# 0 532    0
# Name: amount_per_area, dtype: int64
# 0 1013    0
# Name: amount_per_area, dtype: int64
# 0 51    0
# Name: amount_per_area, dtype: int64
# 0 532    0
# Name: amount_per_area, dtype: int64
# 0 1013    0
# Name: amount_per_area, dtype: int64
# 1579 52    255
# Name: amount_per_area, dtype: int64
# 1579 533    1019
# Name: amount_per_area, dtype: int64
# 1579 1014    1910
# Name: amount_per_area, dtype: int64
# 1579 52    255
# Name: amount_per_area, dtype: int64
# 1579 533    1019
# Name: amount_per_area, dtype: int64
# 1579 1014    1910
# Name: amount_per_area, dtype: int64
# 0 53    0
# Name: amount_per_area, dtype: int64
# 0 534    0
# Name: amount_per_area, dtype: int64
# 0 1015    0
# Name: amount_per_area, dtype: int64
# 0 53    0
# Name: amount_per_area, dtype: int64
# 0 534    0
# Name: amount_per_area, dtype: int64
# 0 1015    0
# Name: amount_per_area, dtype: int64
# 2061 54    248
# Name: amount_per_area, dtype: int64
# 2061 535    918
# Name: amount_per_area, dtype: int64
# 2061 1016    2365
# Name: amount_per_area, dtype: int64
# 2061 54    248
# Name: amount_per_area, dtype: int64
# 2061 535    918
# Name: amount_per_area, dtype: int64
# 2061 1016    2365
# Name: amount_per_area, dtype: int64
# 1195 55    215
# Name: amount_per_area, dtype: int64
# 1195 536    547
# Name: amount_per_area, dtype: int64
# 1195 1017    1192
# Name: amount_per_area, dtype: int64
# 1195 55    215
# Name: amount_per_area, dtype: int64
# 1195 536    547
# Name: amount_per_area, dtype: int64
# 1195 1017    1192
# Name: amount_per_area, dtype: int64
# 2168 56    418
# Name: amount_per_area, dtype: int64
# 2168 537    870
# Name: amount_per_area, dtype: int64
# 2168 1018    2192
# Name: amount_per_area, dtype: int64
# 2168 56    418
# Name: amount_per_area, dtype: int64
# 2168 537    870
# Name: amount_per_area, dtype: int64
# 2168 1018    2192
# Name: amount_per_area, dtype: int64
# 703 57    131
# Name: amount_per_area, dtype: int64
# 703 538    308
# Name: amount_per_area, dtype: int64
# 703 1019    746
# Name: amount_per_area, dtype: int64
# 703 57    131
# Name: amount_per_area, dtype: int64
# 703 538    308
# Name: amount_per_area, dtype: int64
# 703 1019    746
# Name: amount_per_area, dtype: int64
# 1508 58    409
# Name: amount_per_area, dtype: int64
# 1508 539    764
# Name: amount_per_area, dtype: int64
# 1508 1020    1554
# Name: amount_per_area, dtype: int64
# 1508 58    409
# Name: amount_per_area, dtype: int64
# 1508 539    764
# Name: amount_per_area, dtype: int64
# 1508 1020    1554
# Name: amount_per_area, dtype: int64
# 1107 59    331
# Name: amount_per_area, dtype: int64
# 1107 540    579
# Name: amount_per_area, dtype: int64
# 1107 1021    1157
# Name: amount_per_area, dtype: int64
# 1107 59    331
# Name: amount_per_area, dtype: int64
# 1107 540    579
# Name: amount_per_area, dtype: int64
# 1107 1021    1157
# Name: amount_per_area, dtype: int64
# 584 60    115
# Name: amount_per_area, dtype: int64
# 584 541    230
# Name: amount_per_area, dtype: int64
# 584 1022    613
# Name: amount_per_area, dtype: int64
# 584 60    115
# Name: amount_per_area, dtype: int64
# 584 541    230
# Name: amount_per_area, dtype: int64
# 584 1022    613
# Name: amount_per_area, dtype: int64
# 0 61    0
# Name: amount_per_area, dtype: int64
# 0 542    0
# Name: amount_per_area, dtype: int64
# 0 1023    0
# Name: amount_per_area, dtype: int64
# 0 61    0
# Name: amount_per_area, dtype: int64
# 0 542    0
# Name: amount_per_area, dtype: int64
# 0 1023    0
# Name: amount_per_area, dtype: int64
# 61 62    0
# Name: amount_per_area, dtype: int64
# 61 543    0
# Name: amount_per_area, dtype: int64
# 61 1024    0
# Name: amount_per_area, dtype: int64
# 61 62    0
# Name: amount_per_area, dtype: int64
# 61 543    0
# Name: amount_per_area, dtype: int64
# 61 1024    0
# Name: amount_per_area, dtype: int64
# 1965 63    636
# Name: amount_per_area, dtype: int64
# 1965 544    1172
# Name: amount_per_area, dtype: int64
# 1965 1025    1540
# Name: amount_per_area, dtype: int64
# 1965 63    636
# Name: amount_per_area, dtype: int64
# 1965 544    1172
# Name: amount_per_area, dtype: int64
# 1965 1025    1540
# Name: amount_per_area, dtype: int64
# 1561 64    552
# Name: amount_per_area, dtype: int64
# 1561 545    951
# Name: amount_per_area, dtype: int64
# 1561 1026    1564
# Name: amount_per_area, dtype: int64
# 1561 64    552
# Name: amount_per_area, dtype: int64
# 1561 545    951
# Name: amount_per_area, dtype: int64
# 1561 1026    1564
# Name: amount_per_area, dtype: int64
# 708 65    325
# Name: amount_per_area, dtype: int64
# 708 546    429
# Name: amount_per_area, dtype: int64
# 708 1027    739
# Name: amount_per_area, dtype: int64
# 708 65    325
# Name: amount_per_area, dtype: int64
# 708 546    429
# Name: amount_per_area, dtype: int64
# 708 1027    739
# Name: amount_per_area, dtype: int64
# 1964 66    718
# Name: amount_per_area, dtype: int64
# 1964 547    1196
# Name: amount_per_area, dtype: int64
# 1964 1028    2072
# Name: amount_per_area, dtype: int64
# 1964 66    718
# Name: amount_per_area, dtype: int64
# 1964 547    1196
# Name: amount_per_area, dtype: int64
# 1964 1028    2072
# Name: amount_per_area, dtype: int64
# 1730 67    420
# Name: amount_per_area, dtype: int64
# 1730 548    807
# Name: amount_per_area, dtype: int64
# 1730 1029    2002
# Name: amount_per_area, dtype: int64
# 1730 67    420
# Name: amount_per_area, dtype: int64
# 1730 548    807
# Name: amount_per_area, dtype: int64
# 1730 1029    2002
# Name: amount_per_area, dtype: int64
# 1835 68    553
# Name: amount_per_area, dtype: int64
# 1835 549    829
# Name: amount_per_area, dtype: int64
# 1835 1030    1688
# Name: amount_per_area, dtype: int64
# 1835 68    553
# Name: amount_per_area, dtype: int64
# 1835 549    829
# Name: amount_per_area, dtype: int64
# 1835 1030    1688
# Name: amount_per_area, dtype: int64
# 1825 69    318
# Name: amount_per_area, dtype: int64
# 1825 550    751
# Name: amount_per_area, dtype: int64
# 1825 1031    1819
# Name: amount_per_area, dtype: int64
# 1825 69    318
# Name: amount_per_area, dtype: int64
# 1825 550    751
# Name: amount_per_area, dtype: int64
# 1825 1031    1819
# Name: amount_per_area, dtype: int64
# 2 70    0
# Name: amount_per_area, dtype: int64
# 2 551    0
# Name: amount_per_area, dtype: int64
# 2 1032    0
# Name: amount_per_area, dtype: int64
# 2 70    0
# Name: amount_per_area, dtype: int64
# 2 551    0
# Name: amount_per_area, dtype: int64
# 2 1032    0
# Name: amount_per_area, dtype: int64
# 1 71    0
# Name: amount_per_area, dtype: int64
# 1 552    0
# Name: amount_per_area, dtype: int64
# 1 1033    0
# Name: amount_per_area, dtype: int64
# 1 71    0
# Name: amount_per_area, dtype: int64
# 1 552    0
# Name: amount_per_area, dtype: int64
# 1 1033    0
# Name: amount_per_area, dtype: int64
# 0 72    0
# Name: amount_per_area, dtype: int64
# 0 553    0
# Name: amount_per_area, dtype: int64
# 0 1034    0
# Name: amount_per_area, dtype: int64
# 0 72    0
# Name: amount_per_area, dtype: int64
# 0 553    0
# Name: amount_per_area, dtype: int64
# 0 1034    0
# Name: amount_per_area, dtype: int64
# 1 73    0
# Name: amount_per_area, dtype: int64
# 1 554    0
# Name: amount_per_area, dtype: int64
# 1 1035    0
# Name: amount_per_area, dtype: int64
# 1 73    0
# Name: amount_per_area, dtype: int64
# 1 554    0
# Name: amount_per_area, dtype: int64
# 1 1035    0
# Name: amount_per_area, dtype: int64
# 2 74    0
# Name: amount_per_area, dtype: int64
# 2 555    0
# Name: amount_per_area, dtype: int64
# 2 1036    0
# Name: amount_per_area, dtype: int64
# 2 74    0
# Name: amount_per_area, dtype: int64
# 2 555    0
# Name: amount_per_area, dtype: int64
# 2 1036    0
# Name: amount_per_area, dtype: int64
# 2 75    0
# Name: amount_per_area, dtype: int64
# 2 556    0
# Name: amount_per_area, dtype: int64
# 2 1037    0
# Name: amount_per_area, dtype: int64
# 2 75    0
# Name: amount_per_area, dtype: int64
# 2 556    0
# Name: amount_per_area, dtype: int64
# 2 1037    0
# Name: amount_per_area, dtype: int64
# 0 76    0
# Name: amount_per_area, dtype: int64
# 0 557    0
# Name: amount_per_area, dtype: int64
# 0 1038    0
# Name: amount_per_area, dtype: int64
# 0 76    0
# Name: amount_per_area, dtype: int64
# 0 557    0
# Name: amount_per_area, dtype: int64
# 0 1038    0
# Name: amount_per_area, dtype: int64
# 2 77    0
# Name: amount_per_area, dtype: int64
# 2 558    0
# Name: amount_per_area, dtype: int64
# 2 1039    0
# Name: amount_per_area, dtype: int64
# 2 77    0
# Name: amount_per_area, dtype: int64
# 2 558    0
# Name: amount_per_area, dtype: int64
# 2 1039    0
# Name: amount_per_area, dtype: int64
# 529 78    33
# Name: amount_per_area, dtype: int64
# 529 559    154
# Name: amount_per_area, dtype: int64
# 529 1040    614
# Name: amount_per_area, dtype: int64
# 529 78    33
# Name: amount_per_area, dtype: int64
# 529 559    154
# Name: amount_per_area, dtype: int64
# 529 1040    614
# Name: amount_per_area, dtype: int64
# 0 79    0
# Name: amount_per_area, dtype: int64
# 0 560    0
# Name: amount_per_area, dtype: int64
# 0 1041    0
# Name: amount_per_area, dtype: int64
# 0 79    0
# Name: amount_per_area, dtype: int64
# 0 560    0
# Name: amount_per_area, dtype: int64
# 0 1041    0
# Name: amount_per_area, dtype: int64
# 1812 80    912
# Name: amount_per_area, dtype: int64
# 1812 561    1071
# Name: amount_per_area, dtype: int64
# 1812 1042    1982
# Name: amount_per_area, dtype: int64
# 1812 80    912
# Name: amount_per_area, dtype: int64
# 1812 561    1071
# Name: amount_per_area, dtype: int64
# 1812 1042    1982
# Name: amount_per_area, dtype: int64
# 2269 81    1298
# Name: amount_per_area, dtype: int64
# 2269 562    1587
# Name: amount_per_area, dtype: int64
# 2269 1043    1971
# Name: amount_per_area, dtype: int64
# 2269 81    1298
# Name: amount_per_area, dtype: int64
# 2269 562    1587
# Name: amount_per_area, dtype: int64
# 2269 1043    1971
# Name: amount_per_area, dtype: int64
# 0 82    0
# Name: amount_per_area, dtype: int64
# 0 563    0
# Name: amount_per_area, dtype: int64
# 0 1044    0
# Name: amount_per_area, dtype: int64
# 0 82    0
# Name: amount_per_area, dtype: int64
# 0 563    0
# Name: amount_per_area, dtype: int64
# 0 1044    0
# Name: amount_per_area, dtype: int64
# 2132 83    688
# Name: amount_per_area, dtype: int64
# 2132 564    994
# Name: amount_per_area, dtype: int64
# 2132 1045    2140
# Name: amount_per_area, dtype: int64
# 2132 83    688
# Name: amount_per_area, dtype: int64
# 2132 564    994
# Name: amount_per_area, dtype: int64
# 2132 1045    2140
# Name: amount_per_area, dtype: int64
# 2056 84    863
# Name: amount_per_area, dtype: int64
# 2056 565    1099
# Name: amount_per_area, dtype: int64
# 2056 1046    1962
# Name: amount_per_area, dtype: int64
# 2056 84    863
# Name: amount_per_area, dtype: int64
# 2056 565    1099
# Name: amount_per_area, dtype: int64
# 2056 1046    1962
# Name: amount_per_area, dtype: int64
# 1373 85    720
# Name: amount_per_area, dtype: int64
# 1373 566    777
# Name: amount_per_area, dtype: int64
# 1373 1047    1382
# Name: amount_per_area, dtype: int64
# 1373 85    720
# Name: amount_per_area, dtype: int64
# 1373 566    777
# Name: amount_per_area, dtype: int64
# 1373 1047    1382
# Name: amount_per_area, dtype: int64
# 0 86    0
# Name: amount_per_area, dtype: int64
# 0 567    0
# Name: amount_per_area, dtype: int64
# 0 1048    0
# Name: amount_per_area, dtype: int64
# 0 86    0
# Name: amount_per_area, dtype: int64
# 0 567    0
# Name: amount_per_area, dtype: int64
# 0 1048    0
# Name: amount_per_area, dtype: int64
# 2 87    0
# Name: amount_per_area, dtype: int64
# 2 568    0
# Name: amount_per_area, dtype: int64
# 2 1049    0
# Name: amount_per_area, dtype: int64
# 2 87    0
# Name: amount_per_area, dtype: int64
# 2 568    0
# Name: amount_per_area, dtype: int64
# 2 1049    0
# Name: amount_per_area, dtype: int64
# 2056 88    611
# Name: amount_per_area, dtype: int64
# 2056 569    1030
# Name: amount_per_area, dtype: int64
# 2056 1050    2174
# Name: amount_per_area, dtype: int64
# 2056 88    611
# Name: amount_per_area, dtype: int64
# 2056 569    1030
# Name: amount_per_area, dtype: int64
# 2056 1050    2174
# Name: amount_per_area, dtype: int64
# 0 89    0
# Name: amount_per_area, dtype: int64
# 0 570    0
# Name: amount_per_area, dtype: int64
# 0 1051    0
# Name: amount_per_area, dtype: int64
# 0 89    0
# Name: amount_per_area, dtype: int64
# 0 570    0
# Name: amount_per_area, dtype: int64
# 0 1051    0
# Name: amount_per_area, dtype: int64
# 1680 90    994
# Name: amount_per_area, dtype: int64
# 1680 571    1030
# Name: amount_per_area, dtype: int64
# 1680 1052    1527
# Name: amount_per_area, dtype: int64
# 1680 90    994
# Name: amount_per_area, dtype: int64
# 1680 571    1030
# Name: amount_per_area, dtype: int64
# 1680 1052    1527
# Name: amount_per_area, dtype: int64
# 3019 91    1116
# Name: amount_per_area, dtype: int64
# 3019 572    1736
# Name: amount_per_area, dtype: int64
# 3019 1053    3347
# Name: amount_per_area, dtype: int64
# 3019 91    1116
# Name: amount_per_area, dtype: int64
# 3019 572    1736
# Name: amount_per_area, dtype: int64
# 3019 1053    3347
# Name: amount_per_area, dtype: int64
# 2575 92    808
# Name: amount_per_area, dtype: int64
# 2575 573    1363
# Name: amount_per_area, dtype: int64
# 2575 1054    2878
# Name: amount_per_area, dtype: int64
# 2575 92    808
# Name: amount_per_area, dtype: int64
# 2575 573    1363
# Name: amount_per_area, dtype: int64
# 2575 1054    2878
# Name: amount_per_area, dtype: int64
# 2642 93    805
# Name: amount_per_area, dtype: int64
# 2642 574    1137
# Name: amount_per_area, dtype: int64
# 2642 1055    2794
# Name: amount_per_area, dtype: int64
# 2642 93    805
# Name: amount_per_area, dtype: int64
# 2642 574    1137
# Name: amount_per_area, dtype: int64
# 2642 1055    2794
# Name: amount_per_area, dtype: int64
# 2155 94    709
# Name: amount_per_area, dtype: int64
# 2155 575    1119
# Name: amount_per_area, dtype: int64
# 2155 1056    1901
# Name: amount_per_area, dtype: int64
# 2155 94    709
# Name: amount_per_area, dtype: int64
# 2155 575    1119
# Name: amount_per_area, dtype: int64
# 2155 1056    1901
# Name: amount_per_area, dtype: int64
# 7 95    0
# Name: amount_per_area, dtype: int64
# 7 576    0
# Name: amount_per_area, dtype: int64
# 7 1057    0
# Name: amount_per_area, dtype: int64
# 7 95    0
# Name: amount_per_area, dtype: int64
# 7 576    0
# Name: amount_per_area, dtype: int64
# 7 1057    0
# Name: amount_per_area, dtype: int64
# 71 96    0
# Name: amount_per_area, dtype: int64
# 71 577    0
# Name: amount_per_area, dtype: int64
# 71 1058    0
# Name: amount_per_area, dtype: int64
# 71 96    0
# Name: amount_per_area, dtype: int64
# 71 577    0
# Name: amount_per_area, dtype: int64
# 71 1058    0
# Name: amount_per_area, dtype: int64
# 1503 97    598
# Name: amount_per_area, dtype: int64
# 1503 578    818
# Name: amount_per_area, dtype: int64
# 1503 1059    1730
# Name: amount_per_area, dtype: int64
# 1503 97    598
# Name: amount_per_area, dtype: int64
# 1503 578    818
# Name: amount_per_area, dtype: int64
# 1503 1059    1730
# Name: amount_per_area, dtype: int64
# 2026 98    549
# Name: amount_per_area, dtype: int64
# 2026 579    878
# Name: amount_per_area, dtype: int64
# 2026 1060    2231
# Name: amount_per_area, dtype: int64
# 2026 98    549
# Name: amount_per_area, dtype: int64
# 2026 579    878
# Name: amount_per_area, dtype: int64
# 2026 1060    2231
# Name: amount_per_area, dtype: int64
# 2632 99    851
# Name: amount_per_area, dtype: int64
# 2632 580    1351
# Name: amount_per_area, dtype: int64
# 2632 1061    2802
# Name: amount_per_area, dtype: int64
# 2632 99    851
# Name: amount_per_area, dtype: int64
# 2632 580    1351
# Name: amount_per_area, dtype: int64
# 2632 1061    2802
# Name: amount_per_area, dtype: int64
# 2032 100    471
# Name: amount_per_area, dtype: int64
# 2032 581    1041
# Name: amount_per_area, dtype: int64
# 2032 1062    1847
# Name: amount_per_area, dtype: int64
# 2032 100    471
# Name: amount_per_area, dtype: int64
# 2032 581    1041
# Name: amount_per_area, dtype: int64
# 2032 1062    1847
# Name: amount_per_area, dtype: int64
# 2149 101    445
# Name: amount_per_area, dtype: int64
# 2149 582    889
# Name: amount_per_area, dtype: int64
# 2149 1063    2371
# Name: amount_per_area, dtype: int64
# 2149 101    445
# Name: amount_per_area, dtype: int64
# 2149 582    889
# Name: amount_per_area, dtype: int64
# 2149 1063    2371
# Name: amount_per_area, dtype: int64
# 2707 102    1132
# Name: amount_per_area, dtype: int64
# 2707 583    1280
# Name: amount_per_area, dtype: int64
# 2707 1064    2510
# Name: amount_per_area, dtype: int64
# 2707 102    1132
# Name: amount_per_area, dtype: int64
# 2707 583    1280
# Name: amount_per_area, dtype: int64
# 2707 1064    2510
# Name: amount_per_area, dtype: int64
# 2237 103    548
# Name: amount_per_area, dtype: int64
# 2237 584    1096
# Name: amount_per_area, dtype: int64
# 2237 1065    2570
# Name: amount_per_area, dtype: int64
# 2237 103    548
# Name: amount_per_area, dtype: int64
# 2237 584    1096
# Name: amount_per_area, dtype: int64
# 2237 1065    2570
# Name: amount_per_area, dtype: int64
# 2883 104    539
# Name: amount_per_area, dtype: int64
# 2883 585    1455
# Name: amount_per_area, dtype: int64
# 2883 1066    3395
# Name: amount_per_area, dtype: int64
# 2883 104    539
# Name: amount_per_area, dtype: int64
# 2883 585    1455
# Name: amount_per_area, dtype: int64
# 2883 1066    3395
# Name: amount_per_area, dtype: int64
# 1781 105    1407
# Name: amount_per_area, dtype: int64
# 1781 586    1320
# Name: amount_per_area, dtype: int64
# 1781 1067    1671
# Name: amount_per_area, dtype: int64
# 1781 105    1407
# Name: amount_per_area, dtype: int64
# 1781 586    1320
# Name: amount_per_area, dtype: int64
# 1781 1067    1671
# Name: amount_per_area, dtype: int64
# 2567 106    930
# Name: amount_per_area, dtype: int64
# 2567 587    1343
# Name: amount_per_area, dtype: int64
# 2567 1068    2841
# Name: amount_per_area, dtype: int64
# 2567 106    930
# Name: amount_per_area, dtype: int64
# 2567 587    1343
# Name: amount_per_area, dtype: int64
# 2567 1068    2841
# Name: amount_per_area, dtype: int64
# 2679 107    354
# Name: amount_per_area, dtype: int64
# 2679 588    1061
# Name: amount_per_area, dtype: int64
# 2679 1069    3006
# Name: amount_per_area, dtype: int64
# 2679 107    354
# Name: amount_per_area, dtype: int64
# 2679 588    1061
# Name: amount_per_area, dtype: int64
# 2679 1069    3006
# Name: amount_per_area, dtype: int64
# 1577 108    373
# Name: amount_per_area, dtype: int64
# 1577 589    665
# Name: amount_per_area, dtype: int64
# 1577 1070    1622
# Name: amount_per_area, dtype: int64
# 1577 108    373
# Name: amount_per_area, dtype: int64
# 1577 589    665
# Name: amount_per_area, dtype: int64
# 1577 1070    1622
# Name: amount_per_area, dtype: int64
# 3519 109    534
# Name: amount_per_area, dtype: int64
# 3519 590    1306
# Name: amount_per_area, dtype: int64
# 3519 1071    4094
# Name: amount_per_area, dtype: int64
# 3519 109    534
# Name: amount_per_area, dtype: int64
# 3519 590    1306
# Name: amount_per_area, dtype: int64
# 3519 1071    4094
# Name: amount_per_area, dtype: int64
# 2886 110    453
# Name: amount_per_area, dtype: int64
# 2886 591    1157
# Name: amount_per_area, dtype: int64
# 2886 1072    3369
# Name: amount_per_area, dtype: int64
# 2886 110    453
# Name: amount_per_area, dtype: int64
# 2886 591    1157
# Name: amount_per_area, dtype: int64
# 2886 1072    3369
# Name: amount_per_area, dtype: int64
# 2348 111    378
# Name: amount_per_area, dtype: int64
# 2348 592    906
# Name: amount_per_area, dtype: int64
# 2348 1073    2492
# Name: amount_per_area, dtype: int64
# 2348 111    378
# Name: amount_per_area, dtype: int64
# 2348 592    906
# Name: amount_per_area, dtype: int64
# 2348 1073    2492
# Name: amount_per_area, dtype: int64
# 666 112    195
# Name: amount_per_area, dtype: int64
# 666 593    337
# Name: amount_per_area, dtype: int64
# 666 1074    765
# Name: amount_per_area, dtype: int64
# 666 112    195
# Name: amount_per_area, dtype: int64
# 666 593    337
# Name: amount_per_area, dtype: int64
# 666 1074    765
# Name: amount_per_area, dtype: int64
# 1023 113    275
# Name: amount_per_area, dtype: int64
# 1023 594    464
# Name: amount_per_area, dtype: int64
# 1023 1075    979
# Name: amount_per_area, dtype: int64
# 1023 113    275
# Name: amount_per_area, dtype: int64
# 1023 594    464
# Name: amount_per_area, dtype: int64
# 1023 1075    979
# Name: amount_per_area, dtype: int64
# 101 114    7
# Name: amount_per_area, dtype: int64
# 101 595    28
# Name: amount_per_area, dtype: int64
# 101 1076    120
# Name: amount_per_area, dtype: int64
# 101 114    7
# Name: amount_per_area, dtype: int64
# 101 595    28
# Name: amount_per_area, dtype: int64
# 101 1076    120
# Name: amount_per_area, dtype: int64
# 8 115    0
# Name: amount_per_area, dtype: int64
# 8 596    0
# Name: amount_per_area, dtype: int64
# 8 1077    0
# Name: amount_per_area, dtype: int64
# 8 115    0
# Name: amount_per_area, dtype: int64
# 8 596    0
# Name: amount_per_area, dtype: int64
# 8 1077    0
# Name: amount_per_area, dtype: int64
# 432 116    80
# Name: amount_per_area, dtype: int64
# 432 597    178
# Name: amount_per_area, dtype: int64
# 432 1078    622
# Name: amount_per_area, dtype: int64
# 432 116    80
# Name: amount_per_area, dtype: int64
# 432 597    178
# Name: amount_per_area, dtype: int64
# 432 1078    622
# Name: amount_per_area, dtype: int64
# 905 117    911
# Name: amount_per_area, dtype: int64
# 905 598    881
# Name: amount_per_area, dtype: int64
# 905 1079    1146
# Name: amount_per_area, dtype: int64
# 905 117    911
# Name: amount_per_area, dtype: int64
# 905 598    881
# Name: amount_per_area, dtype: int64
# 905 1079    1146
# Name: amount_per_area, dtype: int64
# 1647 118    753
# Name: amount_per_area, dtype: int64
# 1647 599    890
# Name: amount_per_area, dtype: int64
# 1647 1080    1746
# Name: amount_per_area, dtype: int64
# 1647 118    753
# Name: amount_per_area, dtype: int64
# 1647 599    890
# Name: amount_per_area, dtype: int64
# 1647 1080    1746
# Name: amount_per_area, dtype: int64
# 1907 119    852
# Name: amount_per_area, dtype: int64
# 1907 600    1015
# Name: amount_per_area, dtype: int64
# 1907 1081    2191
# Name: amount_per_area, dtype: int64
# 1907 119    852
# Name: amount_per_area, dtype: int64
# 1907 600    1015
# Name: amount_per_area, dtype: int64
# 1907 1081    2191
# Name: amount_per_area, dtype: int64
# 1552 120    1038
# Name: amount_per_area, dtype: int64
# 1552 601    1115
# Name: amount_per_area, dtype: int64
# 1552 1082    1691
# Name: amount_per_area, dtype: int64
# 1552 120    1038
# Name: amount_per_area, dtype: int64
# 1552 601    1115
# Name: amount_per_area, dtype: int64
# 1552 1082    1691
# Name: amount_per_area, dtype: int64
# 1596 121    1146
# Name: amount_per_area, dtype: int64
# 1596 602    1231
# Name: amount_per_area, dtype: int64
# 1596 1083    1909
# Name: amount_per_area, dtype: int64
# 1596 121    1146
# Name: amount_per_area, dtype: int64
# 1596 602    1231
# Name: amount_per_area, dtype: int64
# 1596 1083    1909
# Name: amount_per_area, dtype: int64
# 1231 122    361
# Name: amount_per_area, dtype: int64
# 1231 603    577
# Name: amount_per_area, dtype: int64
# 1231 1084    1467
# Name: amount_per_area, dtype: int64
# 1231 122    361
# Name: amount_per_area, dtype: int64
# 1231 603    577
# Name: amount_per_area, dtype: int64
# 1231 1084    1467
# Name: amount_per_area, dtype: int64
# 2281 123    935
# Name: amount_per_area, dtype: int64
# 2281 604    1215
# Name: amount_per_area, dtype: int64
# 2281 1085    2477
# Name: amount_per_area, dtype: int64
# 2281 123    935
# Name: amount_per_area, dtype: int64
# 2281 604    1215
# Name: amount_per_area, dtype: int64
# 2281 1085    2477
# Name: amount_per_area, dtype: int64
# 1056 124    566
# Name: amount_per_area, dtype: int64
# 1056 605    900
# Name: amount_per_area, dtype: int64
# 1056 1086    1105
# Name: amount_per_area, dtype: int64
# 1056 124    566
# Name: amount_per_area, dtype: int64
# 1056 605    900
# Name: amount_per_area, dtype: int64
# 1056 1086    1105
# Name: amount_per_area, dtype: int64
# 916 125    436
# Name: amount_per_area, dtype: int64
# 916 606    821
# Name: amount_per_area, dtype: int64
# 916 1087    1308
# Name: amount_per_area, dtype: int64
# 916 125    436
# Name: amount_per_area, dtype: int64
# 916 606    821
# Name: amount_per_area, dtype: int64
# 916 1087    1308
# Name: amount_per_area, dtype: int64
# 914 126    978
# Name: amount_per_area, dtype: int64
# 914 607    856
# Name: amount_per_area, dtype: int64
# 914 1088    1223
# Name: amount_per_area, dtype: int64
# 914 126    978
# Name: amount_per_area, dtype: int64
# 914 607    856
# Name: amount_per_area, dtype: int64
# 914 1088    1223
# Name: amount_per_area, dtype: int64
# 267 127    1102
# Name: amount_per_area, dtype: int64
# 267 608    706
# Name: amount_per_area, dtype: int64
# 267 1089    397
# Name: amount_per_area, dtype: int64
# 267 127    1102
# Name: amount_per_area, dtype: int64
# 267 608    706
# Name: amount_per_area, dtype: int64
# 267 1089    397
# Name: amount_per_area, dtype: int64
# 2211 128    255
# Name: amount_per_area, dtype: int64
# 2211 609    765
# Name: amount_per_area, dtype: int64
# 2211 1090    2622
# Name: amount_per_area, dtype: int64
# 2211 128    255
# Name: amount_per_area, dtype: int64
# 2211 609    765
# Name: amount_per_area, dtype: int64
# 2211 1090    2622
# Name: amount_per_area, dtype: int64
# 2693 129    541
# Name: amount_per_area, dtype: int64
# 2693 610    1126
# Name: amount_per_area, dtype: int64
# 2693 1091    2837
# Name: amount_per_area, dtype: int64
# 2693 129    541
# Name: amount_per_area, dtype: int64
# 2693 610    1126
# Name: amount_per_area, dtype: int64
# 2693 1091    2837
# Name: amount_per_area, dtype: int64
# 2303 130    977
# Name: amount_per_area, dtype: int64
# 2303 611    1349
# Name: amount_per_area, dtype: int64
# 2303 1092    2326
# Name: amount_per_area, dtype: int64
# 2303 130    977
# Name: amount_per_area, dtype: int64
# 2303 611    1349
# Name: amount_per_area, dtype: int64
# 2303 1092    2326
# Name: amount_per_area, dtype: int64
# 2194 131    1036
# Name: amount_per_area, dtype: int64
# 2194 612    1413
# Name: amount_per_area, dtype: int64
# 2194 1093    2260
# Name: amount_per_area, dtype: int64
# 2194 131    1036
# Name: amount_per_area, dtype: int64
# 2194 612    1413
# Name: amount_per_area, dtype: int64
# 2194 1093    2260
# Name: amount_per_area, dtype: int64
# 1958 132    1348
# Name: amount_per_area, dtype: int64
# 1958 613    1448
# Name: amount_per_area, dtype: int64
# 1958 1094    2197
# Name: amount_per_area, dtype: int64
# 1958 132    1348
# Name: amount_per_area, dtype: int64
# 1958 613    1448
# Name: amount_per_area, dtype: int64
# 1958 1094    2197
# Name: amount_per_area, dtype: int64
# 0 133    0
# Name: amount_per_area, dtype: int64
# 0 614    0
# Name: amount_per_area, dtype: int64
# 0 1095    0
# Name: amount_per_area, dtype: int64
# 0 133    0
# Name: amount_per_area, dtype: int64
# 0 614    0
# Name: amount_per_area, dtype: int64
# 0 1095    0
# Name: amount_per_area, dtype: int64
# 541 134    2247
# Name: amount_per_area, dtype: int64
# 541 615    1053
# Name: amount_per_area, dtype: int64
# 541 1096    211
# Name: amount_per_area, dtype: int64
# 541 134    2247
# Name: amount_per_area, dtype: int64
# 541 615    1053
# Name: amount_per_area, dtype: int64
# 541 1096    211
# Name: amount_per_area, dtype: int64
# 1969 135    1099
# Name: amount_per_area, dtype: int64
# 1969 616    1282
# Name: amount_per_area, dtype: int64
# 1969 1097    2198
# Name: amount_per_area, dtype: int64
# 1969 135    1099
# Name: amount_per_area, dtype: int64
# 1969 616    1282
# Name: amount_per_area, dtype: int64
# 1969 1097    2198
# Name: amount_per_area, dtype: int64
# 1753 136    1124
# Name: amount_per_area, dtype: int64
# 1753 617    1208
# Name: amount_per_area, dtype: int64
# 1753 1098    1832
# Name: amount_per_area, dtype: int64
# 1753 136    1124
# Name: amount_per_area, dtype: int64
# 1753 617    1208
# Name: amount_per_area, dtype: int64
# 1753 1098    1832
# Name: amount_per_area, dtype: int64
# 2813 137    1108
# Name: amount_per_area, dtype: int64
# 2813 618    1218
# Name: amount_per_area, dtype: int64
# 2813 1099    3211
# Name: amount_per_area, dtype: int64
# 2813 137    1108
# Name: amount_per_area, dtype: int64
# 2813 618    1218
# Name: amount_per_area, dtype: int64
# 2813 1099    3211
# Name: amount_per_area, dtype: int64
# 2155 138    713
# Name: amount_per_area, dtype: int64
# 2155 619    1090
# Name: amount_per_area, dtype: int64
# 2155 1100    2390
# Name: amount_per_area, dtype: int64
# 2155 138    713
# Name: amount_per_area, dtype: int64
# 2155 619    1090
# Name: amount_per_area, dtype: int64
# 2155 1100    2390
# Name: amount_per_area, dtype: int64
# 2407 139    521
# Name: amount_per_area, dtype: int64
# 2407 620    998
# Name: amount_per_area, dtype: int64
# 2407 1101    2775
# Name: amount_per_area, dtype: int64
# 2407 139    521
# Name: amount_per_area, dtype: int64
# 2407 620    998
# Name: amount_per_area, dtype: int64
# 2407 1101    2775
# Name: amount_per_area, dtype: int64
# 1983 140    388
# Name: amount_per_area, dtype: int64
# 1983 621    808
# Name: amount_per_area, dtype: int64
# 1983 1102    2002
# Name: amount_per_area, dtype: int64
# 1983 140    388
# Name: amount_per_area, dtype: int64
# 1983 621    808
# Name: amount_per_area, dtype: int64
# 1983 1102    2002
# Name: amount_per_area, dtype: int64
# 2175 141    767
# Name: amount_per_area, dtype: int64
# 2175 622    1050
# Name: amount_per_area, dtype: int64
# 2175 1103    2179
# Name: amount_per_area, dtype: int64
# 2175 141    767
# Name: amount_per_area, dtype: int64
# 2175 622    1050
# Name: amount_per_area, dtype: int64
# 2175 1103    2179
# Name: amount_per_area, dtype: int64
# 0 142    0
# Name: amount_per_area, dtype: int64
# 0 623    0
# Name: amount_per_area, dtype: int64
# 0 1104    0
# Name: amount_per_area, dtype: int64
# 0 142    0
# Name: amount_per_area, dtype: int64
# 0 623    0
# Name: amount_per_area, dtype: int64
# 0 1104    0
# Name: amount_per_area, dtype: int64
# 1747 143    1254
# Name: amount_per_area, dtype: int64
# 1747 624    1299
# Name: amount_per_area, dtype: int64
# 1747 1105    1926
# Name: amount_per_area, dtype: int64
# 1747 143    1254
# Name: amount_per_area, dtype: int64
# 1747 624    1299
# Name: amount_per_area, dtype: int64
# 1747 1105    1926
# Name: amount_per_area, dtype: int64
# 0 144    0
# Name: amount_per_area, dtype: int64
# 0 625    0
# Name: amount_per_area, dtype: int64
# 0 1106    0
# Name: amount_per_area, dtype: int64
# 0 144    0
# Name: amount_per_area, dtype: int64
# 0 625    0
# Name: amount_per_area, dtype: int64
# 0 1106    0
# Name: amount_per_area, dtype: int64
# 1 145    0
# Name: amount_per_area, dtype: int64
# 1 626    0
# Name: amount_per_area, dtype: int64
# 1 1107    0
# Name: amount_per_area, dtype: int64
# 1 145    0
# Name: amount_per_area, dtype: int64
# 1 626    0
# Name: amount_per_area, dtype: int64
# 1 1107    0
# Name: amount_per_area, dtype: int64
# 0 146    0
# Name: amount_per_area, dtype: int64
# 0 627    0
# Name: amount_per_area, dtype: int64
# 0 1108    0
# Name: amount_per_area, dtype: int64
# 0 146    0
# Name: amount_per_area, dtype: int64
# 0 627    0
# Name: amount_per_area, dtype: int64
# 0 1108    0
# Name: amount_per_area, dtype: int64
# 2 147    0
# Name: amount_per_area, dtype: int64
# 2 628    0
# Name: amount_per_area, dtype: int64
# 2 1109    0
# Name: amount_per_area, dtype: int64
# 2 147    0
# Name: amount_per_area, dtype: int64
# 2 628    0
# Name: amount_per_area, dtype: int64
# 2 1109    0
# Name: amount_per_area, dtype: int64
# 4 148    0
# Name: amount_per_area, dtype: int64
# 4 629    0
# Name: amount_per_area, dtype: int64
# 4 1110    0
# Name: amount_per_area, dtype: int64
# 4 148    0
# Name: amount_per_area, dtype: int64
# 4 629    0
# Name: amount_per_area, dtype: int64
# 4 1110    0
# Name: amount_per_area, dtype: int64
# 32 149    15
# Name: amount_per_area, dtype: int64
# 32 630    69
# Name: amount_per_area, dtype: int64
# 32 1111    66
# Name: amount_per_area, dtype: int64
# 32 149    15
# Name: amount_per_area, dtype: int64
# 32 630    69
# Name: amount_per_area, dtype: int64
# 32 1111    66
# Name: amount_per_area, dtype: int64
# 0 150    0
# Name: amount_per_area, dtype: int64
# 0 631    0
# Name: amount_per_area, dtype: int64
# 0 1112    0
# Name: amount_per_area, dtype: int64
# 0 150    0
# Name: amount_per_area, dtype: int64
# 0 631    0
# Name: amount_per_area, dtype: int64
# 0 1112    0
# Name: amount_per_area, dtype: int64
# 0 151    0
# Name: amount_per_area, dtype: int64
# 0 632    0
# Name: amount_per_area, dtype: int64
# 0 1113    0
# Name: amount_per_area, dtype: int64
# 0 151    0
# Name: amount_per_area, dtype: int64
# 0 632    0
# Name: amount_per_area, dtype: int64
# 0 1113    0
# Name: amount_per_area, dtype: int64
# 428 152    652
# Name: amount_per_area, dtype: int64
# 428 633    557
# Name: amount_per_area, dtype: int64
# 428 1114    382
# Name: amount_per_area, dtype: int64
# 428 152    652
# Name: amount_per_area, dtype: int64
# 428 633    557
# Name: amount_per_area, dtype: int64
# 428 1114    382
# Name: amount_per_area, dtype: int64
# 334 153    883
# Name: amount_per_area, dtype: int64
# 334 634    687
# Name: amount_per_area, dtype: int64
# 334 1115    393
# Name: amount_per_area, dtype: int64
# 334 153    883
# Name: amount_per_area, dtype: int64
# 334 634    687
# Name: amount_per_area, dtype: int64
# 334 1115    393
# Name: amount_per_area, dtype: int64
# 396 154    572
# Name: amount_per_area, dtype: int64
# 396 635    558
# Name: amount_per_area, dtype: int64
# 396 1116    338
# Name: amount_per_area, dtype: int64
# 396 154    572
# Name: amount_per_area, dtype: int64
# 396 635    558
# Name: amount_per_area, dtype: int64
# 396 1116    338
# Name: amount_per_area, dtype: int64
# 694 155    419
# Name: amount_per_area, dtype: int64
# 694 636    548
# Name: amount_per_area, dtype: int64
# 694 1117    644
# Name: amount_per_area, dtype: int64
# 694 155    419
# Name: amount_per_area, dtype: int64
# 694 636    548
# Name: amount_per_area, dtype: int64
# 694 1117    644
# Name: amount_per_area, dtype: int64
# 487 156    744
# Name: amount_per_area, dtype: int64
# 487 637    706
# Name: amount_per_area, dtype: int64
# 487 1118    409
# Name: amount_per_area, dtype: int64
# 487 156    744
# Name: amount_per_area, dtype: int64
# 487 637    706
# Name: amount_per_area, dtype: int64
# 487 1118    409
# Name: amount_per_area, dtype: int64
# 344 157    1486
# Name: amount_per_area, dtype: int64
# 344 638    1049
# Name: amount_per_area, dtype: int64
# 344 1119    379
# ...
# Name: amount_per_area, dtype: int64
# 10 433    0
# Name: amount_per_area, dtype: int64
# 10 914    0
# Name: amount_per_area, dtype: int64
# 10 1395    0
# Name: amount_per_area, dtype: int64
# 9 434    0
# Name: amount_per_area, dtype: int64
# 9 915    0
# Name: amount_per_area, dtype: int64
# 9 1396    0
# Name: amount_per_area, dtype: int64
# 9 434    0
# Name: amount_per_area, dtype: int64
# 9 915    0
# Name: amount_per_area, dtype: int64
# 9 1396    0
# Name: amount_per_area, dtype: int64
# 4 435    0
# Name: amount_per_area, dtype: int64
# 4 916    0
# Name: amount_per_area, dtype: int64
# 4 1397    0
# Name: amount_per_area, dtype: int64
# 4 435    0
# Name: amount_per_area, dtype: int64
# 4 916    0
# Name: amount_per_area, dtype: int64
# 4 1397    0
# Name: amount_per_area, dtype: int64
# 71 436    7
# Name: amount_per_area, dtype: int64
# 71 917    138
# Name: amount_per_area, dtype: int64
# 71 1398    68
# Name: amount_per_area, dtype: int64
# 71 436    7
# Name: amount_per_area, dtype: int64
# 71 917    138
# Name: amount_per_area, dtype: int64
# 71 1398    68
# Name: amount_per_area, dtype: int64
# 0 437    0
# Name: amount_per_area, dtype: int64
# 0 918    0
# Name: amount_per_area, dtype: int64
# 0 1399    0
# Name: amount_per_area, dtype: int64
# 0 437    0
# Name: amount_per_area, dtype: int64
# 0 918    0
# Name: amount_per_area, dtype: int64
# 0 1399    0
# Name: amount_per_area, dtype: int64
# 3 438    0
# Name: amount_per_area, dtype: int64
# 3 919    0
# Name: amount_per_area, dtype: int64
# 3 1400    0
# Name: amount_per_area, dtype: int64
# 3 438    0
# Name: amount_per_area, dtype: int64
# 3 919    0
# Name: amount_per_area, dtype: int64
# 3 1400    0
# Name: amount_per_area, dtype: int64
# 5 439    10
# Name: amount_per_area, dtype: int64
# 5 920    6
# Name: amount_per_area, dtype: int64
# 5 1401    3
# Name: amount_per_area, dtype: int64
# 5 439    10
# Name: amount_per_area, dtype: int64
# 5 920    6
# Name: amount_per_area, dtype: int64
# 5 1401    3
# Name: amount_per_area, dtype: int64
# 923 440    825
# Name: amount_per_area, dtype: int64
# 923 921    784
# Name: amount_per_area, dtype: int64
# 923 1402    402
# Name: amount_per_area, dtype: int64
# 923 440    825
# Name: amount_per_area, dtype: int64
# 923 921    784
# Name: amount_per_area, dtype: int64
# 923 1402    402
# Name: amount_per_area, dtype: int64
# 881 441    710
# Name: amount_per_area, dtype: int64
# 881 922    787
# Name: amount_per_area, dtype: int64
# 881 1403    422
# Name: amount_per_area, dtype: int64
# 881 441    710
# Name: amount_per_area, dtype: int64
# 881 922    787
# Name: amount_per_area, dtype: int64
# 881 1403    422
# Name: amount_per_area, dtype: int64
# 736 442    168
# Name: amount_per_area, dtype: int64
# 736 923    812
# Name: amount_per_area, dtype: int64
# 736 1404    310
# Name: amount_per_area, dtype: int64
# 736 442    168
# Name: amount_per_area, dtype: int64
# 736 923    812
# Name: amount_per_area, dtype: int64
# 736 1404    310
# Name: amount_per_area, dtype: int64
# 1244 443    1167
# Name: amount_per_area, dtype: int64
# 1244 924    1167
# Name: amount_per_area, dtype: int64
# 1244 1405    737
# Name: amount_per_area, dtype: int64
# 1244 443    1167
# Name: amount_per_area, dtype: int64
# 1244 924    1167
# Name: amount_per_area, dtype: int64
# 1244 1405    737
# Name: amount_per_area, dtype: int64
# 309 444    297
# Name: amount_per_area, dtype: int64
# 309 925    220
# Name: amount_per_area, dtype: int64
# 309 1406    78
# Name: amount_per_area, dtype: int64
# 309 444    297
# Name: amount_per_area, dtype: int64
# 309 925    220
# Name: amount_per_area, dtype: int64
# 309 1406    78
# Name: amount_per_area, dtype: int64
# 742 445    509
# Name: amount_per_area, dtype: int64
# 742 926    664
# Name: amount_per_area, dtype: int64
# 742 1407    240
# Name: amount_per_area, dtype: int64
# 742 445    509
# Name: amount_per_area, dtype: int64
# 742 926    664
# Name: amount_per_area, dtype: int64
# 742 1407    240
# Name: amount_per_area, dtype: int64
# 1676 446    1454
# Name: amount_per_area, dtype: int64
# 1676 927    960
# Name: amount_per_area, dtype: int64
# 1676 1408    330
# Name: amount_per_area, dtype: int64
# 1676 446    1454
# Name: amount_per_area, dtype: int64
# 1676 927    960
# Name: amount_per_area, dtype: int64
# 1676 1408    330
# Name: amount_per_area, dtype: int64
# 925 447    750
# Name: amount_per_area, dtype: int64
# 925 928    633
# Name: amount_per_area, dtype: int64
# 925 1409    300
# Name: amount_per_area, dtype: int64
# 925 447    750
# Name: amount_per_area, dtype: int64
# 925 928    633
# Name: amount_per_area, dtype: int64
# 925 1409    300
# Name: amount_per_area, dtype: int64
# 124 448    93
# Name: amount_per_area, dtype: int64
# 124 929    96
# Name: amount_per_area, dtype: int64
# 124 1410    128
# Name: amount_per_area, dtype: int64
# 124 448    93
# Name: amount_per_area, dtype: int64
# 124 929    96
# Name: amount_per_area, dtype: int64
# 124 1410    128
# Name: amount_per_area, dtype: int64
# 658 449    540
# Name: amount_per_area, dtype: int64
# 658 930    827
# Name: amount_per_area, dtype: int64
# 658 1411    432
# Name: amount_per_area, dtype: int64
# 658 449    540
# Name: amount_per_area, dtype: int64
# 658 930    827
# Name: amount_per_area, dtype: int64
# 658 1411    432
# Name: amount_per_area, dtype: int64
# 0 450    0
# Name: amount_per_area, dtype: int64
# 0 931    0
# Name: amount_per_area, dtype: int64
# 0 1412    0
# Name: amount_per_area, dtype: int64
# 0 450    0
# Name: amount_per_area, dtype: int64
# 0 931    0
# Name: amount_per_area, dtype: int64
# 0 1412    0
# Name: amount_per_area, dtype: int64
# 430 451    311
# Name: amount_per_area, dtype: int64
# 430 932    560
# Name: amount_per_area, dtype: int64
# 430 1413    374
# Name: amount_per_area, dtype: int64
# 430 451    311
# Name: amount_per_area, dtype: int64
# 430 932    560
# Name: amount_per_area, dtype: int64
# 430 1413    374
# Name: amount_per_area, dtype: int64
# 682 452    551
# Name: amount_per_area, dtype: int64
# 682 933    697
# Name: amount_per_area, dtype: int64
# 682 1414    389
# Name: amount_per_area, dtype: int64
# 682 452    551
# Name: amount_per_area, dtype: int64
# 682 933    697
# Name: amount_per_area, dtype: int64
# 682 1414    389
# Name: amount_per_area, dtype: int64
# 1674 453    1565
# Name: amount_per_area, dtype: int64
# 1674 934    922
# Name: amount_per_area, dtype: int64
# 1674 1415    280
# Name: amount_per_area, dtype: int64
# 1674 453    1565
# Name: amount_per_area, dtype: int64
# 1674 934    922
# Name: amount_per_area, dtype: int64
# 1674 1415    280
# Name: amount_per_area, dtype: int64
# 924 454    974
# Name: amount_per_area, dtype: int64
# 924 935    909
# Name: amount_per_area, dtype: int64
# 924 1416    282
# Name: amount_per_area, dtype: int64
# 924 454    974
# Name: amount_per_area, dtype: int64
# 924 935    909
# Name: amount_per_area, dtype: int64
# 924 1416    282
# Name: amount_per_area, dtype: int64
# 306 455    359
# Name: amount_per_area, dtype: int64
# 306 936    351
# Name: amount_per_area, dtype: int64
# 306 1417    126
# Name: amount_per_area, dtype: int64
# 306 455    359
# Name: amount_per_area, dtype: int64
# 306 936    351
# Name: amount_per_area, dtype: int64
# 306 1417    126
# Name: amount_per_area, dtype: int64
# 1373 456    1072
# Name: amount_per_area, dtype: int64
# 1373 937    1098
# Name: amount_per_area, dtype: int64
# 1373 1418    445
# Name: amount_per_area, dtype: int64
# 1373 456    1072
# Name: amount_per_area, dtype: int64
# 1373 937    1098
# Name: amount_per_area, dtype: int64
# 1373 1418    445
# Name: amount_per_area, dtype: int64
# 555 457    382
# Name: amount_per_area, dtype: int64
# 555 938    534
# Name: amount_per_area, dtype: int64
# 555 1419    344
# Name: amount_per_area, dtype: int64
# 555 457    382
# Name: amount_per_area, dtype: int64
# 555 938    534
# Name: amount_per_area, dtype: int64
# 555 1419    344
# Name: amount_per_area, dtype: int64
# 601 458    601
# Name: amount_per_area, dtype: int64
# 601 939    696
# Name: amount_per_area, dtype: int64
# 601 1420    285
# Name: amount_per_area, dtype: int64
# 601 458    601
# Name: amount_per_area, dtype: int64
# 601 939    696
# Name: amount_per_area, dtype: int64
# 601 1420    285
# Name: amount_per_area, dtype: int64
# 933 459    859
# Name: amount_per_area, dtype: int64
# 933 940    1061
# Name: amount_per_area, dtype: int64
# 933 1421    581
# Name: amount_per_area, dtype: int64
# 933 459    859
# Name: amount_per_area, dtype: int64
# 933 940    1061
# Name: amount_per_area, dtype: int64
# 933 1421    581
# Name: amount_per_area, dtype: int64
# 217 460    144
# Name: amount_per_area, dtype: int64
# 217 941    262
# Name: amount_per_area, dtype: int64
# 217 1422    249
# Name: amount_per_area, dtype: int64
# 217 460    144
# Name: amount_per_area, dtype: int64
# 217 941    262
# Name: amount_per_area, dtype: int64
# 217 1422    249
# Name: amount_per_area, dtype: int64
# 289 461    294
# Name: amount_per_area, dtype: int64
# 289 942    294
# Name: amount_per_area, dtype: int64
# 289 1423    154
# Name: amount_per_area, dtype: int64
# 289 461    294
# Name: amount_per_area, dtype: int64
# 289 942    294
# Name: amount_per_area, dtype: int64
# 289 1423    154
# Name: amount_per_area, dtype: int64
# 152 462    71
# Name: amount_per_area, dtype: int64
# 152 943    187
# Name: amount_per_area, dtype: int64
# 152 1424    154
# Name: amount_per_area, dtype: int64
# 152 462    71
# Name: amount_per_area, dtype: int64
# 152 943    187
# Name: amount_per_area, dtype: int64
# 152 1424    154
# Name: amount_per_area, dtype: int64
# 2208 463    2403
# Name: amount_per_area, dtype: int64
# 2208 944    1450
# Name: amount_per_area, dtype: int64
# 2208 1425    290
# Name: amount_per_area, dtype: int64
# 2208 463    2403
# Name: amount_per_area, dtype: int64
# 2208 944    1450
# Name: amount_per_area, dtype: int64
# 2208 1425    290
# Name: amount_per_area, dtype: int64
# 1322 464    954
# Name: amount_per_area, dtype: int64
# 1322 945    863
# Name: amount_per_area, dtype: int64
# 1322 1426    455
# Name: amount_per_area, dtype: int64
# 1322 464    954
# Name: amount_per_area, dtype: int64
# 1322 945    863
# Name: amount_per_area, dtype: int64
# 1322 1426    455
# Name: amount_per_area, dtype: int64
# 284 465    145
# Name: amount_per_area, dtype: int64
# 284 946    297
# Name: amount_per_area, dtype: int64
# 284 1427    282
# Name: amount_per_area, dtype: int64
# 284 465    145
# Name: amount_per_area, dtype: int64
# 284 946    297
# Name: amount_per_area, dtype: int64
# 284 1427    282
# Name: amount_per_area, dtype: int64
# 1 466    0
# Name: amount_per_area, dtype: int64
# 1 947    0
# Name: amount_per_area, dtype: int64
# 1 1428    0
# Name: amount_per_area, dtype: int64
# 1 466    0
# Name: amount_per_area, dtype: int64
# 1 947    0
# Name: amount_per_area, dtype: int64
# 1 1428    0
# Name: amount_per_area, dtype: int64
# 2 467    0
# Name: amount_per_area, dtype: int64
# 2 948    0
# Name: amount_per_area, dtype: int64
# 2 1429    0
# Name: amount_per_area, dtype: int64
# 2 467    0
# Name: amount_per_area, dtype: int64
# 2 948    0
# Name: amount_per_area, dtype: int64
# 2 1429    0
# Name: amount_per_area, dtype: int64
# 541 468    720
# Name: amount_per_area, dtype: int64
# 541 949    618
# Name: amount_per_area, dtype: int64
# 541 1430    133
# Name: amount_per_area, dtype: int64
# 541 468    720
# Name: amount_per_area, dtype: int64
# 541 949    618
# Name: amount_per_area, dtype: int64
# 541 1430    133
# Name: amount_per_area, dtype: int64
# 897 469    979
# Name: amount_per_area, dtype: int64
# 897 950    836
# Name: amount_per_area, dtype: int64
# 897 1431    225
# Name: amount_per_area, dtype: int64
# 897 469    979
# Name: amount_per_area, dtype: int64
# 897 950    836
# Name: amount_per_area, dtype: int64
# 897 1431    225
# Name: amount_per_area, dtype: int64
# 204 470    182
# Name: amount_per_area, dtype: int64
# 204 951    315
# Name: amount_per_area, dtype: int64
# 204 1432    203
# Name: amount_per_area, dtype: int64
# 204 470    182
# Name: amount_per_area, dtype: int64
# 204 951    315
# Name: amount_per_area, dtype: int64
# 204 1432    203
# Name: amount_per_area, dtype: int64
# 566 471    572
# Name: amount_per_area, dtype: int64
# 566 952    587
# Name: amount_per_area, dtype: int64
# 566 1433    308
# Name: amount_per_area, dtype: int64
# 566 471    572
# Name: amount_per_area, dtype: int64
# 566 952    587
# Name: amount_per_area, dtype: int64
# 566 1433    308
# Name: amount_per_area, dtype: int64
# 564 472    464
# Name: amount_per_area, dtype: int64
# 564 953    586
# Name: amount_per_area, dtype: int64
# 564 1434    314
# Name: amount_per_area, dtype: int64
# 564 472    464
# Name: amount_per_area, dtype: int64
# 564 953    586
# Name: amount_per_area, dtype: int64
# 564 1434    314
# Name: amount_per_area, dtype: int64
# 615 473    623
# Name: amount_per_area, dtype: int64
# 615 954    765
# Name: amount_per_area, dtype: int64
# 615 1435    392
# Name: amount_per_area, dtype: int64
# 615 473    623
# Name: amount_per_area, dtype: int64
# 615 954    765
# Name: amount_per_area, dtype: int64
# 615 1435    392
# Name: amount_per_area, dtype: int64
# 251 474    221
# Name: amount_per_area, dtype: int64
# 251 955    335
# Name: amount_per_area, dtype: int64
# 251 1436    206
# Name: amount_per_area, dtype: int64
# 251 474    221
# Name: amount_per_area, dtype: int64
# 251 955    335
# Name: amount_per_area, dtype: int64
# 251 1436    206
# Name: amount_per_area, dtype: int64
# 708 475    700
# Name: amount_per_area, dtype: int64
# 708 956    700
# Name: amount_per_area, dtype: int64
# 708 1437    308
# Name: amount_per_area, dtype: int64
# 708 475    700
# Name: amount_per_area, dtype: int64
# 708 956    700
# Name: amount_per_area, dtype: int64
# 708 1437    308
# Name: amount_per_area, dtype: int64
# 811 476    667
# Name: amount_per_area, dtype: int64
# 811 957    751
# Name: amount_per_area, dtype: int64
# 811 1438    251
# Name: amount_per_area, dtype: int64
# 811 476    667
# Name: amount_per_area, dtype: int64
# 811 957    751
# Name: amount_per_area, dtype: int64
# 811 1438    251
# Name: amount_per_area, dtype: int64
# 264 477    211
# Name: amount_per_area, dtype: int64
# 264 958    395
# Name: amount_per_area, dtype: int64
# 264 1439    312
# Name: amount_per_area, dtype: int64
# 264 477    211
# Name: amount_per_area, dtype: int64
# 264 958    395
# Name: amount_per_area, dtype: int64
# 264 1439    312
# Name: amount_per_area, dtype: int64
# 283 478    283
# Name: amount_per_area, dtype: int64
# 283 959    350
# Name: amount_per_area, dtype: int64
# 283 1440    200
# Name: amount_per_area, dtype: int64
# 283 478    283
# Name: amount_per_area, dtype: int64
# 283 959    350
# Name: amount_per_area, dtype: int64
# 283 1440    200
# Name: amount_per_area, dtype: int64
# 123 479    240
# Name: amount_per_area, dtype: int64
# 123 960    382
# Name: amount_per_area, dtype: int64
# 123 1441    267
# Name: amount_per_area, dtype: int64
# 123 479    240
# Name: amount_per_area, dtype: int64
# 123 960    382
# Name: amount_per_area, dtype: int64
# 123 1441    267
# Name: amount_per_area, dtype: int64
# 2 480    0
# Name: amount_per_area, dtype: int64
# 2 961    0
# Name: amount_per_area, dtype: int64
# 2 1442    0
# Name: amount_per_area, dtype: int64
# 2 480    0
# Name: amount_per_area, dtype: int64
# 2 961    0
# Name: amount_per_area, dtype: int64
# 2 1442    0
# Name: amount_per_area, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-abc3616d7ae8> in <module>
#      50 df['amount'] = amounts
#      51 df['oplniv'] = educations
# ---> 52 df['percentage'] = percentages
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (14430)

# %%
df['p'] = df['amount']/df['amount'].sum()

# %%
df['code']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 14425    480
# 14426    480
# 14427    480
# 14428    480
# 14429    480
# Name: code, Length: 14430, dtype: int64

# %%
peeps = []

for i in range(481):
    
    
    area = df[df['code'] == i]
    
#     print(area['amount']/area['amount'].sum())
    x = list(area['amount']/area['amount'].sum())
    peeps.extend(x)
    
    print(len(peeps), len(x))
#     print(area)
    
#     print(len(peeps) * 481)
#     raise
#     peeps.append((df[df['code'] == i]['amount'].sum()))
# Out:
# 30 30
# 60 30
# 90 30
# 120 30
# 150 30
# 180 30
# 210 30
# 240 30
# 270 30
# 300 30
# 330 30
# 360 30
# 390 30
# 420 30
# 450 30
# 480 30
# 510 30
# 540 30
# 570 30
# 600 30
# 630 30
# 660 30
# 690 30
# 720 30
# 750 30
# 780 30
# 810 30
# 840 30
# 870 30
# 900 30
# 930 30
# 960 30
# 990 30
# 1020 30
# 1050 30
# 1080 30
# 1110 30
# 1140 30
# 1170 30
# 1200 30
# 1230 30
# 1260 30
# 1290 30
# 1320 30
# 1350 30
# 1380 30
# 1410 30
# 1440 30
# 1470 30
# 1500 30
# 1530 30
# 1560 30
# 1590 30
# 1620 30
# 1650 30
# 1680 30
# 1710 30
# 1740 30
# 1770 30
# 1800 30
# 1830 30
# 1860 30
# 1890 30
# 1920 30
# 1950 30
# 1980 30
# 2010 30
# 2040 30
# 2070 30
# 2100 30
# 2130 30
# 2160 30
# 2190 30
# 2220 30
# 2250 30
# 2280 30
# 2310 30
# 2340 30
# 2370 30
# 2400 30
# 2430 30
# 2460 30
# 2490 30
# 2520 30
# 2550 30
# 2580 30
# 2610 30
# 2640 30
# 2670 30
# 2700 30
# 2730 30
# 2760 30
# 2790 30
# 2820 30
# 2850 30
# 2880 30
# 2910 30
# 2940 30
# 2970 30
# 3000 30
# 3030 30
# 3060 30
# 3090 30
# 3120 30
# 3150 30
# 3180 30
# 3210 30
# 3240 30
# 3270 30
# 3300 30
# 3330 30
# 3360 30
# 3390 30
# 3420 30
# 3450 30
# 3480 30
# 3510 30
# 3540 30
# 3570 30
# 3600 30
# 3630 30
# 3660 30
# 3690 30
# 3720 30
# 3750 30
# 3780 30
# 3810 30
# 3840 30
# 3870 30
# 3900 30
# 3930 30
# 3960 30
# 3990 30
# 4020 30
# 4050 30
# 4080 30
# 4110 30
# 4140 30
# 4170 30
# 4200 30
# 4230 30
# 4260 30
# 4290 30
# 4320 30
# 4350 30
# 4380 30
# 4410 30
# 4440 30
# 4470 30
# 4500 30
# 4530 30
# 4560 30
# 4590 30
# 4620 30
# 4650 30
# 4680 30
# 4710 30
# 4740 30
# 4770 30
# 4800 30
# 4830 30
# 4860 30
# 4890 30
# 4920 30
# 4950 30
# 4980 30
# 5010 30
# 5040 30
# 5070 30
# 5100 30
# 5130 30
# 5160 30
# 5190 30
# 5220 30
# 5250 30
# 5280 30
# 5310 30
# 5340 30
# 5370 30
# 5400 30
# 5430 30
# 5460 30
# 5490 30
# 5520 30
# 5550 30
# 5580 30
# 5610 30
# 5640 30
# 5670 30
# 5700 30
# 5730 30
# 5760 30
# 5790 30
# 5820 30
# 5850 30
# 5880 30
# 5910 30
# 5940 30
# 5970 30
# 6000 30
# 6030 30
# 6060 30
# 6090 30
# 6120 30
# 6150 30
# 6180 30
# 6210 30
# 6240 30
# 6270 30
# 6300 30
# 6330 30
# 6360 30
# 6390 30
# 6420 30
# 6450 30
# 6480 30
# 6510 30
# 6540 30
# 6570 30
# 6600 30
# 6630 30
# 6660 30
# 6690 30
# 6720 30
# 6750 30
# 6780 30
# 6810 30
# 6840 30
# 6870 30
# 6900 30
# 6930 30
# 6960 30
# 6990 30
# 7020 30
# 7050 30
# 7080 30
# 7110 30
# 7140 30
# 7170 30
# 7200 30
# 7230 30
# 7260 30
# 7290 30
# 7320 30
# 7350 30
# 7380 30
# 7410 30
# 7440 30
# 7470 30
# 7500 30
# 7530 30
# 7560 30
# 7590 30
# 7620 30
# 7650 30
# 7680 30
# 7710 30
# 7740 30
# 7770 30
# 7800 30
# 7830 30
# 7860 30
# 7890 30
# 7920 30
# 7950 30
# 7980 30
# 8010 30
# 8040 30
# 8070 30
# 8100 30
# 8130 30
# 8160 30
# 8190 30
# 8220 30
# 8250 30
# 8280 30
# 8310 30
# 8340 30
# 8370 30
# 8400 30
# 8430 30
# 8460 30
# 8490 30
# 8520 30
# 8550 30
# 8580 30
# 8610 30
# 8640 30
# 8670 30
# 8700 30
# 8730 30
# 8760 30
# 8790 30
# 8820 30
# 8850 30
# 8880 30
# 8910 30
# 8940 30
# 8970 30
# 9000 30
# 9030 30
# 9060 30
# 9090 30
# 9120 30
# 9150 30
# 9180 30
# 9210 30
# 9240 30
# 9270 30
# 9300 30
# 9330 30
# 9360 30
# 9390 30
# 9420 30
# 9450 30
# 9480 30
# 9510 30
# 9540 30
# 9570 30
# 9600 30
# 9630 30
# 9660 30
# 9690 30
# 9720 30
# 9750 30
# 9780 30
# 9810 30
# 9840 30
# 9870 30
# 9900 30
# 9930 30
# 9960 30
# 9990 30
# 10020 30
# 10050 30
# 10080 30
# 10110 30
# 10140 30
# 10170 30
# 10200 30
# 10230 30
# 10260 30
# 10290 30
# 10320 30
# 10350 30
# 10380 30
# 10410 30
# 10440 30
# 10470 30
# 10500 30
# 10530 30
# 10560 30
# 10590 30
# 10620 30
# 10650 30
# 10680 30
# 10710 30
# 10740 30
# 10770 30
# 10800 30
# 10830 30
# 10860 30
# 10890 30
# 10920 30
# 10950 30
# 10980 30
# 11010 30
# 11040 30
# 11070 30
# 11100 30
# 11130 30
# 11160 30
# 11190 30
# 11220 30
# 11250 30
# 11280 30
# 11310 30
# 11340 30
# 11370 30
# 11400 30
# 11430 30
# 11460 30
# 11490 30
# 11520 30
# 11550 30
# 11580 30
# 11610 30
# 11640 30
# 11670 30
# 11700 30
# 11730 30
# 11760 30
# 11790 30
# 11820 30
# 11850 30
# 11880 30
# 11910 30
# 11940 30
# 11970 30
# 12000 30
# 12030 30
# 12060 30
# 12090 30
# 12120 30
# 12150 30
# 12180 30
# 12210 30
# 12240 30
# 12270 30
# 12300 30
# 12330 30
# 12360 30
# 12390 30
# 12420 30
# 12450 30
# 12480 30
# 12510 30
# 12540 30
# 12570 30
# 12600 30
# 12630 30
# 12660 30
# 12690 30
# 12720 30
# 12750 30
# 12780 30
# 12810 30
# 12840 30
# 12870 30
# 12900 30
# 12930 30
# 12960 30
# 12990 30
# 13020 30
# 13050 30
# 13080 30
# 13110 30
# 13140 30
# 13170 30
# 13200 30
# 13230 30
# 13260 30
# 13290 30
# 13320 30
# 13350 30
# 13380 30
# 13410 30
# 13440 30
# 13470 30
# 13500 30
# 13530 30
# 13560 30
# 13590 30
# 13620 30
# 13650 30
# 13680 30
# 13710 30
# 13740 30
# 13770 30
# 13800 30
# 13830 30
# 13860 30
# 13890 30
# 13920 30
# 13950 30
# 13980 30
# 14010 30
# 14040 30
# 14070 30
# 14100 30
# 14130 30
# 14160 30
# 14190 30
# 14220 30
# 14250 30
# 14280 30
# 14310 30
# 14340 30
# 14370 30
# 14400 30
# 14430 30

# %%
df['x'] = (df.amount/df.amount.sum())*861000

# %%
df[(df['x'] < 20) & (df['x'] > 0)]
# Out:
#            etngrp  code geslacht     amount  oplniv  percentage         x
# 108    Autochtoon    18      Man   7.262483       1    0.297864  0.234163
# 111    Autochtoon    18    Vrouw   7.262483       1    0.297864  0.234163
# 132    Autochtoon    22      Man  18.156207       1    0.297864  0.585406
# 135    Autochtoon    22    Vrouw  18.156207       1    0.297864  0.585406
# 150    Autochtoon    25      Man  50.111130       1    0.297864  1.615722
# ...           ...   ...      ...        ...     ...         ...       ...
# 14425      Overig   480      Man  10.000000       2    0.297864  0.322428
# 14426      Overig   480      Man  10.000000       3    0.297864  0.322428
# 14427      Overig   480    Vrouw  37.323682       1    0.297864  1.203419
# 14428      Overig   480    Vrouw   9.000000       2    0.297864  0.290185
# 14429      Overig   480    Vrouw   9.000000       3    0.297864  0.290185
#
# [3190 rows x 7 columns]

# %%
df
# Out:
#            etngrp  code geslacht       amount  oplniv  percentage           x
# 0      Autochtoon     0      Man  3679.090326       1    0.297864  118.624063
# 1      Autochtoon     0      Man  3925.288488       2    0.297864  126.562174
# 2      Autochtoon     0      Man  4645.726767       3    0.297864  149.791100
# 3      Autochtoon     0    Vrouw  3132.090326       1    0.297864  100.987268
# 4      Autochtoon     0    Vrouw  3378.288488       2    0.297864  108.925379
# ...           ...   ...      ...          ...     ...         ...         ...
# 14425      Overig   480      Man    10.000000       2    0.297864    0.322428
# 14426      Overig   480      Man    10.000000       3    0.297864    0.322428
# 14427      Overig   480    Vrouw    37.323682       1    0.297864    1.203419
# 14428      Overig   480    Vrouw     9.000000       2    0.297864    0.290185
# 14429      Overig   480    Vrouw     9.000000       3    0.297864    0.290185
#
# [14430 rows x 7 columns]

# %%
df['p'] = np.array(peeps)*100

# %%
df['percentage'] = df['p']

# %%
df = df.fillna(0)

# %%
df.groupby(by=['etngrp', 'geslacht', 'oplniv']).sum().reset_index()
# Out:
#         etngrp geslacht  oplniv    code     amount  percentage
# 0   Autochtoon      Man       1  115440  1022351.0   18.138694
# 1   Autochtoon      Man       2  115440  1098945.0   29.860822
# 2   Autochtoon      Man       3  115440  1262885.0   49.371007
# 3   Autochtoon    Vrouw       1  115440  1027601.0   18.122752
# 4   Autochtoon    Vrouw       2  115440  1104195.0   29.698893
# 5   Autochtoon    Vrouw       3  115440  1268135.0   49.256470
# 6   Marokkaans      Man       1  115440   672824.0    4.010332
# 7   Marokkaans      Man       2  115440   749418.0    4.333144
# 8   Marokkaans      Man       3  115440   913358.0    4.683347
# 9   Marokkaans    Vrouw       1  115440   678074.0    4.010402
# 10  Marokkaans    Vrouw       2  115440   754668.0    4.371163
# 11  Marokkaans    Vrouw       3  115440   918608.0    4.754648
# 12      Overig      Man       1  115440   900110.0   13.762250
# 13      Overig      Man       2  115440   976704.0   21.505823
# 14      Overig      Man       3  115440  1140644.0   32.421686
# 15      Overig    Vrouw       1  115440   905360.0   13.611971
# 16      Overig    Vrouw       2  115440   981954.0   21.115568
# 17      Overig    Vrouw       3  115440  1145894.0   31.793953
# 18   Surinaams      Man       1  115440   663428.0    3.986113
# 19   Surinaams      Man       2  115440   740022.0    4.791210
# 20   Surinaams      Man       3  115440   903962.0    4.557610
# 21   Surinaams    Vrouw       1  115440   668678.0    3.978599
# 22   Surinaams    Vrouw       2  115440   745272.0    4.815954
# 23   Surinaams    Vrouw       3  115440   909212.0    4.574193
# 24       Turks      Man       1  115440   643770.0    2.314945
# 25       Turks      Man       2  115440   720364.0    2.596739
# 26       Turks      Man       3  115440   884304.0    2.765373
# 27       Turks    Vrouw       1  115440   649020.0    2.326892
# 28       Turks    Vrouw       2  115440   725614.0    2.613894
# 29       Turks    Vrouw       3  115440   889554.0    2.782523

# %%
df[df['oplniv'] == 1].groupby(['etngrp', 'geslacht']).mean()
# Out:
#                      code       amount  oplniv  percentage
# etngrp     geslacht
# Autochtoon Man       10.5  1766.863636     1.0   21.185814
#            Vrouw     10.5  1792.681818     1.0   21.548305
# Marokkaans Man       10.5   422.045455     1.0    4.388768
#            Vrouw     10.5   426.954545     1.0    4.433650
# Overig     Man       10.5  1340.954545     1.0   17.470964
#            Vrouw     10.5  1354.954545     1.0   17.704691
# Surinaams  Man       10.5   382.318182     1.0    4.080632
#            Vrouw     10.5   384.818182     1.0    4.119173
# Turks      Man       10.5   247.318182     1.0    2.505841
#            Vrouw     10.5   250.227273     1.0    2.530345

# %%
df.to_csv('../Data/Spatial_data/spatial_data_withbias.csv')

# %%
df['x'] = df[]
# Out:
#            etngrp  code geslacht       amount  oplniv  percentage         p
# 0      Autochtoon     0      Man  3679.090326       1    0.013777  0.013777
# 1      Autochtoon     0      Man  3925.288488       2    0.014699  0.014699
# 2      Autochtoon     0      Man  4645.726767       3    0.017397  0.017397
# 3      Autochtoon     0    Vrouw  3132.090326       1    0.011729  0.011729
# 4      Autochtoon     0    Vrouw  3378.288488       2    0.012651  0.012651
# ...           ...   ...      ...          ...     ...         ...       ...
# 14425      Overig   480      Man    10.000000       2    0.000037  0.000037
# 14426      Overig   480      Man    10.000000       3    0.000037  0.000037
# 14427      Overig   480    Vrouw    37.323682       1    0.000140  0.000140
# 14428      Overig   480    Vrouw     9.000000       2    0.000034  0.000034
# 14429      Overig   480    Vrouw     9.000000       3    0.000034  0.000034
#
# [14430 rows x 7 columns]

# %%
# importing product
from itertools import product
  
# apply product method
x = list(product(df['geslacht'], df['etngrp'] ))

# %%
# Out:
# 0.7480161452478962

# %%
df.groupby(['geslacht','etngrp', 'oplniv']).size().reset_index().to_numpy()
# Out:
# array([['Man', 'Autochtoon', 1, 22],
#        ['Man', 'Autochtoon', 2, 22],
#        ['Man', 'Autochtoon', 3, 22],
#        ['Man', 'Marokkaans', 1, 22],
#        ['Man', 'Marokkaans', 2, 22],
#        ['Man', 'Marokkaans', 3, 22],
#        ['Man', 'Overig', 1, 22],
#        ['Man', 'Overig', 2, 22],
#        ['Man', 'Overig', 3, 22],
#        ['Man', 'Surinaams', 1, 22],
#        ['Man', 'Surinaams', 2, 22],
#        ['Man', 'Surinaams', 3, 22],
#        ['Man', 'Turks', 1, 22],
#        ['Man', 'Turks', 2, 22],
#        ['Man', 'Turks', 3, 22],
#        ['Vrouw', 'Autochtoon', 1, 22],
#        ['Vrouw', 'Autochtoon', 2, 22],
#        ['Vrouw', 'Autochtoon', 3, 22],
#        ['Vrouw', 'Marokkaans', 1, 22],
#        ['Vrouw', 'Marokkaans', 2, 22],
#        ['Vrouw', 'Marokkaans', 3, 22],
#        ['Vrouw', 'Overig', 1, 22],
#        ['Vrouw', 'Overig', 2, 22],
#        ['Vrouw', 'Overig', 3, 22],
#        ['Vrouw', 'Surinaams', 1, 22],
#        ['Vrouw', 'Surinaams', 2, 22],
#        ['Vrouw', 'Surinaams', 3, 22],
#        ['Vrouw', 'Turks', 1, 22],
#        ['Vrouw', 'Turks', 2, 22],
#        ['Vrouw', 'Turks', 3, 22]], dtype=object)
